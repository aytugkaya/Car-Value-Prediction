# %% [markdown]
# Import libraries -- may need to revisit to remove unused ones

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
df=pd.read_csv("autos.csv",  encoding='cp1252'  )

df.head()
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# <div class="span4 alert alert-success">
# ** QUESTION HERE***
#
#
# HERE I read the file. But when I work on the DF manupulation sometimes I make a mistake, and as we all know creating duplicate dfs don't work because if you change one all will change.
#
# What do you recommend here? How do I back-up? Do I go all the way to the beginning? Do I write a csv file?
#
# </div>

# %%
df[df.seller=="gewerblich"]
# Out:
#                 dateCrawled                                         name  \
# 59155   2016-03-15 18:06:22  Verkaufe_mehrere_Fahrzeuge_zum_Verschrotten
# 149393  2016-03-22 09:54:43              Chevrolet_Matiz_1.Hd_TÜV11/2017
# 186181  2016-03-14 15:58:22               BMW_2000_AUTOMATIK_H_ZULASSUNG
#
#             seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 59155   gewerblich   Angebot    100  control       kombi                2000
# 149393  gewerblich   Angebot   1100     test  kleinwagen                2006
# 186181  gewerblich   Angebot   6900  control   limousine                1967
#
#           gearbox  powerPS   model  kilometer  monthOfRegistration fuelType  \
# 59155     manuell        0  megane     150000                    8   benzin
# 149393    manuell       38   matiz     150000                   10   benzin
# 186181  automatik      101  andere      70000                    8   benzin
#
#             brand notRepairedDamage          dateCreated  nrOfPictures  \
# 59155     renault               NaN  2016-03-15 00:00:00             0
# 149393  chevrolet              nein  2016-03-22 00:00:00             0
# 186181        bmw              nein  2016-03-14 00:00:00             0
#
#         postalCode             lastSeen
# 59155        65232  2016-04-06 17:15:37
# 149393        7973  2016-04-05 21:15:48
# 186181       73614  2016-04-05 19:45:06

# %%
df.model=df.model.str.upper()
df.name=df.name.str.upper()
df.brand=df.brand.str.upper()
df[(df.brand=="SONSTIGE_AUTOS")&(df.model.isna()==False)]
df.name=df.name.str.replace("_", " ")
df.seller.unique()
df.seller[df.seller=="privat"] = "private"
df.seller[df.seller=="gewerblich"] = "dealer"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# <div class="span4 alert alert-success">
# ** QUESTION HERE***
#
#
# HERE I read the file. But when I work on the DF manupulation sometimes I make a mistake, and as we all know creating duplicate dfs don't work because if you change one all will change.
#
# What do you recommend here? How do I back-up? Do I go all the way to the beginning? Do I write a csv file?
#
# </div>

# %%
def namecol_list(nm,lst):
    results=[]
    #nm.split(" ")
    
    for row in nm:
        if "" in row:
            row.remove("")
     
        found=False
        for elmnt in row: 
           
                for brnd in lst:


                     if found!=True and brnd == elmnt: 
                        results.append(elmnt)

                        found=True
                        break
                        #break  #except:
                     else: 
                            if found==False and elmnt==row[-1] and brnd==lst[-1]: 
                               
                                results.append("NaN")
 
                                found=True
                                break
      
  
    return (results)

# %% [markdown]
# <div class="span4 alert alert-success">
# Here filtering starts on top and bottom level.
# Pretty easy to tell there will be no cars for 0 or "1 €", or under "100€" --- these are fake advertisements just to draw attention.
# Also, there are ultra luxurious brands, and another filter was written to see and filter out cars that are not ultra luxurious but ultra pricey.
#
# I am plannig to working on using str.split and isin method, which will look nicer. I don't know if it is really necessary.
#
# </div>

# %%
#LEVEL 1
df=df.drop(columns=["offerType","postalCode","nrOfPictures","dateCreated","lastSeen"])






#df=df.drop(df[(df.brand =='SONSTIGE_AUTOS') & (df.model.isna() == True)].index)







df=df.drop(df[df.price==0].index)
df=df.drop(df[df.price==1].index)
df=df.drop(df[df.price<=100].index)
df=df.drop(df[df.price==2147483647].index)
search1=df[(df.brand.isin(["PORSCHE","FERRARI","MASERATI"])==False) &  (df.name.str.contains("FERRARI")==False)
          & (df.name.str.contains("MASERATI")==False) & (df.name.str.contains("PORSCHE")==False)
          & (df.price>=2000000)]
search1#### DİKKAT!!!
df=df.drop(search1.index)

search2=df[(df.brand.isin(["PORSCHE","FERRARI","MASERATI"])==False) &  (df.name.str.contains("FERRARI")==False)
          & (df.name.str.contains("MASERATI")==False) & (df.name.str.contains("PORSCHE")==False)
          & (df.name.str.contains("LAMBORGHINI")==False) & (df.name.str.contains("ASTON MARTIN")==False)
          & (df.name.str.contains("MUSEUM")==False) & (df.name.str.contains("JAGUAR")==False)
          & (df.name.str.contains("ROLLS ROYCE")==False)  & (df.name.str.contains("AMG")==False)
          &(df.name.str.contains("DETOMASO")==False) &(df.name.str.contains("BMW Z8")==False)
          &(df.name.str.contains("MCLAREN")==False)
          & (df.price>=200000) & (df.yearOfRegistration > 1980)]
search2 #### DİKKAT!!!
df=df.drop(search2.index)
search3=df[(df.brand.isin(["PORSCHE","FERRARI","MASERATI"])==False) &  (df.name.str.contains("FERRARI")==False)
          & (df.name.str.contains("MASERATI")==False) & (df.name.str.contains("PORSCHE")==False)
          & (df.name.str.contains("LAMBORGHINI")==False) & (df.name.str.contains("ASTON MARTIN")==False)
          & (df.name.str.contains("MUSEUM")==False) & (df.name.str.contains("JAGUAR")==False)
          & (df.name.str.contains("ROLLS ROYCE")==False)  & (df.name.str.contains("AMG")==False)
          &(df.name.str.contains("DETOMASO")==False) &(df.name.str.contains("BMW Z8")==False)
          &(df.name.str.contains("MCLAREN")==False)
          & (df.price>=100000) & (df.yearOfRegistration > 1980)]
search3#### DİKKAT!!!
df=df.drop(search3.index)

# %%
brands=df.brand.unique()
brands=pd.DataFrame(brands)
liste=list(brands[0].str.upper())

# %%
new_col = namecol_list(df.name.str.split(" "),liste)                              
#len(new_col)-df.name[df.name.isnull()==False].count()
#liste.append("BMW")
#new_col

# %% [markdown]
# <div class="span4 alert alert-success">
#
# AFTER DECIDING THE NUMBER OF DATAPOINTS TRUNCATED WERE TOO MUCH, I CREATED AN AUGMENTED DICTIONARY OF BRANDS AND MODELS TO RETREIVE DATA FROM THE NAME COLUMN
#
# </div>

# %%
df[df.brand=='SONSTIGE_AUTOS']
liste1=(["OLDSMOBILE", "DODGE", "LEXUS", "MG", "BUICK", "BENTLEY" , "TRIUMPH", "LINCOLN", "PROTON", "HUMMER",
         "CADILLAC", "LOTUS", 'FERRARI','MASERATI','GMC','PONTIAC','IVECO','ISUZU'])
#liste.remove(["OLDMOBILE", "DODGE", "LEXUS", "MG", "BUICK", "BENTLEY" , "TRIUMPH", "LINCOLN", "PROTON", "HUMMER"])
liste.extend(liste1)

# %%
extendedDict={
'OLDSMOBILE': ['ACHIEVA', 'ALERO', 'AURORA', 'CIERA', 'CUTLASS', 'CUTLASS SUPREME', 'DELTA EIGHTY-EIGHT',  'INTRIGUE', 'LSS', 'NINETY-EIGHT', 'REGENCY', 'SILHOUETTE', 'BRAVADA'],
'DODGE': ['CHALLENGER', 'DURANGO', 'CHARGER', 'GRAND CARAVAN', 'JOURNEY', 'CARAVAN', 'AVENGER', 'CALIBER', 'DAKOTA', 'DART', 'NITRO', 'RAM', 'SPRINTER'],
'LEXUS': ['ES', 'GS', 'GX', 'IS', 'LC', 'LS', 'LX', 'NX', 'RC', 'RX', 'UX', 'HS', 'LFA', 'SC'],
'MG':['3', 'ZS', '6', 'GS'],
'BUICK': ['CASCADA', 'ENCLAVE', 'ENCORE', 'ENVISION', 'LACROSSE', 'REGAL', 'LUCERNE', 'RAINIER', 'RENDEZVOUS', 'TERRAZA', 'VERANO'],
'BENTLEY':['CONTINENTAL', 'FLYING', 'MULSANNE', 'ARNAGE', 'AZURE', 'BROOKLANDS'],
'TRIUMPH': ['SUPER', 'ROADSTER', 'DOLOMITE'],
'LINCOLN': ['CONTINENTAL', 'MKC', 'MKT', 'MKX','MKZ', 'NAUTILUS', 'NAVIGATOR', 'MARK LT', 'MKS', 'TOWN CAR'],
'PROTON':['PERDANA', 'SAGA', 'SATRIA'],
'HUMMER': ['H1', 'H2', 'H3', 'H3T'],
'CADILLAC' : ['ATS',  'CT6', 'CTS' ,'ESCALADE' ,'XT5', 'XTS' ,'DTS' ,'SRX' ,'ELR' ,'STS' ,'XLR', 'XT4'],
'LOTUS': ['ELISE', 'ESPRIT', 'EXIGE'],
'FERRARI': ['MODENA', '360', '430', '456', '458', '458','550','575','599', '488', '612', 'CALIFORNIA', 'ENZO', 'F355','F430','FF','LAFERRARI','SUPERAMERICA', '812', 'PORTOFINO'],
'MASERATI': ['GHIBLI', 'GRANTURISMO', 'LEVANTE', 'QUATTROPORTE', 'GRANSPORT', 'SPYDER'],
'GMC': ['ACADIA', 'CANYON', 'SAVANA', 'SIERRA ', 'TERRAIN', 'YUKON', 'ENVOY'],
'PONTIAC': ['G3', 'SUNFIRE', 'VIBE', 'BONNEVILLE', 'G6', 'G8', 'GRAND AM', 'GRAND PRIX' ,'MONTANA', 'TRANSPORT', 'FIREBIRD', 'G5', 'GTO', 'SOLSTICE', 'AZTEK', 'TORRENT'],
'IVECO': ['DAILY', 'EUROCARGO', 'TRAKKER', 'STRALIS', 'STRALIS X-WAY', 'POWERSTAR', 'STRATOR', 'TECTOR'],
'ISUZU': ['OASIS','AMIGO', 'ASCENDER', 'AXIOM', 'HOMBRE''I-280','I-290','I-350','I-370', 'RODEO','TROOPER','VEHICROSS']}

# %% [markdown]
# CODE BELOW FILLS BRAND VALUE BY LOOKING AT NAME COLUMN IF BRAND IS "SONSTIGE AUTOS"

# %%
def other_brands_look(row,list_name):
    mdlist=[]
    
    if row.brand == "SONSTIGE_AUTOS":
    
        for brnd in list_name:
        
            if brnd in list(row["name"].split(" ")):
                
                return brnd

# %%
df["others"]=df.apply (lambda row: other_brands_look(row,liste),axis=1) 
df[(df.brand=='SONSTIGE_AUTOS')& (df.others.notnull()==True)]
df.others.fillna(value=df.brand, inplace=True)
df=df.drop(df[df.others=='SONSTIGE_AUTOS'].index)
df=df.drop(columns="brand")
df.rename(columns={"others":"brand"}, inplace=True)

# %%
grand_opt={'CHRYSLER':"GRAND VOYAGER", 'SUZUKI':"GRAND VITARA",'JEEP': "GRAND CHEROKEE"}
def lookupCode(code):
    return grand_opt.get(code)
df.model=df.model.str.upper()
df.brand=df.brand.str.upper()
df.name=df.name.str.upper()
#df.model[df1.model=="Grand"] = 
df.model[df.model=="GRAND"] = df.brand[df.model=="GRAND"].map(lookupCode)
#dftrim1.model[dftrim1.model=="GRAND"] = dftrim1.brand[df.model=="GRAND"].map(lookupCode)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
models=df.model.unique()
models=pd.DataFrame(models)
models.sort_values(by=0)

#models=list(models[0])
models=models[0].str.upper()
#print(liste)
models=list(models.dropna())
models
# Out:
# ['GOLF',
#  'GRAND CHEROKEE',
#  'FABIA',
#  '3ER',
#  '2_REIHE',
#  'C_MAX',
#  '3_REIHE',
#  'PASSAT',
#  'NAVARA',
#  'KA',
#  'POLO',
#  'TWINGO',
#  'A_KLASSE',
#  'SCIROCCO',
#  '5ER',
#  'MERIVA',
#  'AROSA',
#  'ANDERE',
#  'C4',
#  'CIVIC',
#  'TRANSPORTER',
#  'PUNTO',
#  'E_KLASSE',
#  'CLIO',
#  'KADETT',
#  'KANGOO',
#  'ONE',
#  'FORTWO',
#  '1ER',
#  'B_KLASSE',
#  'SIGNUM',
#  'ASTRA',
#  'A8',
#  'JETTA',
#  'FIESTA',
#  'C_KLASSE',
#  'MICRA',
#  'VITO',
#  'SPRINTER',
#  '156',
#  'ESCORT',
#  'FORESTER',
#  'XC_REIHE',
#  'SCENIC',
#  'A4',
#  'A1',
#  'INSIGNIA',
#  'COMBO',
#  'FOCUS',
#  'TT',
#  'CORSA',
#  'A6',
#  'JAZZ',
#  'OMEGA',
#  'SLK',
#  '7ER',
#  '80',
#  '147',
#  'GLK',
#  '100',
#  'Z_REIHE',
#  'SPORTAGE',
#  'SORENTO',
#  'V40',
#  'IBIZA',
#  'MUSTANG',
#  'EOS',
#  'TOURAN',
#  'GETZ',
#  'A3',
#  'ALMERA',
#  'MEGANE',
#  'LUPO',
#  'R19',
#  'ZAFIRA',
#  'CADDY',
#  'MONDEO',
#  'CORDOBA',
#  'COLT',
#  'IMPREZA',
#  'VECTRA',
#  'BERLINGO',
#  'M_KLASSE',
#  'TIGUAN',
#  'I_REIHE',
#  'ESPACE',
#  'SHARAN',
#  '6_REIHE',
#  'PANDA',
#  'UP',
#  'SEICENTO',
#  'CEED',
#  '5_REIHE',
#  'YETI',
#  'OCTAVIA',
#  'MII',
#  'RX_REIHE',
#  '6ER',
#  'MODUS',
#  'FOX',
#  'MATIZ',
#  'BEETLE',
#  'C1',
#  'RIO',
#  'TOUAREG',
#  'LOGAN',
#  'SPIDER',
#  'CUORE',
#  'S_MAX',
#  'A2',
#  'X_REIHE',
#  'A5',
#  'GALAXY',
#  'C3',
#  'VIANO',
#  'S_KLASSE',
#  '1_REIHE',
#  'AVENSIS',
#  'SL',
#  'ROOMSTER',
#  'Q5',
#  'KAEFER',
#  'SANTA',
#  'COOPER',
#  'LEON',
#  '4_REIHE',
#  '500',
#  'LAGUNA',
#  'PTCRUISER',
#  'CLK',
#  'PRIMERA',
#  'EXEO',
#  '159',
#  'TRANSIT',
#  'JUKE',
#  'QASHQAI',
#  'CARISMA',
#  'ACCORD',
#  'COROLLA',
#  'GRAND VITARA',
#  'LANOS',
#  'PHAETON',
#  'BOXSTER',
#  'VERSO',
#  'SWIFT',
#  'RAV',
#  'KUGA',
#  'PICANTO',
#  'KALOS',
#  'SUPERB',
#  'STILO',
#  'ALHAMBRA',
#  '911',
#  'M_REIHE',
#  'ROADSTER',
#  'YPSILON',
#  'CAYENNE',
#  'GALANT',
#  'JUSTY',
#  '90',
#  'SIRION',
#  'CROSSFIRE',
#  'AGILA',
#  'DUSTER',
#  'CR_REIHE',
#  'V50',
#  'MX_REIHE',
#  'DISCOVERY',
#  'C_REIHE',
#  'V_KLASSE',
#  'YARIS',
#  'C5',
#  'AYGO',
#  'CC',
#  'CARNIVAL',
#  'FUSION',
#  'BORA',
#  'FORFOUR',
#  'CL',
#  'TIGRA',
#  '300C',
#  'Q3',
#  'SPARK',
#  'V70',
#  'X_TYPE',
#  'DUCATO',
#  'S_TYPE',
#  'X_TRAIL',
#  'TOLEDO',
#  'ALTEA',
#  'GRAND VOYAGER',
#  'VOYAGER',
#  'CALIBRA',
#  'BRAVO',
#  'RANGE_ROVER',
#  'ANTARA',
#  'TUCSON',
#  'Q7',
#  'CITIGO',
#  'JIMNY',
#  'CX_REIHE',
#  'WRANGLER',
#  'LYBRA',
#  'RANGE_ROVER_SPORT',
#  'LANCER',
#  'FREELANDER',
#  'CAPTIVA',
#  'C2',
#  'RANGE_ROVER_EVOQUE',
#  'SANDERO',
#  'NOTE',
#  '900',
#  'DEFENDER',
#  'CHEROKEE',
#  'CLUBMAN',
#  'SAMARA',
#  '601',
#  'LEGACY',
#  'PAJERO',
#  'AURIS',
#  'NIVA',
#  'S60',
#  'NUBIRA',
#  'VIVARO',
#  'G_KLASSE',
#  'LODGY',
#  '850',
#  'SERIE_2',
#  'CHARADE',
#  'CROMA',
#  'OUTLANDER',
#  'GL',
#  'DOBLO',
#  'MUSA',
#  'AMAROK',
#  'MOVE',
#  '9000',
#  'V60',
#  'AVEO',
#  '200',
#  '145',
#  'B_MAX',
#  'DELTA',
#  'TERIOS',
#  'RANGEROVER',
#  'MATERIA',
#  'KALINA',
#  'ELEFANTINO',
#  'I3',
#  'KAPPA',
#  'SERIE_3',
#  'SERIE_1',
#  'DISCOVERY_SPORT']

# %%
def colbrmdl(brands,models):
    out={}
    for mdl in  models:
        
        hits= df.brand[df.model==mdl].unique()
            
        for hit in hits:
            if mdl not in ["MISSING VALUE","ANDERE" ]:
            
            
            
          
                out.setdefault(hit, []).append(mdl) 
        
    return out

# %%
brandsmodels={}
brandsmodels=colbrmdl(brands,models)
brandsmodels


brandsmodels.update(extendedDict)
brandsmodels
# Out:
# {'VOLKSWAGEN': ['GOLF',
#   'PASSAT',
#   'POLO',
#   'SCIROCCO',
#   'TRANSPORTER',
#   'JETTA',
#   'EOS',
#   'TOURAN',
#   'LUPO',
#   'CADDY',
#   'TIGUAN',
#   'SHARAN',
#   'UP',
#   'FOX',
#   'BEETLE',
#   'TOUAREG',
#   'KAEFER',
#   'PHAETON',
#   'CC',
#   'BORA',
#   'AMAROK'],
#  'JEEP': ['GRAND CHEROKEE', 'WRANGLER', 'CHEROKEE'],
#  'SKODA': ['FABIA', 'YETI', 'OCTAVIA', 'ROOMSTER', 'SUPERB', 'CITIGO'],
#  'BMW': ['3ER',
#   '5ER',
#   '1ER',
#   '7ER',
#   'Z_REIHE',
#   '6ER',
#   'X_REIHE',
#   'M_REIHE',
#   'I3'],
#  'PEUGEOT': ['2_REIHE', '3_REIHE', '5_REIHE', '1_REIHE', '4_REIHE'],
#  'FORD': ['C_MAX',
#   'KA',
#   'FIESTA',
#   'ESCORT',
#   'FOCUS',
#   'MUSTANG',
#   'MONDEO',
#   'S_MAX',
#   'GALAXY',
#   'TRANSIT',
#   'KUGA',
#   'FUSION',
#   'B_MAX'],
#  'MAZDA': ['3_REIHE',
#   '6_REIHE',
#   '5_REIHE',
#   'RX_REIHE',
#   '1_REIHE',
#   'MX_REIHE',
#   'CX_REIHE'],
#  'NISSAN': ['NAVARA',
#   'MICRA',
#   'ALMERA',
#   'PRIMERA',
#   'JUKE',
#   'QASHQAI',
#   'X_TRAIL',
#   'NOTE'],
#  'RENAULT': ['TWINGO',
#   'CLIO',
#   'KANGOO',
#   'SCENIC',
#   'MEGANE',
#   'R19',
#   'ESPACE',
#   'MODUS',
#   'LAGUNA'],
#  'MERCEDES_BENZ': ['A_KLASSE',
#   'E_KLASSE',
#   'B_KLASSE',
#   'C_KLASSE',
#   'VITO',
#   'SPRINTER',
#   'SLK',
#   'GLK',
#   'M_KLASSE',
#   'VIANO',
#   'S_KLASSE',
#   'SL',
#   'CLK',
#   'V_KLASSE',
#   'CL',
#   'G_KLASSE',
#   'GL'],
#  'OPEL': ['MERIVA',
#   'KADETT',
#   'SIGNUM',
#   'ASTRA',
#   'INSIGNIA',
#   'COMBO',
#   'CORSA',
#   'OMEGA',
#   'ZAFIRA',
#   'VECTRA',
#   'AGILA',
#   'TIGRA',
#   'CALIBRA',
#   'ANTARA',
#   'VIVARO'],
#  'SEAT': ['AROSA',
#   'IBIZA',
#   'CORDOBA',
#   'MII',
#   'LEON',
#   'EXEO',
#   'ALHAMBRA',
#   'TOLEDO',
#   'ALTEA'],
#  'CITROEN': ['C4', 'BERLINGO', 'C1', 'C3', 'C5', 'C2'],
#  'HONDA': ['CIVIC', 'JAZZ', 'ACCORD', 'CR_REIHE'],
#  'FIAT': ['PUNTO',
#   'PANDA',
#   'SEICENTO',
#   '500',
#   'STILO',
#   'DUCATO',
#   'BRAVO',
#   'CROMA',
#   'DOBLO'],
#  'MINI': ['ONE', 'COOPER', 'CLUBMAN'],
#  'SMART': ['FORTWO', 'ROADSTER', 'FORFOUR'],
#  'AUDI': ['A8',
#   'A4',
#   'A1',
#   'TT',
#   'A6',
#   '80',
#   '100',
#   'A3',
#   'A2',
#   'A5',
#   'Q5',
#   '90',
#   'Q3',
#   'Q7',
#   '200'],
#  'ALFA_ROMEO': ['156', '147', 'SPIDER', '159', '145'],
#  'SUBARU': ['FORESTER', 'IMPREZA', 'JUSTY', 'LEGACY'],
#  'VOLVO': ['XC_REIHE', 'V40', 'V50', 'C_REIHE', 'V70', 'S60', '850', 'V60'],
#  'KIA': ['SPORTAGE', 'SORENTO', 'CEED', 'RIO', 'PICANTO', 'CARNIVAL'],
#  'HYUNDAI': ['GETZ', 'I_REIHE', 'SANTA', 'TUCSON'],
#  'MITSUBISHI': ['COLT', 'CARISMA', 'GALANT', 'LANCER', 'PAJERO', 'OUTLANDER'],
#  'CHEVROLET': ['MATIZ', 'SPARK', 'CAPTIVA', 'AVEO'],
#  'DAEWOO': ['MATIZ', 'LANOS', 'KALOS', 'NUBIRA'],
#  'DACIA': ['LOGAN', 'DUSTER', 'SANDERO', 'LODGY'],
#  'DAIHATSU': ['CUORE', 'SIRION', 'CHARADE', 'MOVE', 'TERIOS', 'MATERIA'],
#  'TOYOTA': ['AVENSIS', 'COROLLA', 'VERSO', 'RAV', 'YARIS', 'AYGO', 'AURIS'],
#  'CHRYSLER': ['PTCRUISER', 'CROSSFIRE', '300C', 'GRAND VOYAGER', 'VOYAGER'],
#  'SUZUKI': ['GRAND VITARA', 'SWIFT', 'JIMNY'],
#  'PORSCHE': ['BOXSTER', '911', 'CAYENNE'],
#  'LANCIA': ['YPSILON', 'LYBRA', 'MUSA', 'DELTA', 'ELEFANTINO', 'KAPPA'],
#  'LAND_ROVER': ['DISCOVERY',
#   'RANGE_ROVER',
#   'RANGE_ROVER_SPORT',
#   'FREELANDER',
#   'RANGE_ROVER_EVOQUE',
#   'DEFENDER',
#   'SERIE_2',
#   'SERIE_3',
#   'SERIE_1',
#   'DISCOVERY_SPORT'],
#  'ROVER': ['DISCOVERY', 'FREELANDER', 'DEFENDER', 'RANGEROVER'],
#  'JAGUAR': ['X_TYPE', 'S_TYPE'],
#  'SAAB': ['900', '9000'],
#  'LADA': ['SAMARA', 'NIVA', 'KALINA'],
#  'TRABANT': ['601'],
#  'OLDSMOBILE': ['ACHIEVA',
#   'ALERO',
#   'AURORA',
#   'CIERA',
#   'CUTLASS',
#   'CUTLASS SUPREME',
#   'DELTA EIGHTY-EIGHT',
#   'INTRIGUE',
#   'LSS',
#   'NINETY-EIGHT',
#   'REGENCY',
#   'SILHOUETTE',
#   'BRAVADA'],
#  'DODGE': ['CHALLENGER',
#   'DURANGO',
#   'CHARGER',
#   'GRAND CARAVAN',
#   'JOURNEY',
#   'CARAVAN',
#   'AVENGER',
#   'CALIBER',
#   'DAKOTA',
#   'DART',
#   'NITRO',
#   'RAM',
#   'SPRINTER'],
#  'LEXUS': ['ES',
#   'GS',
#   'GX',
#   'IS',
#   'LC',
#   'LS',
#   'LX',
#   'NX',
#   'RC',
#   'RX',
#   'UX',
#   'HS',
#   'LFA',
#   'SC'],
#  'MG': ['3', 'ZS', '6', 'GS'],
#  'BUICK': ['CASCADA',
#   'ENCLAVE',
#   'ENCORE',
#   'ENVISION',
#   'LACROSSE',
#   'REGAL',
#   'LUCERNE',
#   'RAINIER',
#   'RENDEZVOUS',
#   'TERRAZA',
#   'VERANO'],
#  'BENTLEY': ['CONTINENTAL',
#   'FLYING',
#   'MULSANNE',
#   'ARNAGE',
#   'AZURE',
#   'BROOKLANDS'],
#  'TRIUMPH': ['SUPER', 'ROADSTER', 'DOLOMITE'],
#  'LINCOLN': ['CONTINENTAL',
#   'MKC',
#   'MKT',
#   'MKX',
#   'MKZ',
#   'NAUTILUS',
#   'NAVIGATOR',
#   'MARK LT',
#   'MKS',
#   'TOWN CAR'],
#  'PROTON': ['PERDANA', 'SAGA', 'SATRIA'],
#  'HUMMER': ['H1', 'H2', 'H3', 'H3T'],
#  'CADILLAC': ['ATS',
#   'CT6',
#   'CTS',
#   'ESCALADE',
#   'XT5',
#   'XTS',
#   'DTS',
#   'SRX',
#   'ELR',
#   'STS',
#   'XLR',
#   'XT4'],
#  'LOTUS': ['ELISE', 'ESPRIT', 'EXIGE'],
#  'FERRARI': ['MODENA',
#   '360',
#   '430',
#   '456',
#   '458',
#   '458',
#   '550',
#   '575',
#   '599',
#   '488',
#   '612',
#   'CALIFORNIA',
#   'ENZO',
#   'F355',
#   'F430',
#   'FF',
#   'LAFERRARI',
#   'SUPERAMERICA',
#   '812',
#   'PORTOFINO'],
#  'MASERATI': ['GHIBLI',
#   'GRANTURISMO',
#   'LEVANTE',
#   'QUATTROPORTE',
#   'GRANSPORT',
#   'SPYDER'],
#  'GMC': ['ACADIA', 'CANYON', 'SAVANA', 'SIERRA ', 'TERRAIN', 'YUKON', 'ENVOY'],
#  'PONTIAC': ['G3',
#   'SUNFIRE',
#   'VIBE',
#   'BONNEVILLE',
#   'G6',
#   'G8',
#   'GRAND AM',
#   'GRAND PRIX',
#   'MONTANA',
#   'TRANSPORT',
#   'FIREBIRD',
#   'G5',
#   'GTO',
#   'SOLSTICE',
#   'AZTEK',
#   'TORRENT'],
#  'IVECO': ['DAILY',
#   'EUROCARGO',
#   'TRAKKER',
#   'STRALIS',
#   'STRALIS X-WAY',
#   'POWERSTAR',
#   'STRATOR',
#   'TECTOR'],
#  'ISUZU': ['OASIS',
#   'AMIGO',
#   'ASCENDER',
#   'AXIOM',
#   'HOMBREI-280',
#   'I-290',
#   'I-350',
#   'I-370',
#   'RODEO',
#   'TROOPER',
#   'VEHICROSS']}

# %%
def fill_value(row,lookupDict):
    mdlist=[]
    
    if row.model in ["MISSING VALUE","ANDERE"]:#== "MISSING VALUE" or row.model=="ANDERE":
    
        mdlist=lookupDict.get(row.brand)
   
        for mdl in mdlist:
            
            if mdl in list(row["name"].split(" ")):
                
                return mdl

# %%
df["model"]=df["model"].fillna("MISSING VALUE")
df["sonuc"]=df.apply (lambda row: fill_value(row,brandsmodels),axis=1)
df.sonuc[df.brand=="CADILLAC"].unique()
df.sonuc.fillna(value=df.model, inplace=True)
df=df.drop(columns="model")
df.rename(columns={"sonuc":"model"}, inplace=True)
df=df.drop(df[df.model=='MISSING VALUE'].index)
df=df.drop(df[df.model=='ANDERE'].index)

# %%
df[df.model=='CIVIC'].groupby("vehicleType").count()

##########CHECKPOINT 
##########CHECKPOINT HERE I MAKE A DEEPCOPY OF THE DATAFRAME AND WILL DISCARD NULL VALUES AND COMPARE COPY AND MASTER
##########CHECKPOINT 
##########CHECKPOINT 

df1=df.copy(deep=True)

# %%
df[df.vehicleType.isna()==True]
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 16      2016-04-01 12:46:46
# 22      2016-03-23 14:52:51
# 26      2016-03-10 19:38:18
# 31      2016-03-29 16:57:02
# 35      2016-03-08 07:54:46
# 37      2016-03-28 17:50:15
# 48      2016-03-25 14:40:12
# 51      2016-03-07 18:57:08
# 66      2016-03-28 17:41:27
# 72      2016-03-07 08:55:18
# 78      2016-03-31 22:48:06
# 81      2016-03-17 18:52:56
# 94      2016-03-16 07:56:19
# 96      2016-03-28 16:37:43
# 111     2016-03-16 23:25:21
# 130     2016-03-20 10:54:17
# 134     2016-03-20 18:47:31
# 150     2016-03-06 21:38:00
# 152     2016-03-15 12:50:00
# 160     2016-03-09 12:53:53
# 168     2016-04-04 12:57:02
# 186     2016-03-21 14:43:48
# 202     2016-03-24 13:51:03
# 206     2016-04-03 20:44:13
# 224     2016-03-13 18:47:40
# 226     2016-03-27 18:54:59
# 231     2016-03-23 16:51:03
# 240     2016-03-14 09:54:32
# 268     2016-04-04 09:49:59
# ...                     ...
# 370975  2016-03-11 10:40:31
# 370980  2016-03-20 16:37:55
# 370992  2016-03-21 07:56:03
# 371032  2016-03-08 08:56:13
# 371050  2016-03-05 20:43:30
# 371056  2016-04-04 02:36:35
# 371088  2016-03-21 09:45:25
# 371133  2016-03-15 10:40:56
# 371189  2016-03-24 21:51:05
# 371197  2016-03-11 13:51:18
# 371210  2016-03-17 22:06:35
# 371242  2016-03-07 19:50:51
# 371243  2016-03-17 15:45:46
# 371245  2016-03-12 09:56:23
# 371252  2016-03-09 12:51:50
# 371258  2016-03-11 15:49:51
# 371261  2016-03-07 11:59:24
# 371274  2016-03-13 14:46:13
# 371286  2016-03-29 16:47:29
# 371316  2016-03-29 19:50:03
# 371349  2016-03-10 23:36:19
# 371354  2016-03-17 00:56:26
# 371359  2016-03-26 08:54:05
# 371380  2016-03-14 11:51:40
# 371407  2016-03-25 09:37:59
# 371460  2016-04-03 13:46:24
# 371493  2016-03-05 18:57:45
# 371495  2016-03-31 19:52:33
# 371504  2016-03-07 17:06:35
# 371519  2016-03-09 13:37:43
#
#                                                      name   seller  price  \
# 0                                              GOLF 3 1.6  private    480
# 16                                            POLO 6N 1 4  private    300
# 22                          OPEL MERIVA 1.HAND TÜV 3.2018  private   2900
# 26                              CITROEN C4 GRAND PICASSO.  private   5555
# 31                           RENAULT CLIO 1.2 TÜV 07/2016  private    899
# 35                                              VW GOLF 3  private    350
# 37                              RENAULT KANGOO 1.9 DIESEL  private   1500
# 48               VW GOLF 6   KLIMA   ALU   SCHECKHEFT !!!  private   7750
# 51                            FIAT PUNTO 5 TUERER  6 GANG  private   2000
# 66                   OPEL ASTRA 1.4 MIT VIELEN EXTRAS!!!!  private  10900
# 72                                           BMW 520I E39  private   2300
# 78                              GOLF 4 TDI 1 9.  3 TUERIG  private    800
# 81                                    OPEL ASTRA F CABRIO  private    150
# 94                               FORD KA   TÜV ABGELAUFEN  private    250
# 96      UNFALL OPEL INSIGNIA VOLL AUSSTATTUNG  TÜV NEU...  private   8390
# 111                                       HONDA CIVIC EG4  private    900
# 130                             VW GOLF 6 1.4 COMFORTLINE  private   8000
# 134                           BMW E36 328I COUPE SCHALTER  private   3390
# 150     AUDI 100 C3 TYP 44 BJ 1985 QUATTRO KRAROSSE MI...  private    150
# 152                KRANKENFAHRSTUHL 25 KMH  ZU VERKAUFEN.  private    300
# 160                                          KIA SPORTAGE  private  14500
# 168                                  OPEL ASTRA G TÜV NEU  private   1200
# 186                SKODA FABIAN AUTOMATIK. KOMBI BENZINER  private   3000
# 202       RENAULT TWINGO LAZULI SPORT 1.2 16V TÜV 2 JAHRE  private   2800
# 206                                         NISSAN ALMERA  private   1999
# 224                                           OPEL ZAFIRA  private   2100
# 226                                      CADDY 14D 1.6SDI  private    850
# 231                 TÜV NEU! TOP ANFAENGERAUTO! CORSA 1.4  private    900
# 240                             ICH VERKAUFE EINEN GOLF 5  private   3750
# 268                          MITSUBISHI COLT TUEV 07/2016  private    450
# ...                                                   ...      ...    ...
# 370975                                     RENAULT MEGANE  private    700
# 370980                    OPEL CORSA C CHECKHEFT GEPFLEGT  private   2250
# 370992                           RENAULT MEGANE GRANDTOUR  private   7200
# 371032                             PEUGEOT 306 TÜV 9/2016  private    350
# 371050      TRABANT 600 P60 LIMO SCHEUNENFUND  / KEIN 601  private    800
# 371056                   GOLF TUEV 2/2018 GLASSCHIEBEDACH  private    999
# 371088                                  ASTRA G 1 6  84PS  private   1000
# 371133                                        AUDI A3 1.6  private   1900
# 371189                                         SEAT IBIZA  private    350
# 371197                               KIA PICANTO 1.1 65PS  private   2950
# 371210                                  VW GOLF 5 1.9 TDI  private   3700
# 371242           BMW 316 COMPACT ERSATZTEILE  ODER EXPORT  private    250
# 371243  POLO 1 4 DIESEL / KLIMAAUTOMATIK/SCHECKHEFT GE...  private   4900
# 371245  OPEL VECTRA B CC 2 5L MIT ZYLINDERKOPFDICHTUNG...  private    600
# 371252                     VERKAUFE GOLF 3   1 4 L  60 PS  private    395
# 371258      FORD TRANSIT 280 K TDCI LKW TREND. SCHECKHEFT  private   3600
# 371261    OPEL ASTRA 167500KM GUTER ZUSTAND ZU VERKAUFEN.  private    299
# 371274                           RENAULT TWINGO OHNE TUEV  private    400
# 371286                              AUDI A4  ZU VERKAUFEN  private   1000
# 371316                                    COLT MITSUBISHI  private   3000
# 371349            MERCEDES BENZ CLK 200 KOMPRESSOR 6 GANG  private   1350
# 371354                       FORD FIESTA  2.HAND  TÜV NEU  private   2140
# 371359                                    207 CC PLATINUM  private   8700
# 371380                                   BMW 118I MANUELL  private   9000
# 371407                                       OPEL CORSA C  private   1250
# 371460         POLO G40 AUCH TAUSCH VAG...NO VR6 GTI 1.8T  private   3500
# 371493                                        TOP ZUSTAND  private   3299
# 371495                                         OPEL TIGRA  private    180
# 371504                                       220 CDI BENZ  private   2600
# 371519  ALFA ROMEO 159 JTDM 1.9 150 PS 13 600 KM TOP VOLL  private   5250
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test         NaN                1993    manuell        0
# 16         test         NaN                2016        NaN       60
# 22         test         NaN                2018    manuell       90
# 26      control         NaN                2017    manuell      125
# 31      control         NaN                2016    manuell       60
# 35         test         NaN                2016    manuell       75
# 37         test         NaN                2016        NaN        0
# 48      control         NaN                2017    manuell       80
# 51      control         NaN                2017    manuell       90
# 66         test         NaN                2017    manuell      101
# 72      control         NaN                1997    manuell      150
# 78         test         NaN                2000    manuell       90
# 81      control         NaN                2016    manuell       75
# 94      control         NaN                2000        NaN       60
# 96         test         NaN                2009        NaN        0
# 111        test         NaN                1995    manuell       90
# 130     control         NaN                2009    manuell        0
# 134        test         NaN                2000        NaN        0
# 150     control         NaN                1985        NaN        0
# 152     control         NaN                2005    manuell        0
# 160     control         NaN                2017    manuell      136
# 168     control         NaN                2018    manuell       75
# 186     control         NaN                2016  automatik       75
# 202     control         NaN                2018    manuell       75
# 206        test         NaN                2016    manuell      110
# 224        test         NaN                2017    manuell        0
# 226     control         NaN                1985    manuell       54
# 231        test         NaN                2017    manuell       60
# 240     control         NaN                2005        NaN       75
# 268     control         NaN                2016    manuell        0
# ...         ...         ...                 ...        ...      ...
# 370975     test         NaN                2016    manuell        0
# 370980     test         NaN                2017    manuell       60
# 370992  control         NaN                2010    manuell      131
# 371032     test         NaN                2016    manuell       60
# 371050  control         NaN                1970        NaN        0
# 371056  control         NaN                2018        NaN        0
# 371088  control         NaN                2005        NaN        0
# 371133  control         NaN                2000    manuell      102
# 371189     test         NaN                2000    manuell       50
# 371197     test         NaN                2016    manuell        0
# 371210  control         NaN                2016    manuell       90
# 371242  control         NaN                2016    manuell        0
# 371243     test         NaN                2017    manuell       69
# 371245  control         NaN                2016    manuell      170
# 371252  control         NaN                2016    manuell       60
# 371258     test         NaN                2017    manuell       86
# 371261     test         NaN                2016    manuell       60
# 371274     test         NaN                2000        NaN        0
# 371286  control         NaN                2017    manuell      101
# 371316  control         NaN                2016    manuell        0
# 371349     test         NaN                2016    manuell        0
# 371354     test         NaN                2018    manuell       80
# 371359     test         NaN                2009        NaN        0
# 371380     test         NaN                2008        NaN        0
# 371407     test         NaN                2018        NaN        0
# 371460  control         NaN                1995        NaN        0
# 371493     test         NaN                2005  automatik        0
# 371495  control         NaN                1995        NaN        0
# 371504  control         NaN                2005  automatik        0
# 371519  control         NaN                2016  automatik      150
#
#         kilometer  monthOfRegistration fuelType notRepairedDamage  \
# 0          150000                    0   benzin               NaN
# 16         150000                    0   benzin               NaN
# 22         150000                    5   benzin              nein
# 26         125000                    4      NaN              nein
# 31         150000                    6   benzin               NaN
# 35         150000                    4   benzin              nein
# 37         150000                    1   diesel              nein
# 48         100000                    1   benzin               NaN
# 51         150000                   11   diesel                ja
# 66          50000                    3      NaN              nein
# 72         150000                    3      NaN              nein
# 78         150000                    2   diesel               NaN
# 81         150000                    3   benzin                ja
# 94         150000                    0      NaN               NaN
# 96         150000                    0      NaN               NaN
# 111        150000                    3   benzin               NaN
# 130        100000                   10   benzin              nein
# 134        150000                    2      NaN               NaN
# 150        150000                    4   benzin               NaN
# 152         40000                    9      NaN                ja
# 160        125000                    5   diesel              nein
# 168        150000                    0      NaN              nein
# 186        150000                    0   benzin               NaN
# 202        125000                   12      NaN              nein
# 206        150000                    9   diesel               NaN
# 224        150000                   12   diesel               NaN
# 226        150000                    0   diesel               NaN
# 231        150000                    0   benzin              nein
# 240        150000                    0      NaN               NaN
# 268        150000                    3   benzin              nein
# ...           ...                  ...      ...               ...
# 370975     150000                    7   benzin               NaN
# 370980     150000                    8      NaN              nein
# 370992     100000                    5      NaN              nein
# 371032     150000                   10      NaN              nein
# 371050     150000                    0      NaN               NaN
# 371056     150000                    8      NaN              nein
# 371088     150000                    0      NaN               NaN
# 371133     125000                    7   benzin               NaN
# 371189     150000                    5      NaN              nein
# 371197      80000                    7   benzin              nein
# 371210     150000                    4   diesel               NaN
# 371242     150000                    5   benzin                ja
# 371243     150000                   12   diesel               NaN
# 371245     150000                    0   benzin                ja
# 371252     150000                   12   benzin               NaN
# 371258     150000                    5   diesel               NaN
# 371261     150000                    4   benzin                ja
# 371274     150000                    0      NaN               NaN
# 371286     150000                    9      NaN               NaN
# 371316     150000                    8   diesel              nein
# 371349     150000                    8      NaN                ja
# 371354     150000                    6      NaN              nein
# 371359      90000                    8   benzin               NaN
# 371380     125000                    0      NaN               NaN
# 371407     150000                    0   benzin               NaN
# 371460     150000                    0      NaN               NaN
# 371493     150000                    4   benzin               NaN
# 371495     125000                    3   benzin               NaN
# 371504     150000                    9      NaN               NaN
# 371519     150000                   12      NaN              nein
#
#                 brand      model
# 0          VOLKSWAGEN       GOLF
# 16         VOLKSWAGEN       POLO
# 22               OPEL     MERIVA
# 26            CITROEN         C4
# 31            RENAULT       CLIO
# 35         VOLKSWAGEN       GOLF
# 37            RENAULT     KANGOO
# 48         VOLKSWAGEN       GOLF
# 51               FIAT      PUNTO
# 66               OPEL      ASTRA
# 72                BMW        5ER
# 78         VOLKSWAGEN       GOLF
# 81               OPEL      ASTRA
# 94               FORD         KA
# 96               OPEL   INSIGNIA
# 111             HONDA      CIVIC
# 130        VOLKSWAGEN       GOLF
# 134               BMW        3ER
# 150              AUDI        100
# 152              FIAT      PUNTO
# 160               KIA   SPORTAGE
# 168              OPEL      ASTRA
# 186             SKODA      FABIA
# 202           RENAULT     TWINGO
# 206            NISSAN     ALMERA
# 224              OPEL     ZAFIRA
# 226        VOLKSWAGEN      CADDY
# 231              OPEL      CORSA
# 240        VOLKSWAGEN       GOLF
# 268        MITSUBISHI       COLT
# ...               ...        ...
# 370975        RENAULT     MEGANE
# 370980           OPEL      CORSA
# 370992        RENAULT     MEGANE
# 371032        PEUGEOT    3_REIHE
# 371050        TRABANT        601
# 371056     VOLKSWAGEN       GOLF
# 371088           OPEL      ASTRA
# 371133           AUDI         A3
# 371189           SEAT      IBIZA
# 371197            KIA    PICANTO
# 371210     VOLKSWAGEN       GOLF
# 371242            BMW        3ER
# 371243     VOLKSWAGEN       POLO
# 371245           OPEL     VECTRA
# 371252     VOLKSWAGEN       GOLF
# 371258           FORD    TRANSIT
# 371261           OPEL      ASTRA
# 371274        RENAULT     TWINGO
# 371286           AUDI         A4
# 371316     MITSUBISHI       COLT
# 371349  MERCEDES_BENZ        CLK
# 371354           FORD     FIESTA
# 371359        PEUGEOT    2_REIHE
# 371380            BMW        1ER
# 371407           OPEL      CORSA
# 371460     VOLKSWAGEN       POLO
# 371493     MITSUBISHI  OUTLANDER
# 371495           OPEL      TIGRA
# 371504  MERCEDES_BENZ   C_KLASSE
# 371519     ALFA_ROMEO        159
#
# [28144 rows x 15 columns]

# %%
df1['dateCrawled']=pd.to_datetime(df1.dateCrawled)
#df["age"]=np.round(((pd.datetime.today()-df.yearOfRegistration.iloc[1]).days-df.monthOfRegistration*30)/365 ,2)

# %%
df1=df1.drop(df1[df1.yearOfRegistration<1950].index)
df1=df1.drop( df1[(df1.yearOfRegistration>df1.dateCrawled.max().year)].index)  ## fake dates, a car can not be 2018 model in 2016
df1=df1.drop(df1[(df1.yearOfRegistration==df1.dateCrawled.max().year) & (df1.monthOfRegistration>df1.dateCrawled.max().month)].index)
df1=df1.dropna()
df1[df1.price>1000*1000]
df1=df1.drop(df1[df1.price==df1.price.max()].index)
df1[df1.powerPS>801].sort_values(by='price',ascending=False)
df1=df1.drop(df1[df1.powerPS>801].index)
df1=df1.drop(df1[df1.fuelType=='elektro'][df1.powerPS>000][df1.model!="FORTWO"][df1.model!="I3"][df1.powerPS>000].index)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
df1=df1.drop(df1[df1.powerPS<1].index)
df1=df1.drop(df1[df1.powerPS<10].index)
df1=df1.drop(df1[(df1.powerPS<30)&(df1.yearOfRegistration>1980)&(df1.brand!="TRABANT")].index)
df1=df1.drop(df1[df1.fuelType=='andere'].index)
df1.monthOfRegistration.max()
df1=df1.drop(df1[df1.price<200].index)

# %%
df1[df1.price==500].sort_values(by="yearOfRegistration", ascending=False)
#df1=df1.drop(df1[df1.price<200].index)
# Out:
#                dateCrawled                                               name  \
# 73012  2016-03-13 13:22:25                                            FORD KA
# 178792 2016-03-23 12:52:19               FORD FUSION 1 4 L 80 PS TOTALSCHADEN
# 327733 2016-03-26 23:32:33  OPEOE CORSA 1 0 EDITION 2000 NICHT FAHRBEREIT ...
# 240945 2016-03-27 13:27:17  OPEL CORSA 1 0 EDITION 2000 NICHT FAHRBEREIT A...
# 232597 2016-04-05 19:25:34  OPEL CORSA  ED.2000. VIELE NEUTEUILE / NICHT F...
# 187592 2016-03-31 08:56:06                  VERKAUFE BESCHAEDIGTEN CITROEN C4
# 16446  2016-03-13 01:54:20               FORD FOCUS TURNIER 1.6 TDCI DPF GHIA
# 74716  2016-03-16 18:06:42                         FORD KA . EVTL BASTLERAUTO
# 47459  2016-04-01 09:54:46          FORD KA ZUM AUFBEREITEN ODER TEILESPENDER
# 292473 2016-03-07 12:51:17           FORD FIESTA KLIMA 12/16 TÜV FRONTSCHADEN
# 195116 2016-04-03 02:01:24                                   PEUGEOT 206 2007
# 188719 2016-03-11 12:55:37                   CITROEN C1 BJ2006  UNFALLSCHADEN
# 216715 2016-03-29 18:49:38                             PANDA MIT MOTORSCHADEN
# 279577 2016-04-01 23:36:40                              RENAULT MODUS 1.6 16V
# 140924 2016-03-07 03:38:25                                         TWINGO 16V
# 205585 2016-03-19 16:49:33                                  FIAT PUNTO 1.2 8V
# 224936 2016-03-09 12:36:59                                   LANCIA Y 1.2 16V
# 303226 2016-03-17 21:56:44                           CITROEN C3   UNFALLAUTO!
# 143519 2016-03-11 17:56:04                                PEUGEOT 206 500€ FP
# 82299  2016-03-05 19:55:46                         GAR NICHT MAL SO SCHOEN...
# 271275 2016-03-31 14:53:53  FIAT DUCATO   ERDGAS+BENZIN  MOTOR SCHADEN ABE...
# 214352 2016-03-19 13:49:30  FIAT STILO MULTI WAGON 1 6 16V DYNAMIC MIT UNF...
# 66881  2016-03-19 13:37:54              FORD KA  BJ 2006   BASTLERFAHRZEUG!!!
# 217178 2016-03-14 16:59:05         KIA CARNIVAL CRDI LX   ZUM TEILE VERKAUFEN
# 27976  2016-03-19 16:39:56                                  FIAT PUNTO 1.2 8V
# 307569 2016-03-20 10:51:37  PEUGEOT 206 !MOTOR TOP! SCHECKHEFTGEPFLEGT  / ...
# 154729 2016-03-14 11:49:45  FIAT STILO MULTI WAGON 1 6 16V DYNAMIC MIT UNF...
# 245605 2016-03-25 15:49:14        RENAULT MODUS WIRTSCHAFTLICHER TOTALSCHADEN
# 176150 2016-03-21 19:54:48                                AUTO  TÜV 11. 2016
# 15450  2016-03-06 10:06:24              FORD MONDEO 2.0 TURNIER TDCI AMBIENTE
# ...                    ...                                                ...
# 320137 2016-03-05 20:55:43                                      AUDI 80 1.8 S
# 130165 2016-04-02 04:02:59     OPEL OMEGA AUT. CD DIAMANT  TÜV NEU  WENIGE KM
# 358830 2016-03-14 19:39:03                                 VOLKSWAGEN GOLF CL
# 70250  2016-03-14 19:48:29                                       AUTO VERKAUF
# 287128 2016-03-27 23:51:07            HONDA CIVIC AUTOMATIC  94 PS  87.000 KM
# 200307 2016-04-04 02:36:44                                   AUDI 80 TÜV 2017
# 163093 2016-03-28 00:59:02  E30 316I MIT MOTORSCHADEN ZUM WIEDERAUFBAU... ...
# 321414 2016-03-23 17:54:45                                        OPEL VECTRA
# 230465 2016-03-20 10:51:58                                       AUTO VERKAUF
# 185850 2016-03-23 14:52:21                                           BMW 316I
# 310836 2016-03-17 17:57:46        RENAULT LAGUNA I PHASE 2  GRANDOUR  1 9 DTI
# 262807 2016-03-11 17:57:14                     OPEL ASTRA CARAVAN TÜV 06/2017
# 36641  2016-03-29 11:38:58                                          BMW 524TD
# 170436 2016-03-09 21:49:21                     AUDI 100 2.3 E BASTLERFAHRZEUG
# 24755  2016-03-31 09:56:05     VW PASSAT 35I  LIMOSINE   1988    FUER BASTLER
# 130862 2016-03-19 16:46:35                         AUDI 80 1.8 S UNFALLWAGEN!
# 26589  2016-03-15 15:44:29                              FIAT PANDA 4X4 SISLEY
# 139958 2016-03-14 23:36:24                                  VOLKSWAGEN GOLF 2
# 369444 2016-03-05 15:39:14                                 VOLKSWAGEN GOLF CL
# 208260 2016-03-21 12:55:14  AUDI 90 2.3E 5 ZYLINDER TECHNISCH UEBERHOLT  W...
# 14685  2016-03-27 15:39:09                    KADETT E 1 3N LS WENIG GELAUFEN
# 147119 2016-03-09 15:37:16                  RESTAURATIONSOBJEKT TRABANT 601 S
# 205755 2016-03-25 16:36:47                                E30 320I KAROSSERIE
# 251616 2016-03-25 20:51:20                                        TRABANT 601
# 100449 2016-03-29 12:51:39           BMW 524 TD KAROSSERIE OHNE MOTOR  TUEREN
# 161868 2016-04-03 21:49:18                 GOLF  2   ROST  FREI    KAROSSERIE
# 190089 2016-03-21 12:49:42                                    OLDTIMER GOLF 2
# 147839 2016-03-15 14:41:40                                VOLKSWAGEN JETTA CL
# 46663  2016-03-12 14:56:37                                    VOLKSWAGEN POLO
# 215045 2016-03-14 08:55:48                       TRABANT 601 CABRIO OSTERMANM
#
#          seller  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 73012   private    500     test  kleinwagen                2016    manuell
# 178792  private    500  control   limousine                2012    manuell
# 327733  private    500  control  kleinwagen                2010    manuell
# 240945  private    500  control  kleinwagen                2010    manuell
# 232597  private    500  control  kleinwagen                2010    manuell
# 187592  private    500  control       coupe                2008    manuell
# 16446   private    500  control       kombi                2007    manuell
# 74716   private    500  control  kleinwagen                2007    manuell
# 47459   private    500     test  kleinwagen                2007    manuell
# 292473  private    500  control  kleinwagen                2007    manuell
# 195116  private    500  control  kleinwagen                2007    manuell
# 188719  private    500     test  kleinwagen                2006    manuell
# 216715  private    500  control  kleinwagen                2006    manuell
# 279577  private    500  control         bus                2006    manuell
# 140924  private    500     test  kleinwagen                2006    manuell
# 205585  private    500     test  kleinwagen                2006    manuell
# 224936  private    500  control  kleinwagen                2006    manuell
# 303226  private    500     test   limousine                2006    manuell
# 143519  private    500  control   limousine                2006    manuell
# 82299   private    500     test  kleinwagen                2005    manuell
# 271275  private    500  control         bus                2005    manuell
# 214352  private    500     test       kombi                2005    manuell
# 66881   private    500     test  kleinwagen                2005    manuell
# 217178  private    500     test         bus                2005    manuell
# 27976   private    500     test  kleinwagen                2005    manuell
# 307569  private    500  control  kleinwagen                2005    manuell
# 154729  private    500     test       kombi                2005    manuell
# 245605  private    500     test       kombi                2005    manuell
# 176150  private    500     test  kleinwagen                2005    manuell
# 15450   private    500  control       kombi                2005    manuell
# ...         ...    ...      ...         ...                 ...        ...
# 320137  private    500  control   limousine                1989    manuell
# 130165  private    500     test   limousine                1989  automatik
# 358830  private    500  control   limousine                1989    manuell
# 70250   private    500  control  kleinwagen                1989    manuell
# 287128  private    500     test  kleinwagen                1989  automatik
# 200307  private    500  control   limousine                1989    manuell
# 163093  private    500  control       coupe                1989    manuell
# 321414  private    500  control   limousine                1989    manuell
# 230465  private    500  control  kleinwagen                1989    manuell
# 185850  private    500     test   limousine                1989    manuell
# 310836  private    500  control       kombi                1988    manuell
# 262807  private    500  control       kombi                1988    manuell
# 36641   private    500     test   limousine                1988    manuell
# 170436  private    500     test   limousine                1988    manuell
# 24755   private    500  control   limousine                1988    manuell
# 130862  private    500     test   limousine                1988    manuell
# 26589   private    500  control  kleinwagen                1988    manuell
# 139958  private    500  control   limousine                1987    manuell
# 369444  private    500  control   limousine                1987    manuell
# 208260  private    500  control   limousine                1987    manuell
# 14685   private    500  control   limousine                1987    manuell
# 147119  private    500  control   limousine                1987    manuell
# 205755  private    500  control   limousine                1986    manuell
# 251616  private    500  control   limousine                1986    manuell
# 100449  private    500     test   limousine                1985    manuell
# 161868  private    500     test  kleinwagen                1985    manuell
# 190089  private    500  control  kleinwagen                1985  automatik
# 147839  private    500  control   limousine                1984    manuell
# 46663   private    500     test  kleinwagen                1983    manuell
# 215045  private    500     test      cabrio                1980    manuell
#
#         powerPS  kilometer  monthOfRegistration fuelType notRepairedDamage  \
# 73012        60      90000                    2   benzin                ja
# 178792       80      40000                    4   benzin                ja
# 327733       54     150000                    6   benzin              nein
# 240945       54     150000                    6   benzin              nein
# 232597       54     150000                    6   benzin                ja
# 187592      119     125000                    6   benzin                ja
# 16446       109     150000                    4   diesel                ja
# 74716        70      70000                    5   benzin              nein
# 47459        60     100000                    0   benzin                ja
# 292473       70     150000                    2   benzin                ja
# 195116       75     150000                    5   benzin              nein
# 188719       54     150000                   10   diesel                ja
# 216715       60      90000                    3   benzin                ja
# 279577       88     150000                    5   benzin                ja
# 140924       75     150000                    6   benzin                ja
# 205585       60     150000                    2   benzin                ja
# 224936       60     125000                    7   benzin              nein
# 303226      109     150000                   12   diesel                ja
# 143519       75     150000                    7   benzin                ja
# 82299        65     150000                    6   benzin                ja
# 271275      100     100000                   10   hybrid                ja
# 214352      103     150000                    6   benzin                ja
# 66881        70     125000                    0   benzin                ja
# 217178      144     150000                    1   diesel                ja
# 27976        60     150000                    3   benzin                ja
# 307569       60     125000                    8   benzin                ja
# 154729      103     150000                    6   benzin                ja
# 245605       75     150000                    9   benzin                ja
# 176150       54     150000                    1   benzin              nein
# 15450       116     150000                    9   diesel                ja
# ...         ...        ...                  ...      ...               ...
# 320137       90     150000                    9   benzin              nein
# 130165      116     125000                    4   benzin              nein
# 358830       54     150000                    3   benzin              nein
# 70250        54     150000                    3   benzin              nein
# 287128       94      90000                   12   benzin              nein
# 200307       90     150000                   10   benzin                ja
# 163093       99     150000                    9   benzin                ja
# 321414      102     150000                    4   benzin              nein
# 230465       69     150000                    9   benzin              nein
# 185850       99     150000                    1   benzin                ja
# 310836       98     150000                    7   diesel              nein
# 262807       75     150000                    2   benzin                ja
# 36641       116     150000                   11   diesel                ja
# 170436      136     150000                    6   benzin                ja
# 24755        90     150000                   11   benzin                ja
# 130862       90     150000                    2   benzin                ja
# 26589        44     150000                    7   benzin                ja
# 139958       54     150000                    6   benzin              nein
# 369444       69     150000                    7   benzin              nein
# 208260      136     150000                    7   benzin              nein
# 14685        60      50000                    5   benzin                ja
# 147119       26      90000                    5   benzin              nein
# 205755      129       5000                    1   benzin              nein
# 251616       35      40000                    5   benzin                ja
# 100449      116     150000                    2   diesel              nein
# 161868      112     150000                    5   benzin                ja
# 190089       75     150000                    3   benzin                ja
# 147839       90     150000                   10   benzin              nein
# 46663        50      70000                    2   benzin              nein
# 215045       26       5000                    3   benzin              nein
#
#              brand     model
# 73012         FORD        KA
# 178792        FORD    FUSION
# 327733        OPEL     CORSA
# 240945        OPEL     CORSA
# 232597        OPEL     CORSA
# 187592     CITROEN        C4
# 16446         FORD     FOCUS
# 74716         FORD        KA
# 47459         FORD        KA
# 292473        FORD    FIESTA
# 195116     PEUGEOT   2_REIHE
# 188719     CITROEN        C1
# 216715        FIAT     PANDA
# 279577     RENAULT     MODUS
# 140924     RENAULT    TWINGO
# 205585        FIAT     PUNTO
# 224936      LANCIA   YPSILON
# 303226     CITROEN        C3
# 143519     PEUGEOT   2_REIHE
# 82299          KIA   PICANTO
# 271275        FIAT    DUCATO
# 214352        FIAT     STILO
# 66881         FORD        KA
# 217178         KIA  CARNIVAL
# 27976         FIAT     PUNTO
# 307569     PEUGEOT   2_REIHE
# 154729        FIAT     STILO
# 245605     RENAULT     MODUS
# 176150   CHEVROLET     MATIZ
# 15450         FORD    MONDEO
# ...            ...       ...
# 320137        AUDI        80
# 130165        OPEL     OMEGA
# 358830  VOLKSWAGEN      GOLF
# 70250   VOLKSWAGEN      GOLF
# 287128       HONDA     CIVIC
# 200307        AUDI        80
# 163093         BMW       3ER
# 321414        OPEL    VECTRA
# 230465  VOLKSWAGEN      GOLF
# 185850         BMW       3ER
# 310836     RENAULT    LAGUNA
# 262807        OPEL     ASTRA
# 36641          BMW       5ER
# 170436        AUDI       100
# 24755   VOLKSWAGEN    PASSAT
# 130862        AUDI        80
# 26589         FIAT     PANDA
# 139958  VOLKSWAGEN      GOLF
# 369444  VOLKSWAGEN      GOLF
# 208260        AUDI        90
# 14685         OPEL    KADETT
# 147119     TRABANT       601
# 205755         BMW       3ER
# 251616     TRABANT       601
# 100449         BMW       5ER
# 161868  VOLKSWAGEN      GOLF
# 190089  VOLKSWAGEN      GOLF
# 147839  VOLKSWAGEN     JETTA
# 46663   VOLKSWAGEN      POLO
# 215045     TRABANT       601
#
# [2812 rows x 15 columns]

# %%
df1=df1.drop(df1[(df1.price<1000)&(df1.yearOfRegistration>2008)].index)
df1=df1.drop(df1[(df1.price<1000)&(df1.yearOfRegistration>2005)].index)
df=df.drop(df.loc[df.price>=1.9*1e6].index)

df1.rename(columns={"notRepairedDamage":"salvaged"}, inplace=True)

# %%
df1.salvaged[df1.salvaged=="nein"] = "no"
df1.salvaged[df1.salvaged=="ja"] = "yes"
df1=df1.drop(df1[(df.yearOfRegistration>1960)&(df1.yearOfRegistration<1969)&(df1.brand=='FIAT')&(df1.powerPS>200)].index)
df1.reset_index(inplace=True)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#df2=df1.copy(deep=True)
#df1.reset_index(inplace=True)
#df1=df1.drop(columns="index")
df1
# Out:
#          index         dateCrawled  \
# 0            1 2016-03-24 10:58:45
# 1            3 2016-03-17 16:54:04
# 2            4 2016-03-31 17:25:20
# 3            5 2016-04-04 17:36:23
# 4            6 2016-04-01 20:48:51
# 5           10 2016-03-26 19:54:18
# 6           11 2016-04-07 10:06:22
# 7           14 2016-03-21 12:57:01
# 8           17 2016-03-20 10:25:19
# 9           18 2016-03-23 15:48:05
# 10          19 2016-04-01 22:55:47
# 11          20 2016-04-01 19:56:48
# 12          21 2016-03-27 11:38:00
# 13          23 2016-03-12 19:43:07
# 14          25 2016-03-18 21:44:09
# 15          27 2016-03-07 12:51:23
# 16          28 2016-03-09 11:56:38
# 17          29 2016-03-08 19:55:19
# 18          30 2016-04-03 15:48:11
# 19          33 2016-03-25 21:48:47
# 20          34 2016-03-17 18:55:12
# 21          43 2016-03-13 15:47:08
# 22          45 2016-03-29 18:57:46
# 23          46 2016-03-15 18:59:02
# 24          47 2016-04-04 00:38:22
# 25          49 2016-04-04 14:06:22
# 26          57 2016-03-22 17:56:12
# 27          59 2016-03-31 08:57:44
# 28          62 2016-03-25 19:44:06
# 29          63 2016-03-30 12:49:54
# ...        ...                 ...
# 231127  371470 2016-03-29 13:53:42
# 231128  371472 2016-03-19 19:44:29
# 231129  371474 2016-03-25 17:48:10
# 231130  371477 2016-03-07 16:50:15
# 231131  371478 2016-03-23 11:36:43
# 231132  371479 2016-03-13 12:51:55
# 231133  371480 2016-03-26 23:25:24
# 231134  371483 2016-03-07 09:54:08
# 231135  371487 2016-03-14 16:52:33
# 231136  371490 2016-03-22 10:37:54
# 231137  371491 2016-03-15 20:25:20
# 231138  371497 2016-03-05 15:54:11
# 231139  371499 2016-03-08 13:52:00
# 231140  371500 2016-03-21 23:40:49
# 231141  371501 2016-03-26 18:36:54
# 231142  371502 2016-04-01 12:59:21
# 231143  371503 2016-04-01 01:55:58
# 231144  371505 2016-04-03 19:56:57
# 231145  371506 2016-03-20 18:47:59
# 231146  371508 2016-04-02 16:43:27
# 231147  371510 2016-03-06 21:11:23
# 231148  371511 2016-03-31 18:50:37
# 231149  371512 2016-03-25 18:48:06
# 231150  371513 2016-03-21 15:36:22
# 231151  371516 2016-04-04 09:57:12
# 231152  371517 2016-03-28 13:48:07
# 231153  371520 2016-03-19 19:53:49
# 231154  371524 2016-03-05 19:56:21
# 231155  371525 2016-03-19 18:57:12
# 231156  371527 2016-03-07 19:39:19
#
#                                                      name   seller  price  \
# 0                                    A5 SPORTBACK 2.7 TDI  private  18300
# 1                                      GOLF 4 1 4  3TÜRER  private   1500
# 2                          SKODA FABIA 1.4 TDI PD CLASSIC  private   3600
# 3       BMW 316I   E36 LIMOUSINE   BASTLERFAHRZEUG  EX...  private    650
# 4                             PEUGEOT 206 CC 110 PLATINUM  private   2200
# 5                                       MAZDA 3 1.6 SPORT  private   2000
# 6           VOLKSWAGEN PASSAT VARIANT 2.0 TDI COMFORTLINE  private   2799
# 7       NISSAN NAVARA 2.5DPF SE4X4 KLIMA SITZHEIZG BLU...  private  17999
# 8                             RENAULT TWINGO 1.2 16V AUT.  private   1750
# 9                        FORD C MAX 2.0 TDCI DPF TITANIUM  private   7550
# 10                      MERCEDES BENZ A 160 CLASSIC KLIMA  private   1850
# 11                      VOLKSWAGEN SCIROCCO 1.4 TSI SPORT  private  10400
# 12      BMW 530I TÜV 7/17 SCHECKHEFTGEPFLEGT SEHR GUTE...  private   3699
# 13                                           STADTFLITZER  private    450
# 14                  BMW 530D TOURING VOLLAUSSTATTUNG NAVI  private   2500
# 15                         HONDA CIVIC 1.4 I VTEC COMFORT  private   6900
# 16                                   VOLKSWAGEN T3 ANDERE  private   1990
# 17                                         FIAT PUNTO 1.2  private    690
# 18              MERCEDES BENZ E 250 D ORIGINAL ZUSTAND !!  private   3300
# 19                                          BMW 325I AUT.  private  18000
# 20              MERCEDES BENZ E 200 CDI AUTOMATIK CLASSIC  private   3500
# 21                     MINI ONE PEPPER SCHECKHEFTGEPFLEGT  private   6990
# 22                                       RENAULT CLIO 1.4  private    590
# 23                                           BMW 120D DPF  private   7999
# 24                                       BMW 528I TOURING  private   2100
# 25                           MERCEDES BENZ B180 AUTOMATIK  private  13500
# 26                             SMART CABRIO TÜV BIS 07/17  private   3000
# 27                        VOLKSWAGEN GOLF 1.6 COMFORTLINE  private   1000
# 28                                AUDI A8 3.0 TDI QUATTRO  private   7499
# 29                                        SKODA FABIA 1.2  private   5500
# ...                                                   ...      ...    ...
# 231127                         VOLKSWAGEN GOLF CABRIO 1.8  private   1300
# 231128                                SEAT IBIZA 1 4  16V  private   5990
# 231129                                BMW 118I SPORT LINE  private  19800
# 231130                        BMW 525D TOURING SPORT AUT.  private  23900
# 231131                            MERCEDES BENZ A 170 CDI  private   1300
# 231132                OPEL VECTRA 1.6 CARAVAN EDITION 100  private   1600
# 231133         SMART  ROADSTER BLACK EDITION*SPORT*CABRIO  private   4499
# 231134  MERCEDES BENZ E 200 CDI DPF BLUEEFFICIENCY 7G ...  private  20500
# 231135  MERCEDES BENZ E 270 CDI ELEGANCE  +VOLLAUSSTAT...  private   3800
# 231136  HONDA ACCORD TOURER 2.0 LIFESTYLE VERHANDLUNGS...  private  13850
# 231137                    VOLKSWAGEN PASSAT 2.0 EXECUTIVE  private   3200
# 231138                             OPEL ASTRA 1.6 CARAVAN  private   4900
# 231139  OPEL CORSA B  ECO SWING  TÜV 1/17 8FACH BEREIF...  private    600
# 231140  VOLKSWAGEN GOLF 1.4 TSI BLUEMOTION TECHNOLOGY ...  private  20400
# 231141                                   CHRYSLER VOYAGER  private   3900
# 231142                                  AUDI A4 AVANT 1.8  private   1600
# 231143                                   SUBARU JUSTY 1.3  private   1700
# 231144                   OPEL ASTRA 1.6 CARAVAN SELECTION  private    800
# 231145  VOLKSWAGEN GOLF 1.9 TDI DPF GOAL RENTNERFZG. 1...  private   5900
# 231146                                     OPEL ASTRA 1.8  private   1400
# 231147  MERCEDES BENZ E KLASSE AVANGARDE 220 CDI GRUNE...  private   6500
# 231148                           AUDI A3 1.8 T ATTRACTION  private   1999
# 231149                 MERCEDES BENZ E 400 CDI AVANTGARDE  private   5000
# 231150                       SEAT LEON 1.9 TDI 4/5 TUEREN  private   4400
# 231151                                VOLKSWAGEN LUPO 1.0  private   1490
# 231152                   VOLKSWAGEN GOLF 2.0 TDI DPF TEAM  private   7900
# 231153                                       TURBO DEFEKT  private   3200
# 231154              SMART SMART LEISTUNGSSTEIGERUNG 100PS  private   1199
# 231155                 VOLKSWAGEN MULTIVAN T4 TDI 7DC UY2  private   9200
# 231156       BMW M135I VOLLAUSGESTATTET NP 52.720    EURO  private  28990
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test       coupe                2011    manuell      190
# 1          test  kleinwagen                2001    manuell       75
# 2          test  kleinwagen                2008    manuell       69
# 3          test   limousine                1995    manuell      102
# 4          test      cabrio                2004    manuell      109
# 5       control   limousine                2004    manuell      105
# 6       control       kombi                2005    manuell      140
# 7       control         suv                2011    manuell      190
# 8       control  kleinwagen                2004  automatik       75
# 9          test         bus                2007    manuell      136
# 10         test         bus                2004    manuell      102
# 11      control       coupe                2009    manuell      160
# 12         test   limousine                2002  automatik      231
# 13         test  kleinwagen                1997    manuell       50
# 14      control       kombi                2002  automatik      193
# 15         test   limousine                2008    manuell       99
# 16         test         bus                1981    manuell       50
# 17         test  kleinwagen                2003    manuell       60
# 18         test   limousine                1995  automatik      113
# 19         test   limousine                2007  automatik      218
# 20      control   limousine                2004  automatik      122
# 21         test   limousine                2007    manuell       95
# 22      control  kleinwagen                1999    manuell       75
# 23      control   limousine                2007    manuell      177
# 24         test       kombi                1998  automatik      193
# 25         test         bus                2012  automatik      109
# 26      control      cabrio                2006  automatik       61
# 27      control   limousine                1998    manuell      101
# 28         test   limousine                2004  automatik      232
# 29      control  kleinwagen                2010    manuell       60
# ...         ...         ...                 ...        ...      ...
# 231127  control      cabrio                1998    manuell       90
# 231128  control  kleinwagen                2009    manuell       86
# 231129     test   limousine                2011    manuell      170
# 231130  control       kombi                2011  automatik      204
# 231131     test  kleinwagen                2001    manuell       95
# 231132     test       kombi                1999    manuell      101
# 231133  control      cabrio                2006  automatik       82
# 231134  control   limousine                2012  automatik      136
# 231135     test   limousine                2002  automatik      177
# 231136  control       kombi                2012    manuell      156
# 231137     test   limousine                2002    manuell      116
# 231138  control       kombi                2008    manuell      116
# 231139  control  kleinwagen                1998    manuell       54
# 231140     test   limousine                2014  automatik      150
# 231141     test         bus                2003  automatik      174
# 231142     test       kombi                1998    manuell      125
# 231143  control  kleinwagen                1999    manuell       68
# 231144     test       kombi                2000    manuell      101
# 231145     test   limousine                2006    manuell      105
# 231146  control   limousine                2001    manuell      125
# 231147     test   limousine                2003  automatik      145
# 231148  control   limousine                1997    manuell      150
# 231149     test   limousine                2003  automatik      260
# 231150  control   limousine                2008    manuell      105
# 231151  control  kleinwagen                1998    manuell       50
# 231152     test   limousine                2010    manuell      140
# 231153  control   limousine                2004    manuell      225
# 231154     test      cabrio                2000  automatik      101
# 231155     test         bus                1996    manuell      102
# 231156  control   limousine                2013    manuell      320
#
#         kilometer  monthOfRegistration fuelType salvaged          brand  \
# 0          125000                    5   diesel      yes           AUDI
# 1          150000                    6   benzin       no     VOLKSWAGEN
# 2           90000                    7   diesel       no          SKODA
# 3          150000                   10   benzin      yes            BMW
# 4          150000                    8   benzin       no        PEUGEOT
# 5          150000                   12   benzin       no          MAZDA
# 6          150000                   12   diesel      yes     VOLKSWAGEN
# 7           70000                    3   diesel       no         NISSAN
# 8          150000                    2   benzin       no        RENAULT
# 9          150000                    6   diesel       no           FORD
# 10         150000                    1   benzin       no  MERCEDES_BENZ
# 11         100000                    4   benzin       no     VOLKSWAGEN
# 12         150000                    7   benzin       no            BMW
# 13         150000                    5   benzin       no           SEAT
# 14         150000                    9   diesel      yes            BMW
# 15          60000                   11   benzin       no          HONDA
# 16           5000                    1   benzin       no     VOLKSWAGEN
# 17         150000                    3   benzin       no           FIAT
# 18         150000                    1   diesel       no  MERCEDES_BENZ
# 19          20000                    5   benzin       no            BMW
# 20         150000                   11   diesel       no  MERCEDES_BENZ
# 21         100000                    8   benzin       no           MINI
# 22         125000                    8   benzin       no        RENAULT
# 23         150000                    8   diesel       no            BMW
# 24         150000                    2   benzin       no            BMW
# 25         150000                    7   diesel       no  MERCEDES_BENZ
# 26          80000                    1   benzin       no          SMART
# 27         150000                   10   benzin       no     VOLKSWAGEN
# 28         150000                    3   diesel      yes           AUDI
# 29          70000                    4   benzin       no          SKODA
# ...           ...                  ...      ...      ...            ...
# 231127     150000                    4   benzin       no     VOLKSWAGEN
# 231128      90000                    6   benzin       no           SEAT
# 231129      80000                   12   benzin       no            BMW
# 231130     150000                    7   diesel       no            BMW
# 231131     150000                   10   diesel       no  MERCEDES_BENZ
# 231132     150000                    5   benzin       no           OPEL
# 231133     125000                    3   benzin       no          SMART
# 231134      60000                    4   diesel       no  MERCEDES_BENZ
# 231135     150000                    5   diesel      yes  MERCEDES_BENZ
# 231136     125000                   10   benzin       no          HONDA
# 231137     150000                    4      lpg       no     VOLKSWAGEN
# 231138     150000                    2   benzin       no           OPEL
# 231139     150000                    1   benzin       no           OPEL
# 231140      30000                    9   benzin       no     VOLKSWAGEN
# 231141     150000                    7   benzin       no       CHRYSLER
# 231142     150000                    2   benzin       no           AUDI
# 231143      70000                   11   benzin       no         SUBARU
# 231144     150000                   11   benzin      yes           OPEL
# 231145     150000                    9   diesel       no     VOLKSWAGEN
# 231146     150000                    2   benzin       no           OPEL
# 231147     150000                    3   diesel       no  MERCEDES_BENZ
# 231148     150000                   12   benzin       no           AUDI
# 231149     150000                   12   diesel      yes  MERCEDES_BENZ
# 231150     150000                    7   diesel       no           SEAT
# 231151     150000                    9   benzin       no     VOLKSWAGEN
# 231152     150000                    7   diesel       no     VOLKSWAGEN
# 231153     150000                    5   benzin      yes           SEAT
# 231154     125000                    3   benzin       no          SMART
# 231155     150000                    3   diesel       no     VOLKSWAGEN
# 231156      50000                    8   benzin       no            BMW
#
#               model
# 0                A5
# 1              GOLF
# 2             FABIA
# 3               3ER
# 4           2_REIHE
# 5           3_REIHE
# 6            PASSAT
# 7            NAVARA
# 8            TWINGO
# 9             C_MAX
# 10         A_KLASSE
# 11         SCIROCCO
# 12              5ER
# 13            AROSA
# 14              5ER
# 15            CIVIC
# 16      TRANSPORTER
# 17            PUNTO
# 18         E_KLASSE
# 19              3ER
# 20         E_KLASSE
# 21              ONE
# 22             CLIO
# 23              1ER
# 24              5ER
# 25         B_KLASSE
# 26           FORTWO
# 27             GOLF
# 28               A8
# 29            FABIA
# ...             ...
# 231127         GOLF
# 231128        IBIZA
# 231129          1ER
# 231130          5ER
# 231131     A_KLASSE
# 231132       VECTRA
# 231133     ROADSTER
# 231134     E_KLASSE
# 231135     E_KLASSE
# 231136       ACCORD
# 231137       PASSAT
# 231138        ASTRA
# 231139        CORSA
# 231140         GOLF
# 231141      VOYAGER
# 231142           A4
# 231143        JUSTY
# 231144        ASTRA
# 231145         GOLF
# 231146        ASTRA
# 231147     E_KLASSE
# 231148           A3
# 231149     E_KLASSE
# 231150         LEON
# 231151         LUPO
# 231152         GOLF
# 231153         LEON
# 231154       FORTWO
# 231155  TRANSPORTER
# 231156      M_REIHE
#
# [231157 rows x 16 columns]

# %%
def calculateAge(row,date):
    
    
    delta_year=date.year-row.yearOfRegistration
    
    delta_month=date.month-row.monthOfRegistration
   
    
                
    return np.round((delta_year-delta_month/12),2)
df1["age"]=df1.apply (lambda row: calculateAge(row,pd.datetime.today()),axis=1)

# %% [markdown]
# **** CAUTION HERE*****
#
#
# <div class="span4 alert alert-success">
# Here the top filtering ends, but are these the results I want?
# I cleaned all fake data, but there are outliers still....Do I want them?
# </div>

# %%
df.shape
df.columns
print(df.info())
print(df['vehicleType'].value_counts(dropna=False))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323590 entries, 0 to 371527
# Data columns (total 15 columns):
# dateCrawled            323590 non-null object
# name                   323590 non-null object
# seller                 323590 non-null object
# price                  323590 non-null int64
# abtest                 323590 non-null object
# vehicleType            295446 non-null object
# yearOfRegistration     323590 non-null int64
# gearbox                310095 non-null object
# powerPS                323590 non-null int64
# kilometer              323590 non-null int64
# monthOfRegistration    323590 non-null int64
# fuelType               299886 non-null object
# notRepairedDamage      266626 non-null object
# brand                  323590 non-null object
# model                  323590 non-null object
# dtypes: int64(5), object(10)
# memory usage: 49.5+ MB
# None
# limousine     86173
# kleinwagen    73156
# kombi         62690
# NaN           28144
# bus           25237
# cabrio        20186
# coupe         14208
# suv           11674
# andere         2122
# Name: vehicleType, dtype: int64

# %%
df1.loc[df1.price==df1.price.max()]
# Out:
#        index         dateCrawled                        name   seller  \
# 12549  20143 2016-03-18 00:55:53  PORSCHE 911R EINER VON 911  private
# 48894  78480 2016-03-10 20:43:12               PORSCHE 991 R  private
#
#          price abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 12549  1250000   test       coupe                2016  manuell      500
# 48894  1250000   test       coupe                2016  manuell      500
#
#        kilometer  monthOfRegistration fuelType salvaged    brand model   age
# 12549       5000                    3   benzin       no  PORSCHE   911  3.08
# 48894       5000                    3   benzin       no  PORSCHE   911  3.08

# %%
plt.hist(df1.price[df1.price<1000], bins=40)
# Out:
# (array([ 642.,  107.,  682.,   56.,  265.,  860.,   88.,  868.,   68.,
#          356.,  793.,   51.,  785.,   42.,  367., 2800.,   68., 1432.,
#           68.,  730., 1882.,   65., 1645.,  101.,  799., 1372.,   57.,
#         1729.,  115.,  878., 1875.,   57., 1633.,   53.,  997., 1447.,
#           41., 1605.,   65., 2771.]),
#  array([200.   , 219.975, 239.95 , 259.925, 279.9  , 299.875, 319.85 ,
#         339.825, 359.8  , 379.775, 399.75 , 419.725, 439.7  , 459.675,
#         479.65 , 499.625, 519.6  , 539.575, 559.55 , 579.525, 599.5  ,
#         619.475, 639.45 , 659.425, 679.4  , 699.375, 719.35 , 739.325,
#         759.3  , 779.275, 799.25 , 819.225, 839.2  , 859.175, 879.15 ,
#         899.125, 919.1  , 939.075, 959.05 , 979.025, 999.   ]),
#  <a list of 40 Patch objects>)

# %%
plt.subplots(figsize=(9, 5))
g=sns.scatterplot(x=df1[(df1.price<=0.01e7)&(df1.age<=60)].age ,y=df1.price[df1.price<=0.01e7],  alpha=0.5,legend='full')
a,b=np.polyfit(df1[df1.price<=0.01e7].age, df1[df1.price<=0.01e7].price, 1)
xx=np.array([0 , 50])
y=a*xx+b
h=sns.lineplot(xx+2, y+17000, color='red')
g.margins(tight=True)
h.margins(tight=True)

# %%
plt.subplots(figsize=(5, 5))
g=sns.lineplot(x=df1[df1.kilometer>=10000].kilometer ,y=df1.price[df1.kilometer>=10000],  alpha=0.5)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.grid(axis='both')
a,b=np.polyfit(df1[df1.price<=0.01e7].kilometer, df1[df1.price<=0.01e7].price, 1)
xx=np.array([10000 , 150000])
y=a*xx+b
h=sns.lineplot(xx, y, color='red')
#g.margins(tight=True)
#h.margins(tight=True)
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.subplots(figsize=(5, 5))
g=sns.lineplot(x=df1[df1.kilometer>=10000].yearOfRegistration ,y=df1.powerPS[df1.kilometer>=10000],  alpha=0.5)
#g.fill_between([1960,1970], 25, 245, facecolor='magenta', alpha = .15, interpolate=True)
#g.set_xticklabels(g.get_xticklabels(), rotation=90)
#g.set_xlabel()
g.grid(axis='both')
a,b=np.polyfit(df1[df1.price<=0.01e7].yearOfRegistration, df1[df1.price<=0.01e7].powerPS, 1)
xx=np.array([1950 , 2016])
y=a*xx+b
h=sns.lineplot(xx, y, color='red')
#g.margins(tight=True)
#h.margins(tight=True)
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df1=df1.drop(df1[(df.yearOfRegistration>1960)&(df1.yearOfRegistration<1969)&(df1.brand=='FIAT')&(df1.powerPS>200)].index)
#d1=df1.drop(df1.loc[df1.powerPS==df1[(df.yearOfRegistration>1960)&(df1.yearOfRegistration<1969)].powerPS.max()].index)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df1[(df.yearOfRegistration>1950)&(df1.yearOfRegistration<1960)&(df1.powerPS>100)]
#df1[(df.yearOfRegistration>1960)&(df1.yearOfRegistration<1969)&(df1.powerPS>300)]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        index         dateCrawled  \
# 24300  39071 2016-03-14 04:53:33
# 56003  89816 2016-03-30 23:55:51
#
#                                                     name   seller   price  \
# 24300  MERCEDES BENZ 190 SL  UHR  RADIO  MATCHING NUM...  private  119900
# 56003       VOLKSWAGEN VW KAEFER ORIGINAL FALTDACH OVALI  private   31900
#
#         abtest vehicleType  yearOfRegistration  gearbox  powerPS  kilometer  \
# 24300  control      cabrio                1957  manuell      105      70000
# 56003  control   limousine                1954  manuell      140      20000
#
#        monthOfRegistration fuelType salvaged          brand   model    age
# 24300                    9   benzin       no  MERCEDES_BENZ      SL  62.58
# 56003                    7   benzin       no     VOLKSWAGEN  KAEFER  65.42

# %%
#sns.scatterplot(data=df1.groupby("fuelType").price.mean())
#df1[df1.fuelType=="elektro"]
plt.clf()


s=df1.pivot_table("price","brand", aggfunc="mean").plot(kind='bar', figsize=(17,5),rot=80)
s.axhline(df1.price.mean(), color="red" ,linestyle="-.",label="MEAN",marker="D")
s.arrow(20,9000,10,50000, color='magenta',head_width=5, label='mean')
s.text(28, 62000, "Mean", horizontalalignment='left', 
       size='large', color='black')
df1.pivot_table("price","fuelType", aggfunc="mean").plot(kind='bar', figsize=(9,5))
df1.pivot_table("price","salvaged", aggfunc="mean").plot(kind='bar', figsize=(5,5))
df1.pivot_table("price","salvaged", aggfunc="count").plot(kind='bar', figsize=(5,5), title="Count", legend=False)
df1.pivot_table("price","gearbox", aggfunc="mean").plot(kind='bar', figsize=(5,5))
dfp=df1.pivot_table("price","salvaged", aggfunc="count")
dfp.rename(columns={"price":"count"}, inplace=True)
dfp.plot(kind='bar', figsize=(5,5))
df1.pivot_table("powerPS","fuelType", aggfunc="mean").plot(kind='bar', figsize=(5,5))



df1.pivot_table("price","gearbox", aggfunc="mean")#.plot(kind='bar', figsize=(5,5))
# Out:
#                   price
# gearbox
# automatik  11538.802795
# manuell     5475.730810

# %%
df1[df1.fuelType=='elektro'][df1.powerPS>000][df1.model!="FORTWO"][df1.model!="I3"][df1.powerPS>000].sort_values(by='powerPS',ascending=False)
#df1=df1.drop(df1[df1.fuelType=='elektro'][df1.powerPS>000][df1.model!="FORTWO"][df1.model!="I3"][df1.powerPS>000].index)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [index, dateCrawled, name, seller, price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, kilometer, monthOfRegistration, fuelType, salvaged, brand, model, age]
# Index: []

# %%
#df=df.drop(df[df.price>9e6].index)
plt.subplots(figsize=(15, 9))
g=sns.barplot(x=df1["brand"], y=df1["price"], data=df1,  alpha=0.5)
g.set_xticklabels(g.get_xticklabels(), rotation=90)
#g.ax_joint.set_yscale('log')
#g.ax_joint.set_xscale('log')
#df=df.drop(df[df.powerPS<30].index)
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# [Text(0,0,'AUDI'),
#  Text(0,0,'VOLKSWAGEN'),
#  Text(0,0,'SKODA'),
#  Text(0,0,'BMW'),
#  Text(0,0,'PEUGEOT'),
#  Text(0,0,'MAZDA'),
#  Text(0,0,'NISSAN'),
#  Text(0,0,'RENAULT'),
#  Text(0,0,'FORD'),
#  Text(0,0,'MERCEDES_BENZ'),
#  Text(0,0,'SEAT'),
#  Text(0,0,'HONDA'),
#  Text(0,0,'FIAT'),
#  Text(0,0,'MINI'),
#  Text(0,0,'SMART'),
#  Text(0,0,'ALFA_ROMEO'),
#  Text(0,0,'SUBARU'),
#  Text(0,0,'OPEL'),
#  Text(0,0,'HYUNDAI'),
#  Text(0,0,'MITSUBISHI'),
#  Text(0,0,'CITROEN'),
#  Text(0,0,'KIA'),
#  Text(0,0,'CHEVROLET'),
#  Text(0,0,'DACIA'),
#  Text(0,0,'DAIHATSU'),
#  Text(0,0,'TOYOTA'),
#  Text(0,0,'DODGE'),
#  Text(0,0,'VOLVO'),
#  Text(0,0,'SUZUKI'),
#  Text(0,0,'PORSCHE'),
#  Text(0,0,'JEEP'),
#  Text(0,0,'LANCIA'),
#  Text(0,0,'DAEWOO'),
#  Text(0,0,'LEXUS'),
#  Text(0,0,'CHRYSLER'),
#  Text(0,0,'LAND_ROVER'),
#  Text(0,0,'JAGUAR'),
#  Text(0,0,'CADILLAC'),
#  Text(0,0,'FERRARI'),
#  Text(0,0,'ROVER'),
#  Text(0,0,'LOTUS'),
#  Text(0,0,'LADA'),
#  Text(0,0,'SAAB'),
#  Text(0,0,'TRABANT'),
#  Text(0,0,'PONTIAC'),
#  Text(0,0,'LINCOLN'),
#  Text(0,0,'MASERATI'),
#  Text(0,0,'IVECO'),
#  Text(0,0,'HUMMER'),
#  Text(0,0,'BENTLEY'),
#  Text(0,0,'TRIUMPH'),
#  Text(0,0,'GMC'),
#  Text(0,0,'MG'),
#  Text(0,0,'OLDSMOBILE'),
#  Text(0,0,'ISUZU'),
#  Text(0,0,'BUICK')]

# %%
np.percentile(df1[df1.brand=='FERRARI'].price, [20,70])
# Out:
# array([ 72900., 116800.])

# %%
g=sns.distplot(df["kilometer"], bins=70)
#g.invert_xaxis()
#g.set_xticklabels(g.get_xticklabels(), rotation=60)
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g=sns.scatterplot(x="yearOfRegistration", y="price", data=df,  alpha=0.5)
g.set_autoscalex_on
g.set_autoscaley_on
g.axvline(x=2016, color="red")
g.fill_between([2016,10000], 0, df.price.max(), facecolor='red', alpha = .15, interpolate=True)
g.text(df.yearOfRegistration.max()/2, df.price.max()/2, "Erroneous Data", horizontalalignment='left', size='medium', color='black', weight='semibold')
# Out:
# Text(4999.5,625000,'Erroneous Data')

# %%
g=sns.scatterplot(x="powerPS", y="price", data=df,  alpha=0.5)
g.set_autoscalex_on
g.set_autoscaley_on
g.axvline(x=600)
g.fill_between([600,20000], 0, df.price.max(), facecolor='red', alpha = .15, interpolate=True)
g.text(df.powerPS.max()/2, df.price.max()/2, "Erroneous Data", horizontalalignment='left', size='medium', color='black', weight='semibold')
# Out:
# Text(10000,625000,'Erroneous Data')

# %%
g=sns.scatterplot(x="powerPS", y="price", data=df1[df1.price<250000],  alpha=0.5)
g.set_autoscalex_on
g.set_autoscaley_on
a,b=np.polyfit(df1[df1.price<400000].powerPS, df1[df1.price<400000].price, 1)
xx=np.array([0 , 800])
y=a*xx+b
h=sns.lineplot(xx, y, color='red')


#g.axvline(x=600)
#g.fill_between([600,20000], 0, df.price.max(), facecolor='red', alpha = .15, interpolate=True)
#g.text(df.age.max()/2, df.price.max()/2, "Erroneous Data", horizontalalignment='left', size='medium', color='black', weight='semibold')

# %%
df1[df1.fuelType=='andere'].count()
# Out:
# index                  0
# dateCrawled            0
# name                   0
# seller                 0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# salvaged               0
# brand                  0
# model                  0
# age                    0
# dtype: int64

# %%
df1.powerPS.max()
# Out:
# 801

# %%
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays."""
    # Compute correlation matrix: corr_mat
    corr_mat=np.corrcoef(x,y)

    # Return entry [0,1]
    return np.round(corr_mat[0,1],5)

# %%
r=pearson_r(df1.age, df1.price)
print("The correlation coefficient between age, price is {}".format(r))
r=pearson_r(df1.powerPS, df1.price)
print("The correlation coefficient between powerPS, price is {}".format(r))
r=pearson_r(df1.kilometer, df1.price)
print("The correlation coefficient between kilometer, price is {}".format(r))
r=pearson_r(df1.yearOfRegistration, df1.price)
print("The correlation coefficient between year, price is {}".format(r))
# Out:
# The correlation coefficient between age, price is -0.38794
# The correlation coefficient between powerPS, price is 0.496
# The correlation coefficient between kilometer, price is -0.37484
# The correlation coefficient between year, price is 0.38862

# %%
r=pearson_r(df1.powerPS, df1.price)

print("The correlation between two values are {}".format(r))
# Out:
# The correlation between two values are 0.5

# %%
sns.heatmap(df1.drop('index',axis=1).corr(), square=True, cmap='RdYlGn')

# %%
df5=df1.head(100)

# %%
df5.drop('index',axis=1)
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-24 10:58:45                               A5 SPORTBACK 2.7 TDI
# 1  2016-03-17 16:54:04                                 GOLF 4 1 4  3TÜRER
# 2  2016-03-31 17:25:20                     SKODA FABIA 1.4 TDI PD CLASSIC
# 3  2016-04-04 17:36:23  BMW 316I   E36 LIMOUSINE   BASTLERFAHRZEUG  EX...
# 4  2016-04-01 20:48:51                        PEUGEOT 206 CC 110 PLATINUM
# 5  2016-03-26 19:54:18                                  MAZDA 3 1.6 SPORT
# 6  2016-04-07 10:06:22      VOLKSWAGEN PASSAT VARIANT 2.0 TDI COMFORTLINE
# 7  2016-03-21 12:57:01  NISSAN NAVARA 2.5DPF SE4X4 KLIMA SITZHEIZG BLU...
# 8  2016-03-20 10:25:19                        RENAULT TWINGO 1.2 16V AUT.
# 9  2016-03-23 15:48:05                   FORD C MAX 2.0 TDCI DPF TITANIUM
# 10 2016-04-01 22:55:47                  MERCEDES BENZ A 160 CLASSIC KLIMA
# 11 2016-04-01 19:56:48                  VOLKSWAGEN SCIROCCO 1.4 TSI SPORT
# 12 2016-03-27 11:38:00  BMW 530I TÜV 7/17 SCHECKHEFTGEPFLEGT SEHR GUTE...
# 13 2016-03-12 19:43:07                                       STADTFLITZER
# 14 2016-03-18 21:44:09              BMW 530D TOURING VOLLAUSSTATTUNG NAVI
# 15 2016-03-07 12:51:23                     HONDA CIVIC 1.4 I VTEC COMFORT
# 16 2016-03-09 11:56:38                               VOLKSWAGEN T3 ANDERE
# 17 2016-03-08 19:55:19                                     FIAT PUNTO 1.2
# 18 2016-04-03 15:48:11          MERCEDES BENZ E 250 D ORIGINAL ZUSTAND !!
# 19 2016-03-25 21:48:47                                      BMW 325I AUT.
# 20 2016-03-17 18:55:12          MERCEDES BENZ E 200 CDI AUTOMATIK CLASSIC
# 21 2016-03-13 15:47:08                 MINI ONE PEPPER SCHECKHEFTGEPFLEGT
# 22 2016-03-29 18:57:46                                   RENAULT CLIO 1.4
# 23 2016-03-15 18:59:02                                       BMW 120D DPF
# 24 2016-04-04 00:38:22                                   BMW 528I TOURING
# 25 2016-04-04 14:06:22                       MERCEDES BENZ B180 AUTOMATIK
# 26 2016-03-22 17:56:12                         SMART CABRIO TÜV BIS 07/17
# 27 2016-03-31 08:57:44                    VOLKSWAGEN GOLF 1.6 COMFORTLINE
# 28 2016-03-25 19:44:06                            AUDI A8 3.0 TDI QUATTRO
# 29 2016-03-30 12:49:54                                    SKODA FABIA 1.2
# ..                 ...                                                ...
# 70 2016-03-28 20:45:46  FABIA II COMBI GREENLINE 1 2 TDI DPF MIT GEBRA...
# 71 2016-04-01 22:55:34                         AUDI CABRIOLET TYP 89 2.0L
# 72 2016-03-21 16:45:30   MERCEDES BENZ C 220 CDI DPF AUTOMATIK AVANTGARDE
# 73 2016-04-02 10:59:28               ALFA ROMEO 147 1.9 JTD 8V M JET  DPF
# 74 2016-03-13 01:57:12                                   BMW 530D TOURING
# 75 2016-03-28 19:06:18  SEHR GEPFLEGTER UNFALLFREIER FORD C MAX STYLE+...
# 76 2016-03-09 09:51:36  RENAULT CLIO TÜV NEU BIS 03 2018 INZAHLUNGNAME...
# 77 2016-03-31 00:59:04  MERCEDES BENZ GLK 250 BLUETEC 4MATIC STANDHZG ...
# 78 2016-04-05 09:55:37                              BMW 330D SCHADOW LINE
# 79 2016-03-27 12:59:00                                  VOLKSWAGEN GOLF 3
# 80 2016-03-09 12:50:41                         PEUGEOT 307 90 GRAND FILOU
# 81 2016-03-22 10:50:53                          MERCEDES C 200 KOMPRESSOR
# 82 2016-03-29 07:56:29         AUDI A6 AVANT 2 5TDI*NAVI*AUTOMATIK*EURO4*
# 83 2016-04-03 18:58:25         BMW Z4 ROADSTER 2.2I M PAKET  KLIMA  XENON
# 84 2016-03-10 16:57:31                   MERCEDES BENZ C 270 CDI ELEGANCE
# 85 2016-03-21 23:51:55            VW GOLF CL  2ER GOLF    TÜV BIS 02/2018
# 86 2016-04-01 22:49:08                          VOLKSWAGEN T5 TRANSPORTER
# 87 2016-03-28 01:36:15                                   HONDA CIVIC 1.4I
# 88 2016-03-14 12:54:41                                 SEAT IBIZA 1.2 12V
# 89 2016-03-19 13:36:22  FORD C MAX 1.6 TDCI TITANIUM  7 SITZER TOPAUSS...
# 90 2016-03-28 13:46:45  BMW 323 CI AUTOMATIK  SITZHEIZUNG  SPORTAUSPUF...
# 91 2016-03-07 12:38:19  FORD MUSTANG GT V8 CABRIO PREMIUM NEUWAGENZUSTAND
# 92 2016-03-16 12:46:39                             VOLKSWAGEN EOS 2.0 FSI
# 93 2016-03-18 12:39:23  FORD FIESTA 1.4 GHIA KLIMA  SCHECKHEFT  TUEV N...
# 94 2016-03-18 06:36:46      MERCEDES BENZ VITO 115 CDI EXTRALANG DPF AUT.
# 95 2016-03-24 15:38:18       OPEL ASTRA J DESIGN EDITION 1.7 CDTI ECOFLEX
# 96 2016-03-21 00:59:18  MERCEDES BENZ E320 CDI /TÜV 05.2017 //VOLLAUST...
# 97 2016-03-08 20:58:31                SKODA FABIA COMBI 1.2 TSI DSG STYLE
# 98 2016-03-28 17:39:50  AUDI A4   1 8 TFSI   XENON   SCHECKHEFT   51 T...
# 99 2016-03-21 19:06:21                 VOLKSWAGEN POLO 1.4 UNITED 1. HAND
#
#      seller  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0   private  18300     test       coupe                2011    manuell
# 1   private   1500     test  kleinwagen                2001    manuell
# 2   private   3600     test  kleinwagen                2008    manuell
# 3   private    650     test   limousine                1995    manuell
# 4   private   2200     test      cabrio                2004    manuell
# 5   private   2000  control   limousine                2004    manuell
# 6   private   2799  control       kombi                2005    manuell
# 7   private  17999  control         suv                2011    manuell
# 8   private   1750  control  kleinwagen                2004  automatik
# 9   private   7550     test         bus                2007    manuell
# 10  private   1850     test         bus                2004    manuell
# 11  private  10400  control       coupe                2009    manuell
# 12  private   3699     test   limousine                2002  automatik
# 13  private    450     test  kleinwagen                1997    manuell
# 14  private   2500  control       kombi                2002  automatik
# 15  private   6900     test   limousine                2008    manuell
# 16  private   1990     test         bus                1981    manuell
# 17  private    690     test  kleinwagen                2003    manuell
# 18  private   3300     test   limousine                1995  automatik
# 19  private  18000     test   limousine                2007  automatik
# 20  private   3500  control   limousine                2004  automatik
# 21  private   6990     test   limousine                2007    manuell
# 22  private    590  control  kleinwagen                1999    manuell
# 23  private   7999  control   limousine                2007    manuell
# 24  private   2100     test       kombi                1998  automatik
# 25  private  13500     test         bus                2012  automatik
# 26  private   3000  control      cabrio                2006  automatik
# 27  private   1000  control   limousine                1998    manuell
# 28  private   7499     test   limousine                2004  automatik
# 29  private   5500  control  kleinwagen                2010    manuell
# ..      ...    ...      ...         ...                 ...        ...
# 70  private   6990  control       kombi                2012    manuell
# 71  private   4800     test      cabrio                1996    manuell
# 72  private  14499  control   limousine                2007  automatik
# 73  private   3450     test   limousine                2007    manuell
# 74  private   3550  control       kombi                2000  automatik
# 75  private   8250     test         bus                2010    manuell
# 76  private    800     test  kleinwagen                1998    manuell
# 77  private  41900  control         suv                2014  automatik
# 78  private   4200  control       kombi                2003  automatik
# 79  private   1000     test  kleinwagen                1996    manuell
# 80  private    800  control   limousine                2004    manuell
# 81  private   2300  control   limousine                2000    manuell
# 82  private   4000     test       kombi                2003  automatik
# 83  private   9450  control      cabrio                2004    manuell
# 84  private   6890  control   limousine                2003    manuell
# 85  private    850     test   limousine                1989    manuell
# 86  private   8500     test         bus                2007    manuell
# 87  private   1500     test   limousine                2000    manuell
# 88  private   3200     test  kleinwagen                2004    manuell
# 89  private  11890     test         bus                2011    manuell
# 90  private   2900     test       coupe                2000  automatik
# 91  private  19750     test      cabrio                2006    manuell
# 92  private   9800     test      cabrio                2006    manuell
# 93  private   1990  control  kleinwagen                2003    manuell
# 94  private  10500  control         bus                2006  automatik
# 95  private  11000     test   limousine                2012    manuell
# 96  private   2390     test       kombi                2000  automatik
# 97  private  16449  control       kombi                2015  automatik
# 98  private  14300     test   limousine                2011    manuell
# 99  private   5999     test  kleinwagen                2009    manuell
#
#     powerPS  kilometer  monthOfRegistration fuelType salvaged          brand  \
# 0       190     125000                    5   diesel      yes           AUDI
# 1        75     150000                    6   benzin       no     VOLKSWAGEN
# 2        69      90000                    7   diesel       no          SKODA
# 3       102     150000                   10   benzin      yes            BMW
# 4       109     150000                    8   benzin       no        PEUGEOT
# 5       105     150000                   12   benzin       no          MAZDA
# 6       140     150000                   12   diesel      yes     VOLKSWAGEN
# 7       190      70000                    3   diesel       no         NISSAN
# 8        75     150000                    2   benzin       no        RENAULT
# 9       136     150000                    6   diesel       no           FORD
# 10      102     150000                    1   benzin       no  MERCEDES_BENZ
# 11      160     100000                    4   benzin       no     VOLKSWAGEN
# 12      231     150000                    7   benzin       no            BMW
# 13       50     150000                    5   benzin       no           SEAT
# 14      193     150000                    9   diesel      yes            BMW
# 15       99      60000                   11   benzin       no          HONDA
# 16       50       5000                    1   benzin       no     VOLKSWAGEN
# 17       60     150000                    3   benzin       no           FIAT
# 18      113     150000                    1   diesel       no  MERCEDES_BENZ
# 19      218      20000                    5   benzin       no            BMW
# 20      122     150000                   11   diesel       no  MERCEDES_BENZ
# 21       95     100000                    8   benzin       no           MINI
# 22       75     125000                    8   benzin       no        RENAULT
# 23      177     150000                    8   diesel       no            BMW
# 24      193     150000                    2   benzin       no            BMW
# 25      109     150000                    7   diesel       no  MERCEDES_BENZ
# 26       61      80000                    1   benzin       no          SMART
# 27      101     150000                   10   benzin       no     VOLKSWAGEN
# 28      232     150000                    3   diesel      yes           AUDI
# 29       60      70000                    4   benzin       no          SKODA
# ..      ...        ...                  ...      ...      ...            ...
# 70       75     100000                    5   diesel       no          SKODA
# 71      116     150000                    6   benzin       no           AUDI
# 72      170     125000                    5   diesel       no  MERCEDES_BENZ
# 73      120     150000                    4   diesel       no     ALFA_ROMEO
# 74      184     150000                   11   diesel       no            BMW
# 75      109     125000                   10   diesel       no           FORD
# 76       54     150000                   11   benzin       no        RENAULT
# 77      204      40000                    9   diesel       no  MERCEDES_BENZ
# 78      204     150000                    1   diesel       no            BMW
# 79       75     150000                    3   benzin       no     VOLKSWAGEN
# 80       88     150000                    9   benzin      yes        PEUGEOT
# 81      160     150000                    5   benzin       no  MERCEDES_BENZ
# 82      163     150000                    6   diesel       no           AUDI
# 83      170     150000                   12   benzin       no            BMW
# 84      170     125000                    2   diesel       no  MERCEDES_BENZ
# 85       69     125000                   11   benzin       no     VOLKSWAGEN
# 86      131     150000                   12   diesel       no     VOLKSWAGEN
# 87       75     125000                   11   benzin       no          HONDA
# 88       64      80000                    2   benzin       no           SEAT
# 89      116     150000                    4   diesel       no           FORD
# 90      170     150000                    2   benzin       no            BMW
# 91      305      50000                    7   benzin       no           FORD
# 92      150      60000                   11   benzin       no     VOLKSWAGEN
# 93       80     125000                    4   benzin       no           FORD
# 94      150     150000                    6   diesel       no  MERCEDES_BENZ
# 95      131      70000                    3   diesel       no           OPEL
# 96      197     150000                    5   diesel       no  MERCEDES_BENZ
# 97      110      10000                    8   benzin       no          SKODA
# 98      120      60000                    5   benzin       no           AUDI
# 99       80     125000                    5   benzin       no     VOLKSWAGEN
#
#           model    age
# 0            A5   8.25
# 1          GOLF  18.33
# 2         FABIA  11.42
# 3           3ER  24.67
# 4       2_REIHE  15.50
# 5       3_REIHE  15.83
# 6        PASSAT  14.83
# 7        NAVARA   8.08
# 8        TWINGO  15.00
# 9         C_MAX  12.33
# 10     A_KLASSE  14.92
# 11     SCIROCCO  10.17
# 12          5ER  17.42
# 13        AROSA  22.25
# 14          5ER  17.58
# 15        CIVIC  11.75
# 16  TRANSPORTER  37.92
# 17        PUNTO  16.08
# 18     E_KLASSE  23.92
# 19          3ER  12.25
# 20     E_KLASSE  15.75
# 21          ONE  12.50
# 22         CLIO  20.50
# 23          1ER  12.50
# 24          5ER  21.00
# 25     B_KLASSE   7.42
# 26       FORTWO  12.92
# 27         GOLF  21.67
# 28           A8  15.08
# 29        FABIA   9.17
# ..          ...    ...
# 70        FABIA   7.25
# 71           80  23.33
# 72     C_KLASSE  12.25
# 73          147  12.17
# 74          5ER  19.75
# 75        C_MAX   9.67
# 76         CLIO  21.75
# 77          GLK   5.58
# 78          3ER  15.92
# 79         GOLF  23.08
# 80      3_REIHE  15.58
# 81     C_KLASSE  19.25
# 82           A6  16.33
# 83      Z_REIHE  15.83
# 84     C_KLASSE  16.00
# 85         GOLF  30.75
# 86  TRANSPORTER  12.83
# 87        CIVIC  19.75
# 88        IBIZA  15.00
# 89        C_MAX   8.17
# 90          3ER  19.00
# 91      MUSTANG  13.42
# 92          EOS  13.75
# 93       FIESTA  16.17
# 94         VITO  13.33
# 95        ASTRA   7.08
# 96     E_KLASSE  19.25
# 97        FABIA   4.50
# 98           A4   8.25
# 99         POLO  10.25
#
# [100 rows x 16 columns]

# %%
def diff_of_means(data_1, data_2):
    """Difference in means of two arrays."""

    # The difference of means of data_1, data_2: diff
    diff = np.mean(data_1)-np.mean(data_2)

    return diff

def permutation_sample(data1, data2):
    """Generate a permutation sample from two data sets."""

    # Concatenate the data sets: data
    data = np.concatenate((data1,data2))

    # Permute the concatenated array: permuted_data
    permuted_data = np.random.permutation(data)

    # Split the permuted array into two: perm_sample_1, perm_sample_2
    perm_sample_1 = permuted_data[:len(data1)]
    perm_sample_2 = permuted_data[len(data1):]

    return perm_sample_1, perm_sample_2

def draw_perm_reps(data_1, data_2, func, size=1):
    """Generate multiple permutation replicates."""

    # Initialize array of replicates: perm_replicates
    perm_replicates = np.empty(size)

    for i in range(size):
        # Generate permutation sample
        perm_sample_1, perm_sample_2 = permutation_sample(data_1,data_2)

        # Compute the test statistic
        perm_replicates[i] = func(perm_sample_1,perm_sample_2)

    return perm_replicates

# %%
df_aut=df1[df1.brand=='SKODA']
df_man=df1[df1.brand=='VOLKSWAGEN']
print(df_aut.powerPS.mean())
print(df_man.powerPS.mean())
emp_diff=diff_of_means(df_aut.powerPS, df_man.powerPS)
perm_replicates = draw_perm_reps(df_aut.powerPS, df_man.powerPS, diff_of_means, size=10000)                              
p = np.sum(perm_replicates >= emp_diff) / len(perm_replicates)
print("The p value is {}".format(p))
plt.hist(perm_replicates, bins=50)
plt.axvline(emp_diff, color='red')  #### See the position of the red line and it does not change with
# p = np.sum(perm_replicates < empirical_diff_means) / len(perm_replicates) since this plot does not imply the comparison,
#but depits perfectly that two means are not the same.
# Out:
# 109.62690414811343
# 109.34725338491296
# The p value is 0.3594

# %%
plt.clf()
sns.set(style="whitegrid", color_codes=True)
df_aut=df1[df1.fuelType=='diesel']
df_man=df1[df1.fuelType=='benzin']
print(df_aut.powerPS.mean())
print(df_man.powerPS.mean())
emp_diff=diff_of_means(df_aut.powerPS, df_man.powerPS)
perm_replicates = draw_perm_reps(df_aut.powerPS, df_man.powerPS, diff_of_means, size=10000)                              
p = np.sum(perm_replicates >= emp_diff) / len(perm_replicates)
print("The p value is {}".format(p))
g=sns.distplot(perm_replicates,bins=25, norm_hist=False)
g.axvline(emp_diff, color='red')  #### See the position of the red line and it does not change with
# p = np.sum(perm_replicates < empirical_diff_means) / len(perm_replicates) since this plot does not imply the comparison,
#but depits perfectly that two means are not the same.
# Out:
# 144.4582296927213
# 119.63159784073746
# The p value is 0.0
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_aut=df1[df1.fuelType=='diesel']
df_man=df1[df1.fuelType=='benzin']
print(df_aut.price.mean())
print(df_man.price.mean())
emp_diff=diff_of_means(df_aut.price, df_man.price)
print(emp_diff)
perm_replicates = draw_perm_reps(df_aut.price, df_man.price, diff_of_means, size=10000)                              
p = np.sum(perm_replicates >= emp_diff) / len(perm_replicates)
print("The p value is {}".format(p))

g=sns.distplot(perm_replicates,bins=20,norm_hist=True)
g.axvline(emp_diff, color='red')  #### See the position of the red line and it does not change with
# p = np.sum(perm_replicates < empirical_diff_means) / len(perm_replicates) since this plot does not imply the comparison,
#but depits perfectly that two means are not the same.
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(df1.fuelType,df1.price, hue=df1.gearbox, palette='viridis')
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(df1.fuelType,df1.powerPS, hue=df1.gearbox, palette='seismic')
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.set(style="darkgrid", color_codes=True)
sns.jointplot(data=df1[df1.price<200000][df1.powerPS<700] ,y="price" ,x="powerPS",kind='reg',stat_func=stats.ttest_ind,scatter_kws={'alpha':0.15},line_kws={'color': 'red'})
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
# ?sns.set(style="darkgrid", color_codes=True)
sns.jointplot(data=df1[df1.price<200000][df1.age<40] ,y="price" ,x="age",kind='reg',stat_func=pearson_r,scatter_kws={'alpha':0.15},line_kws={'color': 'red'})
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
two_sample = stats.ttest_ind(df1[df1['fuelType']=='diesel'].price, 
                          df1[df1['fuelType']=='benzin'].price)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)

two_sample = stats.ttest_ind(df1[df1['gearbox']=='automatik'].price, 
                          df1[df1['gearbox']=='manuell'].price)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)

two_sample = stats.ttest_ind(df1[df1['salvaged']=='yes'].price, 
                          df1[df1['salvaged']=='no'].price)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)
# Out:
# The t-statistic is 83.050 and the p-value is 0.00000000.
# The t-statistic is 120.509 and the p-value is 0.00000000.
# The t-statistic is -64.047 and the p-value is 0.00000000.

# %%
two_sample = stats.ttest_ind(df1[df1['gearbox']=='automatik'].powerPS, 
                          df1[df1['gearbox']=='manuell'].powerPS)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)


two_sample = stats.ttest_ind(df1[df1['fuelType']=='diesel'].powerPS, 
                          df1[df1['fuelType']=='benzin'].powerPS)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)


two_sample = stats.ttest_ind(df1[df1['brand']=='VOLKSWAGEN'].powerPS, 
                          df1[df1['brand']=='SKODA'].powerPS)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)
# Out:
# The t-statistic is 249.735 and the p-value is 0.00000000.
# The t-statistic is 95.365 and the p-value is 0.00000000.
# The t-statistic is -0.385 and the p-value is 0.70049115.

# %%
two_sample = stats.ttest_ind(df1[df1['brand']=='VOLKSWAGEN'].powerPS, 
                          df1[df1['brand']=='SKODA'].powerPS)
print('The t-statistic is %.3f and the p-value is %.8f.' % two_sample)
# Out:
# The t-statistic is -0.385 and the p-value is 0.70049115.

# %%
# Out:
# The t-statistic is -0.385 and the p-value is 0.70049115.

# %%
df1[df1['brand']=='AUDI'].powerPS.plot(kind="hist")

# %%
df1#=df1.drop('index', axis='columns')
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-24 10:58:45                               A5 SPORTBACK 2.7 TDI
# 1      2016-03-17 16:54:04                                 GOLF 4 1 4  3TÜRER
# 2      2016-03-31 17:25:20                     SKODA FABIA 1.4 TDI PD CLASSIC
# 3      2016-04-04 17:36:23  BMW 316I   E36 LIMOUSINE   BASTLERFAHRZEUG  EX...
# 4      2016-04-01 20:48:51                        PEUGEOT 206 CC 110 PLATINUM
# 5      2016-03-26 19:54:18                                  MAZDA 3 1.6 SPORT
# 6      2016-04-07 10:06:22      VOLKSWAGEN PASSAT VARIANT 2.0 TDI COMFORTLINE
# 7      2016-03-21 12:57:01  NISSAN NAVARA 2.5DPF SE4X4 KLIMA SITZHEIZG BLU...
# 8      2016-03-20 10:25:19                        RENAULT TWINGO 1.2 16V AUT.
# 9      2016-03-23 15:48:05                   FORD C MAX 2.0 TDCI DPF TITANIUM
# 10     2016-04-01 22:55:47                  MERCEDES BENZ A 160 CLASSIC KLIMA
# 11     2016-04-01 19:56:48                  VOLKSWAGEN SCIROCCO 1.4 TSI SPORT
# 12     2016-03-27 11:38:00  BMW 530I TÜV 7/17 SCHECKHEFTGEPFLEGT SEHR GUTE...
# 13     2016-03-12 19:43:07                                       STADTFLITZER
# 14     2016-03-18 21:44:09              BMW 530D TOURING VOLLAUSSTATTUNG NAVI
# 15     2016-03-07 12:51:23                     HONDA CIVIC 1.4 I VTEC COMFORT
# 16     2016-03-09 11:56:38                               VOLKSWAGEN T3 ANDERE
# 17     2016-03-08 19:55:19                                     FIAT PUNTO 1.2
# 18     2016-04-03 15:48:11          MERCEDES BENZ E 250 D ORIGINAL ZUSTAND !!
# 19     2016-03-25 21:48:47                                      BMW 325I AUT.
# 20     2016-03-17 18:55:12          MERCEDES BENZ E 200 CDI AUTOMATIK CLASSIC
# 21     2016-03-13 15:47:08                 MINI ONE PEPPER SCHECKHEFTGEPFLEGT
# 22     2016-03-29 18:57:46                                   RENAULT CLIO 1.4
# 23     2016-03-15 18:59:02                                       BMW 120D DPF
# 24     2016-04-04 00:38:22                                   BMW 528I TOURING
# 25     2016-04-04 14:06:22                       MERCEDES BENZ B180 AUTOMATIK
# 26     2016-03-22 17:56:12                         SMART CABRIO TÜV BIS 07/17
# 27     2016-03-31 08:57:44                    VOLKSWAGEN GOLF 1.6 COMFORTLINE
# 28     2016-03-25 19:44:06                            AUDI A8 3.0 TDI QUATTRO
# 29     2016-03-30 12:49:54                                    SKODA FABIA 1.2
# ...                    ...                                                ...
# 231127 2016-03-29 13:53:42                         VOLKSWAGEN GOLF CABRIO 1.8
# 231128 2016-03-19 19:44:29                                SEAT IBIZA 1 4  16V
# 231129 2016-03-25 17:48:10                                BMW 118I SPORT LINE
# 231130 2016-03-07 16:50:15                        BMW 525D TOURING SPORT AUT.
# 231131 2016-03-23 11:36:43                            MERCEDES BENZ A 170 CDI
# 231132 2016-03-13 12:51:55                OPEL VECTRA 1.6 CARAVAN EDITION 100
# 231133 2016-03-26 23:25:24         SMART  ROADSTER BLACK EDITION*SPORT*CABRIO
# 231134 2016-03-07 09:54:08  MERCEDES BENZ E 200 CDI DPF BLUEEFFICIENCY 7G ...
# 231135 2016-03-14 16:52:33  MERCEDES BENZ E 270 CDI ELEGANCE  +VOLLAUSSTAT...
# 231136 2016-03-22 10:37:54  HONDA ACCORD TOURER 2.0 LIFESTYLE VERHANDLUNGS...
# 231137 2016-03-15 20:25:20                    VOLKSWAGEN PASSAT 2.0 EXECUTIVE
# 231138 2016-03-05 15:54:11                             OPEL ASTRA 1.6 CARAVAN
# 231139 2016-03-08 13:52:00  OPEL CORSA B  ECO SWING  TÜV 1/17 8FACH BEREIF...
# 231140 2016-03-21 23:40:49  VOLKSWAGEN GOLF 1.4 TSI BLUEMOTION TECHNOLOGY ...
# 231141 2016-03-26 18:36:54                                   CHRYSLER VOYAGER
# 231142 2016-04-01 12:59:21                                  AUDI A4 AVANT 1.8
# 231143 2016-04-01 01:55:58                                   SUBARU JUSTY 1.3
# 231144 2016-04-03 19:56:57                   OPEL ASTRA 1.6 CARAVAN SELECTION
# 231145 2016-03-20 18:47:59  VOLKSWAGEN GOLF 1.9 TDI DPF GOAL RENTNERFZG. 1...
# 231146 2016-04-02 16:43:27                                     OPEL ASTRA 1.8
# 231147 2016-03-06 21:11:23  MERCEDES BENZ E KLASSE AVANGARDE 220 CDI GRUNE...
# 231148 2016-03-31 18:50:37                           AUDI A3 1.8 T ATTRACTION
# 231149 2016-03-25 18:48:06                 MERCEDES BENZ E 400 CDI AVANTGARDE
# 231150 2016-03-21 15:36:22                       SEAT LEON 1.9 TDI 4/5 TUEREN
# 231151 2016-04-04 09:57:12                                VOLKSWAGEN LUPO 1.0
# 231152 2016-03-28 13:48:07                   VOLKSWAGEN GOLF 2.0 TDI DPF TEAM
# 231153 2016-03-19 19:53:49                                       TURBO DEFEKT
# 231154 2016-03-05 19:56:21              SMART SMART LEISTUNGSSTEIGERUNG 100PS
# 231155 2016-03-19 18:57:12                 VOLKSWAGEN MULTIVAN T4 TDI 7DC UY2
# 231156 2016-03-07 19:39:19       BMW M135I VOLLAUSGESTATTET NP 52.720    EURO
#
#          seller  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0       private  18300     test       coupe                2011    manuell
# 1       private   1500     test  kleinwagen                2001    manuell
# 2       private   3600     test  kleinwagen                2008    manuell
# 3       private    650     test   limousine                1995    manuell
# 4       private   2200     test      cabrio                2004    manuell
# 5       private   2000  control   limousine                2004    manuell
# 6       private   2799  control       kombi                2005    manuell
# 7       private  17999  control         suv                2011    manuell
# 8       private   1750  control  kleinwagen                2004  automatik
# 9       private   7550     test         bus                2007    manuell
# 10      private   1850     test         bus                2004    manuell
# 11      private  10400  control       coupe                2009    manuell
# 12      private   3699     test   limousine                2002  automatik
# 13      private    450     test  kleinwagen                1997    manuell
# 14      private   2500  control       kombi                2002  automatik
# 15      private   6900     test   limousine                2008    manuell
# 16      private   1990     test         bus                1981    manuell
# 17      private    690     test  kleinwagen                2003    manuell
# 18      private   3300     test   limousine                1995  automatik
# 19      private  18000     test   limousine                2007  automatik
# 20      private   3500  control   limousine                2004  automatik
# 21      private   6990     test   limousine                2007    manuell
# 22      private    590  control  kleinwagen                1999    manuell
# 23      private   7999  control   limousine                2007    manuell
# 24      private   2100     test       kombi                1998  automatik
# 25      private  13500     test         bus                2012  automatik
# 26      private   3000  control      cabrio                2006  automatik
# 27      private   1000  control   limousine                1998    manuell
# 28      private   7499     test   limousine                2004  automatik
# 29      private   5500  control  kleinwagen                2010    manuell
# ...         ...    ...      ...         ...                 ...        ...
# 231127  private   1300  control      cabrio                1998    manuell
# 231128  private   5990  control  kleinwagen                2009    manuell
# 231129  private  19800     test   limousine                2011    manuell
# 231130  private  23900  control       kombi                2011  automatik
# 231131  private   1300     test  kleinwagen                2001    manuell
# 231132  private   1600     test       kombi                1999    manuell
# 231133  private   4499  control      cabrio                2006  automatik
# 231134  private  20500  control   limousine                2012  automatik
# 231135  private   3800     test   limousine                2002  automatik
# 231136  private  13850  control       kombi                2012    manuell
# 231137  private   3200     test   limousine                2002    manuell
# 231138  private   4900  control       kombi                2008    manuell
# 231139  private    600  control  kleinwagen                1998    manuell
# 231140  private  20400     test   limousine                2014  automatik
# 231141  private   3900     test         bus                2003  automatik
# 231142  private   1600     test       kombi                1998    manuell
# 231143  private   1700  control  kleinwagen                1999    manuell
# 231144  private    800     test       kombi                2000    manuell
# 231145  private   5900     test   limousine                2006    manuell
# 231146  private   1400  control   limousine                2001    manuell
# 231147  private   6500     test   limousine                2003  automatik
# 231148  private   1999  control   limousine                1997    manuell
# 231149  private   5000     test   limousine                2003  automatik
# 231150  private   4400  control   limousine                2008    manuell
# 231151  private   1490  control  kleinwagen                1998    manuell
# 231152  private   7900     test   limousine                2010    manuell
# 231153  private   3200  control   limousine                2004    manuell
# 231154  private   1199     test      cabrio                2000  automatik
# 231155  private   9200     test         bus                1996    manuell
# 231156  private  28990  control   limousine                2013    manuell
#
#         powerPS  kilometer  monthOfRegistration fuelType salvaged  \
# 0           190     125000                    5   diesel      yes
# 1            75     150000                    6   benzin       no
# 2            69      90000                    7   diesel       no
# 3           102     150000                   10   benzin      yes
# 4           109     150000                    8   benzin       no
# 5           105     150000                   12   benzin       no
# 6           140     150000                   12   diesel      yes
# 7           190      70000                    3   diesel       no
# 8            75     150000                    2   benzin       no
# 9           136     150000                    6   diesel       no
# 10          102     150000                    1   benzin       no
# 11          160     100000                    4   benzin       no
# 12          231     150000                    7   benzin       no
# 13           50     150000                    5   benzin       no
# 14          193     150000                    9   diesel      yes
# 15           99      60000                   11   benzin       no
# 16           50       5000                    1   benzin       no
# 17           60     150000                    3   benzin       no
# 18          113     150000                    1   diesel       no
# 19          218      20000                    5   benzin       no
# 20          122     150000                   11   diesel       no
# 21           95     100000                    8   benzin       no
# 22           75     125000                    8   benzin       no
# 23          177     150000                    8   diesel       no
# 24          193     150000                    2   benzin       no
# 25          109     150000                    7   diesel       no
# 26           61      80000                    1   benzin       no
# 27          101     150000                   10   benzin       no
# 28          232     150000                    3   diesel      yes
# 29           60      70000                    4   benzin       no
# ...         ...        ...                  ...      ...      ...
# 231127       90     150000                    4   benzin       no
# 231128       86      90000                    6   benzin       no
# 231129      170      80000                   12   benzin       no
# 231130      204     150000                    7   diesel       no
# 231131       95     150000                   10   diesel       no
# 231132      101     150000                    5   benzin       no
# 231133       82     125000                    3   benzin       no
# 231134      136      60000                    4   diesel       no
# 231135      177     150000                    5   diesel      yes
# 231136      156     125000                   10   benzin       no
# 231137      116     150000                    4      lpg       no
# 231138      116     150000                    2   benzin       no
# 231139       54     150000                    1   benzin       no
# 231140      150      30000                    9   benzin       no
# 231141      174     150000                    7   benzin       no
# 231142      125     150000                    2   benzin       no
# 231143       68      70000                   11   benzin       no
# 231144      101     150000                   11   benzin      yes
# 231145      105     150000                    9   diesel       no
# 231146      125     150000                    2   benzin       no
# 231147      145     150000                    3   diesel       no
# 231148      150     150000                   12   benzin       no
# 231149      260     150000                   12   diesel      yes
# 231150      105     150000                    7   diesel       no
# 231151       50     150000                    9   benzin       no
# 231152      140     150000                    7   diesel       no
# 231153      225     150000                    5   benzin      yes
# 231154      101     125000                    3   benzin       no
# 231155      102     150000                    3   diesel       no
# 231156      320      50000                    8   benzin       no
#
#                 brand        model    age
# 0                AUDI           A5   8.25
# 1          VOLKSWAGEN         GOLF  18.33
# 2               SKODA        FABIA  11.42
# 3                 BMW          3ER  24.67
# 4             PEUGEOT      2_REIHE  15.50
# 5               MAZDA      3_REIHE  15.83
# 6          VOLKSWAGEN       PASSAT  14.83
# 7              NISSAN       NAVARA   8.08
# 8             RENAULT       TWINGO  15.00
# 9                FORD        C_MAX  12.33
# 10      MERCEDES_BENZ     A_KLASSE  14.92
# 11         VOLKSWAGEN     SCIROCCO  10.17
# 12                BMW          5ER  17.42
# 13               SEAT        AROSA  22.25
# 14                BMW          5ER  17.58
# 15              HONDA        CIVIC  11.75
# 16         VOLKSWAGEN  TRANSPORTER  37.92
# 17               FIAT        PUNTO  16.08
# 18      MERCEDES_BENZ     E_KLASSE  23.92
# 19                BMW          3ER  12.25
# 20      MERCEDES_BENZ     E_KLASSE  15.75
# 21               MINI          ONE  12.50
# 22            RENAULT         CLIO  20.50
# 23                BMW          1ER  12.50
# 24                BMW          5ER  21.00
# 25      MERCEDES_BENZ     B_KLASSE   7.42
# 26              SMART       FORTWO  12.92
# 27         VOLKSWAGEN         GOLF  21.67
# 28               AUDI           A8  15.08
# 29              SKODA        FABIA   9.17
# ...               ...          ...    ...
# 231127     VOLKSWAGEN         GOLF  21.17
# 231128           SEAT        IBIZA  10.33
# 231129            BMW          1ER   8.83
# 231130            BMW          5ER   8.42
# 231131  MERCEDES_BENZ     A_KLASSE  18.67
# 231132           OPEL       VECTRA  20.25
# 231133          SMART     ROADSTER  13.08
# 231134  MERCEDES_BENZ     E_KLASSE   7.17
# 231135  MERCEDES_BENZ     E_KLASSE  17.25
# 231136          HONDA       ACCORD   7.67
# 231137     VOLKSWAGEN       PASSAT  17.17
# 231138           OPEL        ASTRA  11.00
# 231139           OPEL        CORSA  20.92
# 231140     VOLKSWAGEN         GOLF   5.58
# 231141       CHRYSLER      VOYAGER  16.42
# 231142           AUDI           A4  21.00
# 231143         SUBARU        JUSTY  20.75
# 231144           OPEL        ASTRA  19.75
# 231145     VOLKSWAGEN         GOLF  13.58
# 231146           OPEL        ASTRA  18.00
# 231147  MERCEDES_BENZ     E_KLASSE  16.08
# 231148           AUDI           A3  22.83
# 231149  MERCEDES_BENZ     E_KLASSE  16.83
# 231150           SEAT         LEON  11.42
# 231151     VOLKSWAGEN         LUPO  21.58
# 231152     VOLKSWAGEN         GOLF   9.42
# 231153           SEAT         LEON  15.25
# 231154          SMART       FORTWO  19.08
# 231155     VOLKSWAGEN  TRANSPORTER  23.08
# 231156            BMW      M_REIHE   6.50
#
# [231157 rows x 16 columns]

# %%
df1.groupby(['fuelType','salvaged']).name.count().plot(kind='bar', logy=True )

# %%
df1.groupby(['fuelType','gearbox']).name.count().plot(kind='bar', logy=True)

# %%
df1.groupby(['fuelType','gearbox']).name.count().plot(kind='bar',figsize=(8,5),logy=True)

# %%
df1.powerPS.plot(kind='hist',bins=40)

# %%
display
# Out:
# <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>
