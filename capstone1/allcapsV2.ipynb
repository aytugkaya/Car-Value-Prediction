# %% [markdown]
# Import libraries -- may need to revisit to remove unused ones

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %% [markdown]
# <div class="span4 alert alert-success">
# ** QUESTION HERE***
#
#
# HERE I read the file. But when I work on the DF manupulation sometimes I make a mistake, and as we all know creating duplicate dfs don't work because if you change one all will change.
#
# What do you recommend here? How do I back-up? Do I go all the way to the beginning? Do I write a csv file?
#
# </div>

# %%
df=pd.read_csv("autos.csv",  encoding='cp1252'  )
#df1=pd.read_csv("autos.csv",  encoding='cp1252'  )
#df2=pd.read_csv("autos.csv",  encoding='cp1252'  )
#df3=pd.read_csv("autos.csv",  encoding='cp1252'  )
#df4=pd.read_csv("autos.csv",  encoding='cp1252'  )
df.head()
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
df.model=df.model.str.upper()
df.name=df.name.str.upper()
df.brand=df.brand.str.upper()

# %%
df[(df.brand=="SONSTIGE_AUTOS")&(df.model.isna()==False)]
# Out:
# Empty DataFrame
# Columns: [dateCrawled, name, seller, offerType, price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage, dateCreated, nrOfPictures, postalCode, lastSeen]
# Index: []

# %% [markdown]
# <div class="span4 alert alert-success">
# ** QUESTION HERE***
#
#
# HERE I read the file. But when I work on the DF manupulation sometimes I make a mistake, and as we all know creating duplicate dfs don't work because if you change one all will change.
#
# What do you recommend here? How do I back-up? Do I go all the way to the beginning? Do I write a csv file?
#
# </div>

# %%
df.name=df.name.str.replace("_", " ")
df.seller.unique()
df.seller[df.seller=="PRIVAT"] = "PRIVATE"
df.seller[df.seller=="GEWERBLICH"] = "DEALER"
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#namecol=df.name.str.split(" ")
##namecol.pop(0)
##liste
##[]
##namecol.apply(brnd for brnd in liste for row in namecol for elmnt in row if brnd in elmnt )
#namecol=namecol[:100]
#namecol2=df.name[:600]
##namecol2

# %%
#def namecol_list_old(nm,lst):
#    results=[]
#    for row in nm: 
#        #print(row)
#        for elmnt in row: 
#            #print(elmnt)
#            if elmnt in lst and elmnt.isalpha()==True  : 
#                results.append(elmnt)
#                
#                break
#            else: 
#                 if (row[0] != row[-1]) and (elmnt==row[-1]):# elmnt.isalpha()==True  
#                    results.append("NaN")
#                #break
#           
#  
#    return (results)
#
#

# %%
def namecol_list(nm,lst):
    results=[]
    #nm.split(" ")
    
    for row in nm:
        if "" in row:
            row.remove("")
        #print(row)
        found=False
        for elmnt in row: 
            #if elmnt.isalpha==True:
            #print(elmnt)
                for brnd in lst:


                     if found!=True and brnd == elmnt: 
                        results.append(elmnt)
                        #print(elmnt, "zzzzzzzzzzzzz")
                        found=True
                        break
                        #break  #except:
                     else: 
                            if found==False and elmnt==row[-1] and brnd==lst[-1]: 
                                #print ("ccccccccccccc", elmnt,"son eleman",row[-1], "son araba marka", brnd,lst[-1])
                                results.append("NaN")
                                #print(elmnt + "wwwwwwwwww")
                                found=True
                                break

# break may only occur syntactically nested in a for or while loop, but not nested in a function or class 
# definition within that loop.

# It terminates the nearest enclosing loop, skipping the optional else clause if the loop has one.

# If a for loop is terminated by break, the loop control target keeps its current value.

# When break passes control out of a try statement with a finally clause, 
# that finally clause is executed before really leaving the loop.           
  
    return (results)

# %%
new_col = namecol_list(df.name.str.split(" "),liste)
#len(new_col)-df.name[df.name.isnull()==False].count()
#liste.append("BMW")
#new_col

# %%
#df["new_models"]=namecol_list(df.name.str.split(" "),models)
#namecol1.str.rstrip("")
#namecol1.str.replace("","a")
#namecol1=namecol1.str.join(' ')
#namecol_list(namecol1,liste)
#namecol1=namecol1.str.split(" ")
#namecol1[402].remove("")
#namecol1#.remove("")

#namecol2=df.name[:10000].str.split(" ")
#namecol2=namecol1[:]
#ccc=namecol_list(namecol2,models)
#aaa
#len(aaa)
#aaa#namecol2

#len(bbb)-len(df.name)
#namecol2.drop_duplicates(keep="first")
#namecol2
#len(ccc)
#df=df[sorted(df.columns)]
#df[df.brand.isna()==True]
#df.name=df.name.str.capitalize()
#df

# %% [markdown]
# <div class="span4 alert alert-success">
# Here filtering starts on top and bottom level.
# Pretty easy to tell there will be no cars for 0 or "1 €", or under "100€" --- these are fake advertisements just to draw attention.
# Also, there are ultra luxurious brands, and another filter was written to see and filter out cars that are not ultra luxurious but ultra pricey.
#
# I am plannig to working on using str.split and isin method, which will look nicer. I don't know if it is really necessary.
#
# </div>

# %%
#LEVEL 1
df=df.drop(columns=["offerType","postalCode","nrOfPictures","dateCreated","lastSeen"])
df=df.drop(df[(df.brand =='SONSTIGE_AUTOS') & (df.model.isna() == True)].index)
df=df.drop(df[df.price==0].index)
df=df.drop(df[df.price==1].index)
df=df.drop(df[df.price<=100].index)
df=df.drop(df[df.price==2147483647].index)
search1=df[(df.brand.isin(["PORSCHE","FERRARI","MASERATI"])==False) &  (df.name.str.contains("FERRARI")==False)
          & (df.name.str.contains("MASERATI")==False) & (df.name.str.contains("PORSCHE")==False)
          & (df.price>=2000000)]
search1#### DİKKAT!!!
df=df.drop(search1.index)

search2=df[(df.brand.isin(["PORSCHE","FERRARI","MASERATI"])==False) &  (df.name.str.contains("FERRARI")==False)
          & (df.name.str.contains("MASERATI")==False) & (df.name.str.contains("PORSCHE")==False)
          & (df.name.str.contains("LAMBORGHINI")==False) & (df.name.str.contains("ASTON MARTIN")==False)
          & (df.name.str.contains("MUSEUM")==False) & (df.name.str.contains("JAGUAR")==False)
          & (df.name.str.contains("ROLLS ROYCE")==False)  & (df.name.str.contains("AMG")==False)
          &(df.name.str.contains("DETOMASO")==False) &(df.name.str.contains("BMW Z8")==False)
          &(df.name.str.contains("MCLAREN")==False)
          & (df.price>=200000) & (df.yearOfRegistration > 1980)]
search2 #### DİKKAT!!!
df=df.drop(search2.index)
search3=df[(df.brand.isin(["PORSCHE","FERRARI","MASERATI"])==False) &  (df.name.str.contains("FERRARI")==False)
          & (df.name.str.contains("MASERATI")==False) & (df.name.str.contains("PORSCHE")==False)
          & (df.name.str.contains("LAMBORGHINI")==False) & (df.name.str.contains("ASTON MARTIN")==False)
          & (df.name.str.contains("MUSEUM")==False) & (df.name.str.contains("JAGUAR")==False)
          & (df.name.str.contains("ROLLS ROYCE")==False)  & (df.name.str.contains("AMG")==False)
          &(df.name.str.contains("DETOMASO")==False) &(df.name.str.contains("BMW Z8")==False)
          &(df.name.str.contains("MCLAREN")==False)
          & (df.price>=100000) & (df.yearOfRegistration > 1980)]
search3#### DİKKAT!!!
df=df.drop(search3.index)

# %%
### LEVEL 2
#df=df.drop(df[df.price==0].index)
#df=df.drop(df[df.price==1].index)
#df=df.drop(df[df.price<=100].index)
#df=df.drop(df[df.price==2147483647].index)
### LEVEL 3

#df=df.drop(columns=["offerType","postalCode","nrOfPictures","dateCreated","lastSeen"])
#df=df.drop(df[df.price==0].index)
#df=df.drop(df[df.price==1].index)
#df=df.drop(df[df.price<=100].index)
#df=df.drop(df[df.price==2147483647].index)
#search=df[df.price>0.8*1e6]
###df=df.drop(search.index)
#search

# %% [markdown]
# **** CAUTION HERE*****
#
#
# <div class="span4 alert alert-success">
# Here the top filtering ends, but are these the results I want?
# I cleaned all fake data, but there are outliers still....Do I want them?
# </div>

# %%
###df.head().notRepairedDamage.isnull().sum()
##
###sns.scatterplot(data=np.log(df.price)*10,  alpha=0.3)
##sns.scatterplot(data=df.price,  alpha=0.3)
##

# %%
df.shape
df.columns
print(df.info())
print(df['vehicleType'].value_counts(dropna=False))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353784 entries, 0 to 371527
# Data columns (total 15 columns):
# dateCrawled            353784 non-null object
# name                   353784 non-null object
# seller                 353784 non-null object
# price                  353784 non-null int64
# abtest                 353784 non-null object
# vehicleType            321731 non-null object
# yearOfRegistration     353784 non-null int64
# gearbox                337978 non-null object
# powerPS                353784 non-null int64
# model                  339425 non-null object
# kilometer              353784 non-null int64
# monthOfRegistration    353784 non-null int64
# fuelType               325992 non-null object
# brand                  353784 non-null object
# notRepairedDamage      289866 non-null object
# dtypes: int64(5), object(10)
# memory usage: 43.2+ MB
# None
# limousine     92852
# kleinwagen    76977
# kombi         65636
# NaN           32053
# bus           29488
# cabrio        22001
# coupe         17936
# suv           13953
# andere         2888
# Name: vehicleType, dtype: int64

# %%
df.loc[df.price==df.price.max()]

# %%
#df.loc[df.price>=0.2*1e8]
#df=df.drop(df[df.price>=0.2*1e8].index)
#sns.scatterplot(data=df.price, alpha=0.3)

#df.loc[df.price>=0.9*1e7]
#df=df.drop(df[df.price>=0.9*1e7].index)
#sns.scatterplot(data=df.price, alpha=0.3)

df.loc[df.price>=1.9*1e6]
#df=df.drop(df[df.price>=0.9*1e7].index)
#sns.scatterplot(data=df.price, alpha=0.3)
#search=df[df.price>=1500000]
#search.sort_values(by="price")

# %%
plt.clf()
plt.hist(df.price[df.price<1000], bins=40)
# Out:
# (array([ 316.,  221., 1728.,  539., 2285.,  388., 2321.,  410., 3265.,
#          136.,  224., 2740.,  468., 2966.,  161., 2234.,  232., 6550.,
#          102.,  176., 2881.,  567., 4658.,  156., 3343.,  355., 4279.,
#           95., 3400.,  113.,  730., 4736.,  124., 3101.,  182., 4440.,
#           78., 2910.,  123., 4851.]),
#  array([101.  , 123.45, 145.9 , 168.35, 190.8 , 213.25, 235.7 , 258.15,
#         280.6 , 303.05, 325.5 , 347.95, 370.4 , 392.85, 415.3 , 437.75,
#         460.2 , 482.65, 505.1 , 527.55, 550.  , 572.45, 594.9 , 617.35,
#         639.8 , 662.25, 684.7 , 707.15, 729.6 , 752.05, 774.5 , 796.95,
#         819.4 , 841.85, 864.3 , 886.75, 909.2 , 931.65, 954.1 , 976.55,
#         999.  ]),
#  <a list of 40 Patch objects>)

# %%
df['price'][df.price<0.4e4].plot(kind='hist', rot=60, logx=False, logy=True)

# %%
df[(df.price>=100)&(df.price<1000)].count()
# Out:
# dateCrawled            57757
# name                   57757
# seller                 57757
# price                  57757
# abtest                 57757
# vehicleType            47390
# yearOfRegistration     57757
# gearbox                52690
# powerPS                57757
# kilometer              57757
# monthOfRegistration    57757
# fuelType               48503
# brand                  57757
# notRepairedDamage      38556
# model                  57757
# dtype: int64

# %%
#df.name[2]
######
####def namesplit(x,list,change):
#########    """checks if dataframe element has list element in it"""
#######    namesplitted = x.split(" ")
######    for i in range len(namesplitted):
#####        if namesplitted[i] in liste:
####            x.brand =

# %%
brands=df.brand.unique()
brands=pd.DataFrame(brands)
liste=list(brands[0].str.upper())

# %%
#df.name[(df.brand =='sonstige_autos') & (df.model.isna() == True)]
#df=df.drop(df[(df.brand =='sonstige_autos') & (df.model.isna() == True)].index)
#df=df.drop(df[(df.brand.isin(["porsche","ferrari","maserati"])==False) & (df.price>=900000)].index)
#
#
#sil1=df[(df.brand.isin(["porsche","ferrari","maserati"])==False) & (df.price>=500000) & (df.yearOfRegistration>2000)]
#df=df.drop(df[(df.brand.isin(["porsche","ferrari","maserati"])==False) & (df.price>=500000) & (df.yearOfRegistration>2000)].index)
#
#
#sil2=df[(df.brand.isin(["porsche","ferrari","maserati"])==False) & (df.price>=200000) & (df.yearOfRegistration>1000)]
#sil2
#
#sil3=df[(df.price<1000) & (df.yearOfRegistration>2010)]
#sil3
#
#df=df.drop(df[(df.price<1000) & (df.yearOfRegistration>2010)].index)
#
#df = df.reset_index(drop=True)
#df
#
#sil4=df[(df.price<1000) & (df.yearOfRegistration>2005)]
#sil4
#
##One too shui fooooo
##df=df.drop(df[df.name=="One too shui fooooo"].index)
#
#df[(df.brand.isin(["porsche","ferrari","maserati"])==False) & (df.price>=100000) & (df.yearOfRegistration>1000)]
##df.iloc[181036] ---- sil

# %%
sns.scatterplot(data=df.price[df.price<=0.01e7],  alpha=0.2)

# %%
#search=df[df.price>=1500000]
#search.sort_values(by="price")
#search=df[(df.brand.isin(["porsche","ferrari","maserati"])==False) & (df.price>=190000)]
#search

# %%
models=df.model.unique()
models=pd.DataFrame(models)
models.sort_values(by=0)

#models=list(models[0])
models=models[0].str.upper()
#print(liste)
models=list(models.dropna())
models
# Out:
# ['GOLF',
#  'GRAND',
#  'FABIA',
#  '3ER',
#  '2_REIHE',
#  'C_MAX',
#  '3_REIHE',
#  'PASSAT',
#  'NAVARA',
#  'KA',
#  'POLO',
#  'TWINGO',
#  'A_KLASSE',
#  'SCIROCCO',
#  '5ER',
#  'MERIVA',
#  'AROSA',
#  'ANDERE',
#  'C4',
#  'CIVIC',
#  'TRANSPORTER',
#  'PUNTO',
#  'E_KLASSE',
#  'CLIO',
#  'KADETT',
#  'KANGOO',
#  'ONE',
#  'FORTWO',
#  '1ER',
#  'B_KLASSE',
#  'SIGNUM',
#  'ASTRA',
#  'A8',
#  'JETTA',
#  'FIESTA',
#  'C_KLASSE',
#  'MICRA',
#  'VITO',
#  'SPRINTER',
#  '156',
#  'ESCORT',
#  'FORESTER',
#  'XC_REIHE',
#  'SCENIC',
#  'A4',
#  'A1',
#  'INSIGNIA',
#  'COMBO',
#  'FOCUS',
#  'TT',
#  'CORSA',
#  'A6',
#  'JAZZ',
#  'OMEGA',
#  'SLK',
#  '7ER',
#  '80',
#  '147',
#  'GLK',
#  '100',
#  'Z_REIHE',
#  'SPORTAGE',
#  'SORENTO',
#  'V40',
#  'IBIZA',
#  'MUSTANG',
#  'EOS',
#  'TOURAN',
#  'GETZ',
#  'A3',
#  'ALMERA',
#  'MEGANE',
#  'LUPO',
#  'R19',
#  'ZAFIRA',
#  'CADDY',
#  'MONDEO',
#  'CORDOBA',
#  'COLT',
#  'IMPREZA',
#  'VECTRA',
#  'BERLINGO',
#  'M_KLASSE',
#  'TIGUAN',
#  'I_REIHE',
#  'ESPACE',
#  'SHARAN',
#  '6_REIHE',
#  'PANDA',
#  'UP',
#  'SEICENTO',
#  'CEED',
#  '5_REIHE',
#  'YETI',
#  'OCTAVIA',
#  'MII',
#  'RX_REIHE',
#  '6ER',
#  'MODUS',
#  'FOX',
#  'MATIZ',
#  'BEETLE',
#  'C1',
#  'RIO',
#  'TOUAREG',
#  'LOGAN',
#  'SPIDER',
#  'CUORE',
#  'S_MAX',
#  'A2',
#  'X_REIHE',
#  'A5',
#  'GALAXY',
#  'C3',
#  'VIANO',
#  'S_KLASSE',
#  '1_REIHE',
#  'AVENSIS',
#  'SL',
#  'ROOMSTER',
#  'Q5',
#  'KAEFER',
#  'SANTA',
#  'COOPER',
#  'LEON',
#  '4_REIHE',
#  '500',
#  'LAGUNA',
#  'PTCRUISER',
#  'CLK',
#  'PRIMERA',
#  'EXEO',
#  '159',
#  'TRANSIT',
#  'JUKE',
#  'QASHQAI',
#  'CARISMA',
#  'ACCORD',
#  'COROLLA',
#  'LANOS',
#  'PHAETON',
#  'BOXSTER',
#  'VERSO',
#  'SWIFT',
#  'RAV',
#  'KUGA',
#  'PICANTO',
#  'KALOS',
#  'SUPERB',
#  'STILO',
#  'ALHAMBRA',
#  '911',
#  'M_REIHE',
#  'ROADSTER',
#  'YPSILON',
#  'CAYENNE',
#  'GALANT',
#  'JUSTY',
#  '90',
#  'SIRION',
#  'CROSSFIRE',
#  'AGILA',
#  'DUSTER',
#  'CR_REIHE',
#  'V50',
#  'MX_REIHE',
#  'DISCOVERY',
#  'C_REIHE',
#  'V_KLASSE',
#  'YARIS',
#  'C5',
#  'AYGO',
#  'CC',
#  'CARNIVAL',
#  'FUSION',
#  'BORA',
#  'FORFOUR',
#  'CL',
#  'TIGRA',
#  '300C',
#  'Q3',
#  'SPARK',
#  'V70',
#  'X_TYPE',
#  'DUCATO',
#  'S_TYPE',
#  'X_TRAIL',
#  'TOLEDO',
#  'ALTEA',
#  'VOYAGER',
#  'CALIBRA',
#  'BRAVO',
#  'RANGE_ROVER',
#  'ANTARA',
#  'TUCSON',
#  'Q7',
#  'CITIGO',
#  'JIMNY',
#  'CX_REIHE',
#  'WRANGLER',
#  'LYBRA',
#  'RANGE_ROVER_SPORT',
#  'LANCER',
#  'FREELANDER',
#  'CAPTIVA',
#  'C2',
#  'RANGE_ROVER_EVOQUE',
#  'SANDERO',
#  'NOTE',
#  '900',
#  'DEFENDER',
#  'CHEROKEE',
#  'CLUBMAN',
#  'SAMARA',
#  '601',
#  'LEGACY',
#  'PAJERO',
#  'AURIS',
#  'NIVA',
#  'S60',
#  'NUBIRA',
#  'VIVARO',
#  'G_KLASSE',
#  'LODGY',
#  '850',
#  'SERIE_2',
#  'CHARADE',
#  'CROMA',
#  'OUTLANDER',
#  'GL',
#  'DOBLO',
#  'MUSA',
#  'AMAROK',
#  'MOVE',
#  '9000',
#  'V60',
#  'AVEO',
#  '200',
#  '145',
#  'B_MAX',
#  'DELTA',
#  'TERIOS',
#  'RANGEROVER',
#  'MATERIA',
#  'KALINA',
#  'ELEFANTINO',
#  'I3',
#  'KAPPA',
#  'SERIE_3',
#  'SERIE_1',
#  'DISCOVERY_SPORT']

# %%
#brand_modelsxxx={'80':, '147', 'Glk', '100', , 'V40',  , 'R19'   , 'M_klasse', , 'Espace', '5_reihe',,
# 'Mii', 'Rx_reihe', '6er', 'Modus', 'Spider', 'Cuore', 'S_max',
#'A2', 'X_reihe', 'Galaxy', '1_reihe', 'Sl', 'Roomster', 'Q5', 'Kaefer', 'Santa', '500'
#'Exeo', '159' ,  'Lanos' ,  '5er',  'Arosa', 'Andere',
#,  ,  'Sandero', 'Note',   'One', 'Fortwo', '1er',  'Signum',
#     , '156',   'Xc_reihe',  ,  'Combo', , 'Tt'  'Slk', '7er',
#'900', 'Cherokee', 'Clubman', , '601', 'Boxster',, 'Swift', 'Rav', 'Picanto', 'Kalos',
#'Superb', 'Alhambra', '911', 'M_reihe', 'Roadster', ,
#, 'Galant', 'Justy', '90', 'Sirion', 'Crossfire', 'Agila', 'Cr_reihe', 'V50', 'Mx_reihe', 'Discovery',
#'C_reihe', 'Cc', , 'Fusion', 'Forfour', 'Cl', '300c', 'Q3', 'Spark'
#, 'S_type', 'Altea', 'Voyager',  'Bravo',  'Antara', 'Q7', 'Citigo', 'Jimny',
#'Cx_reihe', 'Wrangler', 'Lybra', 'Freelander', 'S60', 'Nubira', 'Vivaro', 'Lodgy',
#'850', 'Serie_2', 'Charade', 'Croma', , 'Gl', 'Move', '9000', 'V60', 'Aveo','200', '145',
#'B_max', 'Delta', 'Terios', 'Materia', 'Kalina',  'I3'
#   'Alfa_romeo':['Kappa', 'Elefantino', 'Musa'],
#             'Audi':[ 'A3', 'A5','A8',  'A1','A4' , 'A6',],  
#             'Bmw':['Z_reihe', '3er'], 
#             'Chevrolet':[, 'Matiz'], 
#             'Chrysler':["Grand Voyager", 'Ptcruiser'], 
#             'Citroen':['C1','C3', 'Berlingo', 'C2', 'C4',  'C5'], 
#             'Dacia':['Logan', 'Duster'], 
#             'Daewoo':[, 'Matiz'], 
#             'Daihatsu':[], 
#             'Fiat':['Punto','Fiesta', 'Panda', 'Seicento', 'Doblo','Ducato', 'Stilo'],
#             'Ford':['Focus', 'C_max','Escort','Ka', 'Transit', 'Mustang', 'Kuga''Mondeo',],
#             'Honda':['Jazz','Civic', 'Accord'], 
#             'Hyundai':[, 'I_reihe', 'Tucson', 'Getz'], 
#             'Jaguar':[, 'X_type',], 
#             'Jeep': ["Grand Cherokee"], 
#             'Kia':['Carnival', 'Sportage', 'Sorento', 'Rio', 'Ceed'], 
#             'Lada':['Niva', 'Samara'],
#             'Lancia':['Ypsilon'], 
#             'Land_rover':['Discovery_sport', 'Range_rover_evoque',  'Defender', 'Range_rover_sport', 'Rangerover', 
#                           'Serie_3', 'Serie_1',],
#             'Mazda':["5_reihe", '6_reihe','3_reihe'], 
#             'Mercedes_benz':['E_klasse', 'Sprinter','A_klasse','C_klasse','Vito','B_klasse', 'Viano', 'S_klasse', 
#                              'Clk','V_klasse', 'G_klasse'],
#             'Mini':[, 'Cooper'], 
#             'Mitsubishi':['Pajero', 'Carisma', 'Colt', 'Lancer','Outlander'], 
#             'Nissan':['Micra','Almera', 'Juke', 'Qashqai', 'Primera', 'Navara', 'X_trail'],
#             'Opel':['Omega','Corsa','Insignia' ,'Astra', 'Kadett','Meriva', 'Zafira','Calibra','Vectra', 'Tigra'],
#             'Peugeot':[, '2_reihe','3_reihe', '4_reihe'], 
#             'Porsche':['Cayenne'], 
#             'Renault':['Kangoo','Clio', 'Scenic','Twingo', 'Megane', 'Laguna','Captiva'],
#             'Rover':[], 
#             'Saab':[], 
#             'Seat':['Cordoba','Toledo','Ibiza','Leon'], 
#             'Skoda':[, 'Yeti', 'Octavia','Fabia'], 
#             'Smart':[], 
#             'Subaru':['Legacy', 'Forester', 'Impreza'],
#             'Suzuki':["Grand Vitara"], 
#             'Toyota':["Corolla", "Yaris",'Auris', 'Avensis', 'Verso', 'Aygo'], 
#             'Trabant':[], 
#             'Volkswagen':['Golf','Jetta','Passat','Polo','Scirocco','Up', 'Fox', 'Beetle', 'Lupo', 'Eos', 'Touran', 'Phaeton',
#                            'Touareg','Tiguan', 'Sharan', 'Caddy', 'Bora',  'Amarok', 'Transporter'],
#             'Volvo':[, 'V70']
#                 }

# %%
#df.brand[df.model=='Terios'].unique()

# %%
grand_opt={'CHRYSLER':"GRAND VOYAGER", 'SUZUKI':"GRAND VITARA",'JEEP': "GRAND CHEROKEE"}
def lookupCode(code):
    return grand_opt.get(code)

# %%
df.model=df.model.str.upper()
df.brand=df.brand.str.upper()
df.name=df.name.str.upper()
#df.model[df1.model=="Grand"] = 
df.model[df.model=="GRAND"] = df.brand[df.model=="GRAND"].map(lookupCode)
dftrim1.model[dftrim1.model=="GRAND"] = dftrim1.brand[df.model=="GRAND"].map(lookupCode)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dftrim1=df.head(100)
dftrim1
# Out:
#              dateCrawled                                               name  \
# 0    2016-03-24 11:52:17                                         GOLF 3 1.6
# 1    2016-03-24 10:58:45                               A5 SPORTBACK 2.7 TDI
# 2    2016-03-14 12:52:21                     JEEP GRAND CHEROKEE "OVERLAND"
# 3    2016-03-17 16:54:04                                 GOLF 4 1 4  3TÜRER
# 4    2016-03-31 17:25:20                     SKODA FABIA 1.4 TDI PD CLASSIC
# 5    2016-04-04 17:36:23  BMW 316I   E36 LIMOUSINE   BASTLERFAHRZEUG  EX...
# 6    2016-04-01 20:48:51                        PEUGEOT 206 CC 110 PLATINUM
# 8    2016-04-04 23:42:13               FORD C   MAX TITANIUM 1 0 L ECOBOOST
# 9    2016-03-17 10:53:50  VW GOLF 4 5 TUERIG ZU VERKAUFEN MIT ANHAENGERK...
# 10   2016-03-26 19:54:18                                  MAZDA 3 1.6 SPORT
# 11   2016-04-07 10:06:22      VOLKSWAGEN PASSAT VARIANT 2.0 TDI COMFORTLINE
# 12   2016-03-15 22:49:09                  VW PASSAT FACELIFT 35I  "7SITZER"
# 13   2016-03-21 21:37:40                     VW PASSAT 1.9 TDI 131 PS LEDER
# 14   2016-03-21 12:57:01  NISSAN NAVARA 2.5DPF SE4X4 KLIMA SITZHEIZG BLU...
# 15   2016-03-11 21:39:15                       KA LUFTHANSA EDITION 450€ VB
# 16   2016-04-01 12:46:46                                        POLO 6N 1 4
# 17   2016-03-20 10:25:19                        RENAULT TWINGO 1.2 16V AUT.
# 18   2016-03-23 15:48:05                   FORD C MAX 2.0 TDCI DPF TITANIUM
# 19   2016-04-01 22:55:47                  MERCEDES BENZ A 160 CLASSIC KLIMA
# 20   2016-04-01 19:56:48                  VOLKSWAGEN SCIROCCO 1.4 TSI SPORT
# 21   2016-03-27 11:38:00  BMW 530I TÜV 7/17 SCHECKHEFTGEPFLEGT SEHR GUTE...
# 22   2016-03-23 14:52:51                      OPEL MERIVA 1.HAND TÜV 3.2018
# 23   2016-03-12 19:43:07                                       STADTFLITZER
# 24   2016-03-13 20:40:49                         MERCEDES 200E  TÜV 04/2016
# 25   2016-03-18 21:44:09              BMW 530D TOURING VOLLAUSSTATTUNG NAVI
# 26   2016-03-10 19:38:18                          CITROEN C4 GRAND PICASSO.
# 27   2016-03-07 12:51:23                     HONDA CIVIC 1.4 I VTEC COMFORT
# 28   2016-03-09 11:56:38                               VOLKSWAGEN T3 ANDERE
# 29   2016-03-08 19:55:19                                     FIAT PUNTO 1.2
# 30   2016-04-03 15:48:11          MERCEDES BENZ E 250 D ORIGINAL ZUSTAND !!
# ..                   ...                                                ...
# 73   2016-03-05 16:45:05                                        FORD FIESTA
# 74   2016-03-22 17:45:41        MERCEDES BENZ C 180 T KOMPRESSOR AVANTGARDE
# 75   2016-03-31 18:46:36                             VW GOLF V PLUS TDI 1 8
# 76   2016-03-17 09:48:12                               NISSAN MICRA 1.2 CVT
# 77   2016-03-11 14:50:52                        MB VITO TRANSPORTER 108 CDI
# 78   2016-03-31 22:48:06                          GOLF 4 TDI 1 9.  3 TUERIG
# 79   2016-03-10 10:50:26  MERCEDES BENZ 311 CDI SPRINTER DOKA 6 SITZ. TÜ...
# 80   2016-03-11 23:42:53  MERCEDES BENZ E 250 CDI MOD.2011 AUTOMATIK NAV...
# 81   2016-03-17 18:52:56                                OPEL ASTRA F CABRIO
# 82   2016-04-01 22:39:35  MUSS DRINGEND WEG !!! 2 MAL ALFA ROMEO 156 ZU ...
# 83   2016-04-03 12:56:45                     BASTLER FAHRZEUG MIT REST TUEV
# 84   2016-03-09 21:46:09                                    FORD ESCORT CLX
# 85   2016-03-23 18:59:37               MERCEDES BENZ C 220 T CDI AVANTGARDE
# 86   2016-03-12 19:46:54                                    SUBARU FORESTER
# 87   2016-03-29 14:58:15  VOLVO XC90 AWD D5 KINETIC LEDER STANDHEIZUNG A...
# 88   2016-03-13 19:52:34                                   MITSUBISHI L 400
# 89   2016-03-08 13:49:57                               FIESTA TITANIUM 1.25
# 90   2016-03-07 17:38:57                                     RENAULT SCENIC
# 92   2016-03-23 11:53:21                         A4 DIESEL LEDER TOP   NAVI
# 93   2016-04-02 23:25:25           SENATOR A2  3 0E  180PS  CD AUSSTATTUNG.
# 94   2016-03-16 07:56:19                           FORD KA   TÜV ABGELAUFEN
# 95   2016-03-10 11:44:54                            AUDI A1 1.2 TFSI S LINE
# 96   2016-03-28 16:37:43  UNFALL OPEL INSIGNIA VOLL AUSSTATTUNG  TÜV NEU...
# 97   2016-03-25 18:44:10                          VOLKSWAGEN PASSAT 1.9 TDI
# 98   2016-03-31 10:53:10   BMW 318D AUT.  XENON  NAVI  SPORTSITZE FESTREIS!
# 99   2016-03-26 15:38:12                                  VW T5 KASTENWAGEN
# 100  2016-04-01 12:45:41  MERCEDES A KLASSE    TOP ZUSTAND   TÜV/AU   NE...
# 101  2016-03-11 19:00:25  OPEL COMBO 2008  TÜV NEU BIS 02.2018  DIESEL  ...
# 102  2016-03-28 00:56:46                    FORD FOCUS TURNIER 1.6 TDCI DPF
# 103  2016-03-15 17:41:31                               AUDI A4 B5 1 6 LITER
#
#      seller  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0    privat    480     test         NaN                1993    manuell
# 1    privat  18300     test       coupe                2011    manuell
# 2    privat   9800     test         suv                2004  automatik
# 3    privat   1500     test  kleinwagen                2001    manuell
# 4    privat   3600     test  kleinwagen                2008    manuell
# 5    privat    650     test   limousine                1995    manuell
# 6    privat   2200     test      cabrio                2004    manuell
# 8    privat  14500  control         bus                2014    manuell
# 9    privat    999     test  kleinwagen                1998    manuell
# 10   privat   2000  control   limousine                2004    manuell
# 11   privat   2799  control       kombi                2005    manuell
# 12   privat    999  control       kombi                1995    manuell
# 13   privat   2500  control       kombi                2004    manuell
# 14   privat  17999  control         suv                2011    manuell
# 15   privat    450     test  kleinwagen                1910        NaN
# 16   privat    300     test         NaN                2016        NaN
# 17   privat   1750  control  kleinwagen                2004  automatik
# 18   privat   7550     test         bus                2007    manuell
# 19   privat   1850     test         bus                2004    manuell
# 20   privat  10400  control       coupe                2009    manuell
# 21   privat   3699     test   limousine                2002  automatik
# 22   privat   2900     test         NaN                2018    manuell
# 23   privat    450     test  kleinwagen                1997    manuell
# 24   privat    500     test   limousine                1990    manuell
# 25   privat   2500  control       kombi                2002  automatik
# 26   privat   5555  control         NaN                2017    manuell
# 27   privat   6900     test   limousine                2008    manuell
# 28   privat   1990     test         bus                1981    manuell
# 29   privat    690     test  kleinwagen                2003    manuell
# 30   privat   3300     test   limousine                1995  automatik
# ..      ...    ...      ...         ...                 ...        ...
# 73   privat    750  control  kleinwagen                2002    manuell
# 74   privat   7999  control       kombi                2008    manuell
# 75   privat   6600  control   limousine                2006    manuell
# 76   privat   7999     test  kleinwagen                2013    manuell
# 77   privat   1400  control      andere                2003    manuell
# 78   privat    800     test         NaN                2000    manuell
# 79   privat   5000     test         bus                2006    manuell
# 80   privat  20300     test   limousine                2010  automatik
# 81   privat    150  control         NaN                2016    manuell
# 82   privat    250     test       kombi                2000    manuell
# 83   privat    350  control  kleinwagen                1997    manuell
# 84   privat    600     test   limousine                1994    manuell
# 85   privat   3300     test       kombi                2005    manuell
# 86   privat   1600     test       kombi                1997  automatik
# 87   privat   8000     test         suv                2005    manuell
# 88   privat   1800  control         bus                2001    manuell
# 89   privat   6800  control  kleinwagen                2009    manuell
# 90   privat   2990     test         bus                2004    manuell
# 92   privat   2400     test   limousine                2003    manuell
# 93   privat   1222  control   limousine                1984  automatik
# 94   privat    250  control         NaN                2000        NaN
# 95   privat  14500     test  kleinwagen                2013    manuell
# 96   privat   8390     test         NaN                2009        NaN
# 97   privat   3850     test   limousine                2003    manuell
# 98   privat  23490  control   limousine                2013  automatik
# 99   privat   6450     test         bus                2008    manuell
# 100  privat   1700     test  kleinwagen                1999  automatik
# 101  privat   4290     test         bus                2008    manuell
# 102  privat   1500  control       kombi                2006    manuell
# 103  privat    499  control   limousine                1995    manuell
#
#      powerPS           model  kilometer  monthOfRegistration fuelType  \
# 0          0            GOLF     150000                    0   benzin
# 1        190             NaN     125000                    5   diesel
# 2        163  GRAND CHEROKEE     125000                    8   diesel
# 3         75            GOLF     150000                    6   benzin
# 4         69           FABIA      90000                    7   diesel
# 5        102             3ER     150000                   10   benzin
# 6        109         2_REIHE     150000                    8   benzin
# 8        125           C_MAX      30000                    8   benzin
# 9        101            GOLF     150000                    0      NaN
# 10       105         3_REIHE     150000                   12   benzin
# 11       140          PASSAT     150000                   12   diesel
# 12       115          PASSAT     150000                   11   benzin
# 13       131          PASSAT     150000                    2      NaN
# 14       190          NAVARA      70000                    3   diesel
# 15         0              KA       5000                    0   benzin
# 16        60            POLO     150000                    0   benzin
# 17        75          TWINGO     150000                    2   benzin
# 18       136           C_MAX     150000                    6   diesel
# 19       102        A_KLASSE     150000                    1   benzin
# 20       160        SCIROCCO     100000                    4   benzin
# 21       231             5ER     150000                    7   benzin
# 22        90          MERIVA     150000                    5   benzin
# 23        50           AROSA     150000                    5   benzin
# 24       118          ANDERE     150000                   10   benzin
# 25       193             5ER     150000                    9   diesel
# 26       125              C4     125000                    4      NaN
# 27        99           CIVIC      60000                   11   benzin
# 28        50     TRANSPORTER       5000                    1   benzin
# 29        60           PUNTO     150000                    3   benzin
# 30       113        E_KLASSE     150000                    1   diesel
# ..       ...             ...        ...                  ...      ...
# 73        50          FIESTA     150000                    4   benzin
# 74       156        C_KLASSE     150000                   10   benzin
# 75       105            GOLF     150000                   10   diesel
# 76        80           MICRA      40000                    4   benzin
# 77        82            VITO     150000                    8   diesel
# 78        90            GOLF     150000                    2   diesel
# 79       109        SPRINTER     150000                    4   diesel
# 80       204        E_KLASSE      80000                   12   diesel
# 81        75           ASTRA     150000                    3   benzin
# 82       155             156     150000                    0   benzin
# 83        54             NaN     150000                    3      NaN
# 84        75          ESCORT     100000                    6   benzin
# 85       150        C_KLASSE     150000                    9   diesel
# 86       122        FORESTER     150000                   10   benzin
# 87       185        XC_REIHE     150000                    8   diesel
# 88        87          ANDERE     150000                    7   diesel
# 89        82          FIESTA      60000                   12   benzin
# 90       113          SCENIC     150000                   12   benzin
# 92         0              A4     150000                    9   diesel
# 93       180          ANDERE     150000                    3   benzin
# 94        60              KA     150000                    0      NaN
# 95        86              A1      60000                    4   benzin
# 96         0        INSIGNIA     150000                    0      NaN
# 97       131          PASSAT     150000                    5   diesel
# 98       143             3ER      40000                    6   diesel
# 99        84     TRANSPORTER     150000                   12      NaN
# 100      102        A_KLASSE     125000                   11   benzin
# 101        0           COMBO     150000                    2   diesel
# 102      109           FOCUS     150000                   10   diesel
# 103      101              A4     150000                    5   benzin
#
#              brand notRepairedDamage
# 0       VOLKSWAGEN               NaN
# 1             AUDI                ja
# 2             JEEP               NaN
# 3       VOLKSWAGEN              nein
# 4            SKODA              nein
# 5              BMW                ja
# 6          PEUGEOT              nein
# 8             FORD               NaN
# 9       VOLKSWAGEN               NaN
# 10           MAZDA              nein
# 11      VOLKSWAGEN                ja
# 12      VOLKSWAGEN               NaN
# 13      VOLKSWAGEN              nein
# 14          NISSAN              nein
# 15            FORD               NaN
# 16      VOLKSWAGEN               NaN
# 17         RENAULT              nein
# 18            FORD              nein
# 19   MERCEDES_BENZ              nein
# 20      VOLKSWAGEN              nein
# 21             BMW              nein
# 22            OPEL              nein
# 23            SEAT              nein
# 24   MERCEDES_BENZ                ja
# 25             BMW                ja
# 26         CITROEN              nein
# 27           HONDA              nein
# 28      VOLKSWAGEN              nein
# 29            FIAT              nein
# 30   MERCEDES_BENZ              nein
# ..             ...               ...
# 73            FORD              nein
# 74   MERCEDES_BENZ              nein
# 75      VOLKSWAGEN              nein
# 76          NISSAN              nein
# 77   MERCEDES_BENZ              nein
# 78      VOLKSWAGEN               NaN
# 79   MERCEDES_BENZ              nein
# 80   MERCEDES_BENZ              nein
# 81            OPEL                ja
# 82      ALFA_ROMEO                ja
# 83            FIAT                ja
# 84            FORD                ja
# 85   MERCEDES_BENZ                ja
# 86          SUBARU              nein
# 87           VOLVO               NaN
# 88      MITSUBISHI              nein
# 89            FORD              nein
# 90         RENAULT              nein
# 92            AUDI               NaN
# 93            OPEL               NaN
# 94            FORD               NaN
# 95            AUDI              nein
# 96            OPEL               NaN
# 97      VOLKSWAGEN              nein
# 98             BMW              nein
# 99      VOLKSWAGEN              nein
# 100  MERCEDES_BENZ              nein
# 101           OPEL              nein
# 102           FORD              nein
# 103           AUDI               NaN
#
# [100 rows x 15 columns]

# %%
#namecol.apply(brnd for brnd in liste for row in namecol for elmnt in row if brnd in elmnt )

# %%
def colbrmdl(brands,models):
    out={}
    for mdl in  models:
        
        hits= df.brand[df.model==mdl].unique()
            
        for hit in hits:
            if mdl not in ["MISSING VALUE","ANDERE" ]:
            
            
            
          
                out.setdefault(hit, []).append(mdl) 
        
    return out

# %%
brandsmodels={}
brandsmodels=colbrmdl(brands,models)
brandsmodels
# Out:
# {'VOLKSWAGEN': ['GOLF',
#   'PASSAT',
#   'POLO',
#   'SCIROCCO',
#   'TRANSPORTER',
#   'JETTA',
#   'EOS',
#   'TOURAN',
#   'LUPO',
#   'CADDY',
#   'TIGUAN',
#   'SHARAN',
#   'UP',
#   'FOX',
#   'BEETLE',
#   'TOUAREG',
#   'KAEFER',
#   'PHAETON',
#   'CC',
#   'BORA',
#   'AMAROK'],
#  'SKODA': ['FABIA', 'YETI', 'OCTAVIA', 'ROOMSTER', 'SUPERB', 'CITIGO'],
#  'BMW': ['3ER',
#   '5ER',
#   '1ER',
#   '7ER',
#   'Z_REIHE',
#   '6ER',
#   'X_REIHE',
#   'M_REIHE',
#   'I3'],
#  'PEUGEOT': ['2_REIHE', '3_REIHE', '5_REIHE', '1_REIHE', '4_REIHE'],
#  'FORD': ['C_MAX',
#   'KA',
#   'FIESTA',
#   'ESCORT',
#   'FOCUS',
#   'MUSTANG',
#   'MONDEO',
#   'S_MAX',
#   'GALAXY',
#   'TRANSIT',
#   'KUGA',
#   'FUSION',
#   'B_MAX'],
#  'MAZDA': ['3_REIHE',
#   '6_REIHE',
#   '5_REIHE',
#   'RX_REIHE',
#   '1_REIHE',
#   'MX_REIHE',
#   'CX_REIHE'],
#  'NISSAN': ['NAVARA',
#   'MICRA',
#   'ALMERA',
#   'PRIMERA',
#   'JUKE',
#   'QASHQAI',
#   'X_TRAIL',
#   'NOTE'],
#  'RENAULT': ['TWINGO',
#   'CLIO',
#   'KANGOO',
#   'SCENIC',
#   'MEGANE',
#   'R19',
#   'ESPACE',
#   'MODUS',
#   'LAGUNA'],
#  'MERCEDES_BENZ': ['A_KLASSE',
#   'E_KLASSE',
#   'B_KLASSE',
#   'C_KLASSE',
#   'VITO',
#   'SPRINTER',
#   'SLK',
#   'GLK',
#   'M_KLASSE',
#   'VIANO',
#   'S_KLASSE',
#   'SL',
#   'CLK',
#   'V_KLASSE',
#   'CL',
#   'G_KLASSE',
#   'GL'],
#  'OPEL': ['MERIVA',
#   'KADETT',
#   'SIGNUM',
#   'ASTRA',
#   'INSIGNIA',
#   'COMBO',
#   'CORSA',
#   'OMEGA',
#   'ZAFIRA',
#   'VECTRA',
#   'AGILA',
#   'TIGRA',
#   'CALIBRA',
#   'ANTARA',
#   'VIVARO'],
#  'SEAT': ['AROSA',
#   'IBIZA',
#   'CORDOBA',
#   'MII',
#   'LEON',
#   'EXEO',
#   'ALHAMBRA',
#   'TOLEDO',
#   'ALTEA'],
#  'CITROEN': ['C4', 'BERLINGO', 'C1', 'C3', 'C5', 'C2'],
#  'HONDA': ['CIVIC', 'JAZZ', 'ACCORD', 'CR_REIHE'],
#  'FIAT': ['PUNTO',
#   'PANDA',
#   'SEICENTO',
#   '500',
#   'STILO',
#   'DUCATO',
#   'BRAVO',
#   'CROMA',
#   'DOBLO'],
#  'MINI': ['ONE', 'COOPER', 'CLUBMAN'],
#  'SMART': ['FORTWO', 'ROADSTER', 'FORFOUR'],
#  'AUDI': ['A8',
#   'A4',
#   'A1',
#   'TT',
#   'A6',
#   '80',
#   '100',
#   'A3',
#   'A2',
#   'A5',
#   'Q5',
#   '90',
#   'Q3',
#   'Q7',
#   '200'],
#  'ALFA_ROMEO': ['156', '147', 'SPIDER', '159', '145'],
#  'SUBARU': ['FORESTER', 'IMPREZA', 'JUSTY', 'LEGACY'],
#  'VOLVO': ['XC_REIHE', 'V40', 'V50', 'C_REIHE', 'V70', 'S60', '850', 'V60'],
#  'KIA': ['SPORTAGE', 'SORENTO', 'CEED', 'RIO', 'PICANTO', 'CARNIVAL'],
#  'HYUNDAI': ['GETZ', 'I_REIHE', 'SANTA', 'TUCSON'],
#  'MITSUBISHI': ['COLT', 'CARISMA', 'GALANT', 'LANCER', 'PAJERO', 'OUTLANDER'],
#  'CHEVROLET': ['MATIZ', 'SPARK', 'CAPTIVA', 'AVEO'],
#  'DAEWOO': ['MATIZ', 'LANOS', 'KALOS', 'NUBIRA'],
#  'DACIA': ['LOGAN', 'DUSTER', 'SANDERO', 'LODGY'],
#  'DAIHATSU': ['CUORE', 'SIRION', 'CHARADE', 'MOVE', 'TERIOS', 'MATERIA'],
#  'TOYOTA': ['AVENSIS', 'COROLLA', 'VERSO', 'RAV', 'YARIS', 'AYGO', 'AURIS'],
#  'CHRYSLER': ['PTCRUISER', 'CROSSFIRE', '300C', 'VOYAGER'],
#  'PORSCHE': ['BOXSTER', '911', 'CAYENNE'],
#  'SUZUKI': ['SWIFT', 'JIMNY'],
#  'LANCIA': ['YPSILON', 'LYBRA', 'MUSA', 'DELTA', 'ELEFANTINO', 'KAPPA'],
#  'LAND_ROVER': ['DISCOVERY',
#   'RANGE_ROVER',
#   'RANGE_ROVER_SPORT',
#   'FREELANDER',
#   'RANGE_ROVER_EVOQUE',
#   'DEFENDER',
#   'SERIE_2',
#   'SERIE_3',
#   'SERIE_1',
#   'DISCOVERY_SPORT'],
#  'ROVER': ['DISCOVERY', 'FREELANDER', 'DEFENDER', 'RANGEROVER'],
#  'JAGUAR': ['X_TYPE', 'S_TYPE'],
#  'JEEP': ['WRANGLER', 'CHEROKEE'],
#  'SAAB': ['900', '9000'],
#  'LADA': ['SAMARA', 'NIVA', 'KALINA'],
#  'TRABANT': ['601']}

# %%
df["model"]=df["model"].fillna("MISSING VALUE")
#dftrim.head()
#a.isalnum()

# %%
df
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# 30      2016-04-03 15:48:11
# ...                     ...
# 371496  2016-03-20 12:46:00
# 371497  2016-03-05 15:54:11
# 371498  2016-03-11 15:50:38
# 371499  2016-03-08 13:52:00
# 371500  2016-03-21 23:40:49
# 371501  2016-03-26 18:36:54
# 371502  2016-04-01 12:59:21
# 371503  2016-04-01 01:55:58
# 371504  2016-03-07 17:06:35
# 371505  2016-04-03 19:56:57
# 371506  2016-03-20 18:47:59
# 371507  2016-03-16 17:06:19
# 371508  2016-04-02 16:43:27
# 371509  2016-03-11 23:40:32
# 371510  2016-03-06 21:11:23
# 371511  2016-03-31 18:50:37
# 371512  2016-03-25 18:48:06
# 371513  2016-03-21 15:36:22
# 371514  2016-04-04 11:45:16
# 371515  2016-03-09 11:36:55
# 371516  2016-04-04 09:57:12
# 371517  2016-03-28 13:48:07
# 371518  2016-04-02 20:37:03
# 371519  2016-03-09 13:37:43
# 371520  2016-03-19 19:53:49
# 371521  2016-03-27 20:36:20
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371526  2016-03-20 19:41:08
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller  price  \
# 0                                              GOLF 3 1.6  privat    480
# 1                                    A5 SPORTBACK 2.7 TDI  privat  18300
# 2                          JEEP GRAND CHEROKEE "OVERLAND"  privat   9800
# 3                                      GOLF 4 1 4  3TÜRER  privat   1500
# 4                          SKODA FABIA 1.4 TDI PD CLASSIC  privat   3600
# 5       BMW 316I   E36 LIMOUSINE   BASTLERFAHRZEUG  EX...  privat    650
# 6                             PEUGEOT 206 CC 110 PLATINUM  privat   2200
# 8                    FORD C   MAX TITANIUM 1 0 L ECOBOOST  privat  14500
# 9       VW GOLF 4 5 TUERIG ZU VERKAUFEN MIT ANHAENGERK...  privat    999
# 10                                      MAZDA 3 1.6 SPORT  privat   2000
# 11          VOLKSWAGEN PASSAT VARIANT 2.0 TDI COMFORTLINE  privat   2799
# 12                      VW PASSAT FACELIFT 35I  "7SITZER"  privat    999
# 13                         VW PASSAT 1.9 TDI 131 PS LEDER  privat   2500
# 14      NISSAN NAVARA 2.5DPF SE4X4 KLIMA SITZHEIZG BLU...  privat  17999
# 15                           KA LUFTHANSA EDITION 450€ VB  privat    450
# 16                                            POLO 6N 1 4  privat    300
# 17                            RENAULT TWINGO 1.2 16V AUT.  privat   1750
# 18                       FORD C MAX 2.0 TDCI DPF TITANIUM  privat   7550
# 19                      MERCEDES BENZ A 160 CLASSIC KLIMA  privat   1850
# 20                      VOLKSWAGEN SCIROCCO 1.4 TSI SPORT  privat  10400
# 21      BMW 530I TÜV 7/17 SCHECKHEFTGEPFLEGT SEHR GUTE...  privat   3699
# 22                          OPEL MERIVA 1.HAND TÜV 3.2018  privat   2900
# 23                                           STADTFLITZER  privat    450
# 24                             MERCEDES 200E  TÜV 04/2016  privat    500
# 25                  BMW 530D TOURING VOLLAUSSTATTUNG NAVI  privat   2500
# 26                              CITROEN C4 GRAND PICASSO.  privat   5555
# 27                         HONDA CIVIC 1.4 I VTEC COMFORT  privat   6900
# 28                                   VOLKSWAGEN T3 ANDERE  privat   1990
# 29                                         FIAT PUNTO 1.2  privat    690
# 30              MERCEDES BENZ E 250 D ORIGINAL ZUSTAND !!  privat   3300
# ...                                                   ...     ...    ...
# 371496                             PEUGEOT 206 CC "FILOU"  privat   3850
# 371497                             OPEL ASTRA 1.6 CARAVAN  privat   4900
# 371498                            OPEL VECTRA EDITION 100  privat    699
# 371499  OPEL CORSA B  ECO SWING  TÜV 1/17 8FACH BEREIF...  privat    600
# 371500  VOLKSWAGEN GOLF 1.4 TSI BLUEMOTION TECHNOLOGY ...  privat  20400
# 371501                                   CHRYSLER VOYAGER  privat   3900
# 371502                                  AUDI A4 AVANT 1.8  privat   1600
# 371503                                   SUBARU JUSTY 1.3  privat   1700
# 371504                                       220 CDI BENZ  privat   2600
# 371505                   OPEL ASTRA 1.6 CARAVAN SELECTION  privat    800
# 371506  VOLKSWAGEN GOLF 1.9 TDI DPF GOAL RENTNERFZG. 1...  privat   5900
# 371507  GEPFLEGTER AUDI A4 2.0TDI XENON AHK KLIMA SCHE...  privat   5999
# 371508                                     OPEL ASTRA 1.8  privat   1400
# 371509  LT 35 DIESEL GRUENE PLAKETTE....LETZTE GELEGEN...  privat   1900
# 371510  MERCEDES BENZ E KLASSE AVANGARDE 220 CDI GRUNE...  privat   6500
# 371511                           AUDI A3 1.8 T ATTRACTION  privat   1999
# 371512                 MERCEDES BENZ E 400 CDI AVANTGARDE  privat   5000
# 371513                       SEAT LEON 1.9 TDI 4/5 TUEREN  privat   4400
# 371514                 RENAULT 1 4 LTR.16 V MEGANE CABRIO  privat    999
# 371515                              SKODA FABIA KOMBI 1.4  privat   1690
# 371516                                VOLKSWAGEN LUPO 1.0  privat   1490
# 371517                   VOLKSWAGEN GOLF 2.0 TDI DPF TEAM  privat   7900
# 371518                          BMW 320 D DPF TOURING !!!  privat   3999
# 371519  ALFA ROMEO 159 JTDM 1.9 150 PS 13 600 KM TOP VOLL  privat   5250
# 371520                                       TURBO DEFEKT  privat   3200
# 371521                 OPEL ZAFIRA 1.6 ELEGANCE TÜV 12/16  privat   1150
# 371524              SMART SMART LEISTUNGSSTEIGERUNG 100PS  privat   1199
# 371525                 VOLKSWAGEN MULTIVAN T4 TDI 7DC UY2  privat   9200
# 371526                             VW GOLF KOMBI 1 9L TDI  privat   3400
# 371527       BMW M135I VOLLAUSGESTATTET NP 52.720    EURO  privat  28990
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0          test         NaN                1993    manuell        0
# 1          test       coupe                2011    manuell      190
# 2          test         suv                2004  automatik      163
# 3          test  kleinwagen                2001    manuell       75
# 4          test  kleinwagen                2008    manuell       69
# 5          test   limousine                1995    manuell      102
# 6          test      cabrio                2004    manuell      109
# 8       control         bus                2014    manuell      125
# 9          test  kleinwagen                1998    manuell      101
# 10      control   limousine                2004    manuell      105
# 11      control       kombi                2005    manuell      140
# 12      control       kombi                1995    manuell      115
# 13      control       kombi                2004    manuell      131
# 14      control         suv                2011    manuell      190
# 15         test  kleinwagen                1910        NaN        0
# 16         test         NaN                2016        NaN       60
# 17      control  kleinwagen                2004  automatik       75
# 18         test         bus                2007    manuell      136
# 19         test         bus                2004    manuell      102
# 20      control       coupe                2009    manuell      160
# 21         test   limousine                2002  automatik      231
# 22         test         NaN                2018    manuell       90
# 23         test  kleinwagen                1997    manuell       50
# 24         test   limousine                1990    manuell      118
# 25      control       kombi                2002  automatik      193
# 26      control         NaN                2017    manuell      125
# 27         test   limousine                2008    manuell       99
# 28         test         bus                1981    manuell       50
# 29         test  kleinwagen                2003    manuell       60
# 30         test   limousine                1995  automatik      113
# ...         ...         ...                 ...        ...      ...
# 371496     test      cabrio                2006    manuell      108
# 371497  control       kombi                2008    manuell      116
# 371498  control   limousine                1999    manuell      101
# 371499  control  kleinwagen                1998    manuell       54
# 371500     test   limousine                2014  automatik      150
# 371501     test         bus                2003  automatik      174
# 371502     test       kombi                1998    manuell      125
# 371503  control  kleinwagen                1999    manuell       68
# 371504  control         NaN                2005  automatik        0
# 371505     test       kombi                2000    manuell      101
# 371506     test   limousine                2006    manuell      105
# 371507     test       kombi                2005    manuell      140
# 371508  control   limousine                2001    manuell      125
# 371509     test         NaN                2000    manuell      110
# 371510     test   limousine                2003  automatik      145
# 371511  control   limousine                1997    manuell      150
# 371512     test   limousine                2003  automatik      260
# 371513  control   limousine                2008    manuell      105
# 371514  control      cabrio                2000    manuell       95
# 371515     test       kombi                2004    manuell       55
# 371516  control  kleinwagen                1998    manuell       50
# 371517     test   limousine                2010    manuell      140
# 371518     test       kombi                2005    manuell        3
# 371519  control         NaN                2016  automatik      150
# 371520  control   limousine                2004    manuell      225
# 371521  control         bus                2000    manuell        0
# 371524     test      cabrio                2000  automatik      101
# 371525     test         bus                1996    manuell      102
# 371526     test       kombi                2002    manuell      100
# 371527  control   limousine                2013    manuell      320
#
#                  model  kilometer  monthOfRegistration fuelType  \
# 0                 GOLF     150000                    0   benzin
# 1        MISSING VALUE     125000                    5   diesel
# 2       GRAND CHEROKEE     125000                    8   diesel
# 3                 GOLF     150000                    6   benzin
# 4                FABIA      90000                    7   diesel
# 5                  3ER     150000                   10   benzin
# 6              2_REIHE     150000                    8   benzin
# 8                C_MAX      30000                    8   benzin
# 9                 GOLF     150000                    0      NaN
# 10             3_REIHE     150000                   12   benzin
# 11              PASSAT     150000                   12   diesel
# 12              PASSAT     150000                   11   benzin
# 13              PASSAT     150000                    2      NaN
# 14              NAVARA      70000                    3   diesel
# 15                  KA       5000                    0   benzin
# 16                POLO     150000                    0   benzin
# 17              TWINGO     150000                    2   benzin
# 18               C_MAX     150000                    6   diesel
# 19            A_KLASSE     150000                    1   benzin
# 20            SCIROCCO     100000                    4   benzin
# 21                 5ER     150000                    7   benzin
# 22              MERIVA     150000                    5   benzin
# 23               AROSA     150000                    5   benzin
# 24              ANDERE     150000                   10   benzin
# 25                 5ER     150000                    9   diesel
# 26                  C4     125000                    4      NaN
# 27               CIVIC      60000                   11   benzin
# 28         TRANSPORTER       5000                    1   benzin
# 29               PUNTO     150000                    3   benzin
# 30            E_KLASSE     150000                    1   diesel
# ...                ...        ...                  ...      ...
# 371496         2_REIHE     125000                    2      NaN
# 371497           ASTRA     150000                    2   benzin
# 371498          VECTRA     150000                    3   benzin
# 371499           CORSA     150000                    1   benzin
# 371500            GOLF      30000                    9   benzin
# 371501         VOYAGER     150000                    7   benzin
# 371502              A4     150000                    2   benzin
# 371503           JUSTY      70000                   11   benzin
# 371504        C_KLASSE     150000                    9      NaN
# 371505           ASTRA     150000                   11   benzin
# 371506            GOLF     150000                    9   diesel
# 371507              A4     150000                    4   diesel
# 371508           ASTRA     150000                    2   benzin
# 371509   MISSING VALUE     150000                    7      NaN
# 371510        E_KLASSE     150000                    3   diesel
# 371511              A3     150000                   12   benzin
# 371512        E_KLASSE     150000                   12   diesel
# 371513            LEON     150000                    7   diesel
# 371514          MEGANE     150000                    4   benzin
# 371515           FABIA     150000                    4   benzin
# 371516            LUPO     150000                    9   benzin
# 371517            GOLF     150000                    7   diesel
# 371518             3ER     150000                    5   diesel
# 371519             159     150000                   12      NaN
# 371520            LEON     150000                    5   benzin
# 371521          ZAFIRA     150000                    3   benzin
# 371524          FORTWO     125000                    3   benzin
# 371525     TRANSPORTER     150000                    3   diesel
# 371526            GOLF     150000                    6   diesel
# 371527         M_REIHE      50000                    8   benzin
#
#                 brand notRepairedDamage
# 0          VOLKSWAGEN               NaN
# 1                AUDI                ja
# 2                JEEP               NaN
# 3          VOLKSWAGEN              nein
# 4               SKODA              nein
# 5                 BMW                ja
# 6             PEUGEOT              nein
# 8                FORD               NaN
# 9          VOLKSWAGEN               NaN
# 10              MAZDA              nein
# 11         VOLKSWAGEN                ja
# 12         VOLKSWAGEN               NaN
# 13         VOLKSWAGEN              nein
# 14             NISSAN              nein
# 15               FORD               NaN
# 16         VOLKSWAGEN               NaN
# 17            RENAULT              nein
# 18               FORD              nein
# 19      MERCEDES_BENZ              nein
# 20         VOLKSWAGEN              nein
# 21                BMW              nein
# 22               OPEL              nein
# 23               SEAT              nein
# 24      MERCEDES_BENZ                ja
# 25                BMW                ja
# 26            CITROEN              nein
# 27              HONDA              nein
# 28         VOLKSWAGEN              nein
# 29               FIAT              nein
# 30      MERCEDES_BENZ              nein
# ...               ...               ...
# 371496        PEUGEOT              nein
# 371497           OPEL              nein
# 371498           OPEL               NaN
# 371499           OPEL              nein
# 371500     VOLKSWAGEN              nein
# 371501       CHRYSLER              nein
# 371502           AUDI              nein
# 371503         SUBARU              nein
# 371504  MERCEDES_BENZ               NaN
# 371505           OPEL                ja
# 371506     VOLKSWAGEN              nein
# 371507           AUDI               NaN
# 371508           OPEL              nein
# 371509     VOLKSWAGEN              nein
# 371510  MERCEDES_BENZ              nein
# 371511           AUDI              nein
# 371512  MERCEDES_BENZ                ja
# 371513           SEAT              nein
# 371514        RENAULT               NaN
# 371515          SKODA               NaN
# 371516     VOLKSWAGEN              nein
# 371517     VOLKSWAGEN              nein
# 371518            BMW              nein
# 371519     ALFA_ROMEO              nein
# 371520           SEAT                ja
# 371521           OPEL              nein
# 371524          SMART              nein
# 371525     VOLKSWAGEN              nein
# 371526     VOLKSWAGEN               NaN
# 371527            BMW              nein
#
# [353784 rows x 15 columns]

# %%
#def fillmodel(model,brand,name):
#    for mdl in model:
#list['Renault Twingo 1.2 16V Aut.']        
#'Golf' in brandsmodels.get("Volkswagen")  
#'a' in z.keys()

# %%
df=df.drop(df[(df.brand =='SONSTIGE_AUTOS')].index)

# %%
df[df.brand=='SONSTIGE_AUTOS']
# Out:
# Empty DataFrame
# Columns: [dateCrawled, name, seller, price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage, model]
# Index: []

# %%
def fill_value(row,lookupDict):
    mdlist=[]
    
    if row.model in ["MISSING VALUE","ANDERE"]:#== "MISSING VALUE": #or row.model=="ANDERE":
    
        mdlist=lookupDict.get(row.brand)
   
        for mdl in mdlist:
            
            if mdl in list(row["name"].split(" ")):
                
                return mdl

# %%
brandsmodels
# Out:
# {'VOLKSWAGEN': ['GOLF',
#   'PASSAT',
#   'POLO',
#   'SCIROCCO',
#   'TRANSPORTER',
#   'JETTA',
#   'EOS',
#   'TOURAN',
#   'LUPO',
#   'CADDY',
#   'TIGUAN',
#   'SHARAN',
#   'UP',
#   'FOX',
#   'BEETLE',
#   'TOUAREG',
#   'KAEFER',
#   'PHAETON',
#   'CC',
#   'BORA',
#   'AMAROK'],
#  'SKODA': ['FABIA', 'YETI', 'OCTAVIA', 'ROOMSTER', 'SUPERB', 'CITIGO'],
#  'BMW': ['3ER',
#   '5ER',
#   '1ER',
#   '7ER',
#   'Z_REIHE',
#   '6ER',
#   'X_REIHE',
#   'M_REIHE',
#   'I3'],
#  'PEUGEOT': ['2_REIHE', '3_REIHE', '5_REIHE', '1_REIHE', '4_REIHE'],
#  'FORD': ['C_MAX',
#   'KA',
#   'FIESTA',
#   'ESCORT',
#   'FOCUS',
#   'MUSTANG',
#   'MONDEO',
#   'S_MAX',
#   'GALAXY',
#   'TRANSIT',
#   'KUGA',
#   'FUSION',
#   'B_MAX'],
#  'MAZDA': ['3_REIHE',
#   '6_REIHE',
#   '5_REIHE',
#   'RX_REIHE',
#   '1_REIHE',
#   'MX_REIHE',
#   'CX_REIHE'],
#  'NISSAN': ['NAVARA',
#   'MICRA',
#   'ALMERA',
#   'PRIMERA',
#   'JUKE',
#   'QASHQAI',
#   'X_TRAIL',
#   'NOTE'],
#  'RENAULT': ['TWINGO',
#   'CLIO',
#   'KANGOO',
#   'SCENIC',
#   'MEGANE',
#   'R19',
#   'ESPACE',
#   'MODUS',
#   'LAGUNA'],
#  'MERCEDES_BENZ': ['A_KLASSE',
#   'E_KLASSE',
#   'B_KLASSE',
#   'C_KLASSE',
#   'VITO',
#   'SPRINTER',
#   'SLK',
#   'GLK',
#   'M_KLASSE',
#   'VIANO',
#   'S_KLASSE',
#   'SL',
#   'CLK',
#   'V_KLASSE',
#   'CL',
#   'G_KLASSE',
#   'GL'],
#  'OPEL': ['MERIVA',
#   'KADETT',
#   'SIGNUM',
#   'ASTRA',
#   'INSIGNIA',
#   'COMBO',
#   'CORSA',
#   'OMEGA',
#   'ZAFIRA',
#   'VECTRA',
#   'AGILA',
#   'TIGRA',
#   'CALIBRA',
#   'ANTARA',
#   'VIVARO'],
#  'SEAT': ['AROSA',
#   'IBIZA',
#   'CORDOBA',
#   'MII',
#   'LEON',
#   'EXEO',
#   'ALHAMBRA',
#   'TOLEDO',
#   'ALTEA'],
#  'CITROEN': ['C4', 'BERLINGO', 'C1', 'C3', 'C5', 'C2'],
#  'HONDA': ['CIVIC', 'JAZZ', 'ACCORD', 'CR_REIHE'],
#  'FIAT': ['PUNTO',
#   'PANDA',
#   'SEICENTO',
#   '500',
#   'STILO',
#   'DUCATO',
#   'BRAVO',
#   'CROMA',
#   'DOBLO'],
#  'MINI': ['ONE', 'COOPER', 'CLUBMAN'],
#  'SMART': ['FORTWO', 'ROADSTER', 'FORFOUR'],
#  'AUDI': ['A8',
#   'A4',
#   'A1',
#   'TT',
#   'A6',
#   '80',
#   '100',
#   'A3',
#   'A2',
#   'A5',
#   'Q5',
#   '90',
#   'Q3',
#   'Q7',
#   '200'],
#  'ALFA_ROMEO': ['156', '147', 'SPIDER', '159', '145'],
#  'SUBARU': ['FORESTER', 'IMPREZA', 'JUSTY', 'LEGACY'],
#  'VOLVO': ['XC_REIHE', 'V40', 'V50', 'C_REIHE', 'V70', 'S60', '850', 'V60'],
#  'KIA': ['SPORTAGE', 'SORENTO', 'CEED', 'RIO', 'PICANTO', 'CARNIVAL'],
#  'HYUNDAI': ['GETZ', 'I_REIHE', 'SANTA', 'TUCSON'],
#  'MITSUBISHI': ['COLT', 'CARISMA', 'GALANT', 'LANCER', 'PAJERO', 'OUTLANDER'],
#  'CHEVROLET': ['MATIZ', 'SPARK', 'CAPTIVA', 'AVEO'],
#  'DAEWOO': ['MATIZ', 'LANOS', 'KALOS', 'NUBIRA'],
#  'DACIA': ['LOGAN', 'DUSTER', 'SANDERO', 'LODGY'],
#  'DAIHATSU': ['CUORE', 'SIRION', 'CHARADE', 'MOVE', 'TERIOS', 'MATERIA'],
#  'TOYOTA': ['AVENSIS', 'COROLLA', 'VERSO', 'RAV', 'YARIS', 'AYGO', 'AURIS'],
#  'CHRYSLER': ['PTCRUISER', 'CROSSFIRE', '300C', 'VOYAGER'],
#  'PORSCHE': ['BOXSTER', '911', 'CAYENNE'],
#  'SUZUKI': ['SWIFT', 'JIMNY'],
#  'LANCIA': ['YPSILON', 'LYBRA', 'MUSA', 'DELTA', 'ELEFANTINO', 'KAPPA'],
#  'LAND_ROVER': ['DISCOVERY',
#   'RANGE_ROVER',
#   'RANGE_ROVER_SPORT',
#   'FREELANDER',
#   'RANGE_ROVER_EVOQUE',
#   'DEFENDER',
#   'SERIE_2',
#   'SERIE_3',
#   'SERIE_1',
#   'DISCOVERY_SPORT'],
#  'ROVER': ['DISCOVERY', 'FREELANDER', 'DEFENDER', 'RANGEROVER'],
#  'JAGUAR': ['X_TYPE', 'S_TYPE'],
#  'JEEP': ['WRANGLER', 'CHEROKEE'],
#  'SAAB': ['900', '9000'],
#  'LADA': ['SAMARA', 'NIVA', 'KALINA'],
#  'TRABANT': ['601']}

# %%
df.model.fillna("MISSING VALUE")
# Out:
# 0                  GOLF
# 1         MISSING VALUE
# 2                 GRAND
# 3                  GOLF
# 4                 FABIA
# 5                   3ER
# 6               2_REIHE
# 8                 C_MAX
# 9                  GOLF
# 10              3_REIHE
# 11               PASSAT
# 12               PASSAT
# 13               PASSAT
# 14               NAVARA
# 15                   KA
# 16                 POLO
# 17               TWINGO
# 18                C_MAX
# 19             A_KLASSE
# 20             SCIROCCO
# 21                  5ER
# 22               MERIVA
# 23                AROSA
# 24               ANDERE
# 25                  5ER
# 26                   C4
# 27                CIVIC
# 28          TRANSPORTER
# 29                PUNTO
# 30             E_KLASSE
#               ...
# 371497            ASTRA
# 371498           VECTRA
# 371499            CORSA
# 371500             GOLF
# 371501          VOYAGER
# 371502               A4
# 371503            JUSTY
# 371504         C_KLASSE
# 371505            ASTRA
# 371506             GOLF
# 371507               A4
# 371508            ASTRA
# 371509    MISSING VALUE
# 371510         E_KLASSE
# 371511               A3
# 371512         E_KLASSE
# 371513             LEON
# 371514           MEGANE
# 371515            FABIA
# 371516             LUPO
# 371517             GOLF
# 371518              3ER
# 371519              159
# 371520             LEON
# 371521           ZAFIRA
# 371523    MISSING VALUE
# 371524           FORTWO
# 371525      TRANSPORTER
# 371526             GOLF
# 371527          M_REIHE
# Name: model, Length: 357045, dtype: object

# %%
#df.model[1]!=np.nan
#np.nan
#str()=="nan"
#df.model[1]
#bool(np.isnan(df.model[2]))


df[(df.results=="ANDERE")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-256-4306682dd597> in <module>()
#       6
#       7
# ----> 8 df[(df.results=="ANDERE")]
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'results'

# %%
df["sonuc"]=df.apply (lambda row: fill_value(row,brandsmodels),axis=1)

# %%
#dftrim1.sonuçlar=dftrim1.sonuçlar+dftrim1.model
df.sonuc.fillna(value=df.model, inplace=True)

# %%
#df=df.drop(columns="model")
df.rename(columns={"sonuc":"model"}, inplace=True)

# %%
#df.columns
df=df[[['dateCrawled', 'name','brand' , 'price','model' , 'vehicleType','yearOfRegistration' ,'monthOfRegistration','kilometer'
       , 'gearbox', 'powerPS', 'notRepairedDamage' , 'fuelType',
       , ,,
       'model']]]'seller'   'abtest'

# %%
####Suggest deletion of these rows


df.notRepairedDamage[df.notRepairedDamage=='nein'].count()
df[df.powerPS==0].count()
df[df.gearbox.isna()==True]
df[df.model=='MISSING VALUE']
# Out:
#                 dateCrawled  \
# 83      2016-04-03 12:56:45
# 165     2016-03-19 19:49:15
# 191     2016-03-16 15:51:08
# 320     2016-03-13 13:38:54
# 365     2016-03-08 08:57:34
# 373     2016-03-23 23:57:07
# 427     2016-03-26 21:49:45
# 563     2016-03-15 17:43:21
# 612     2016-03-10 18:45:10
# 658     2016-03-27 09:56:27
# 698     2016-03-17 14:56:29
# 735     2016-03-21 14:47:07
# 797     2016-03-25 15:56:33
# 806     2016-04-03 14:57:50
# 900     2016-04-02 13:50:51
# 907     2016-03-22 16:57:42
# 957     2016-03-26 18:44:52
# 974     2016-04-04 13:49:39
# 1060    2016-03-11 17:58:10
# 1244    2016-03-30 12:49:20
# 1255    2016-03-15 21:50:00
# 1261    2016-03-29 11:51:21
# 1433    2016-03-28 21:48:01
# 1504    2016-04-03 20:42:49
# 1542    2016-03-19 12:53:13
# 1630    2016-03-17 23:52:30
# 1684    2016-03-30 10:54:05
# 1734    2016-04-02 13:38:21
# 1835    2016-03-11 09:53:47
# 1880    2016-03-28 08:54:59
# ...                     ...
# 369819  2016-03-25 12:55:22
# 369827  2016-03-19 19:38:47
# 369950  2016-03-06 11:37:17
# 369976  2016-03-15 17:55:04
# 370085  2016-03-28 18:42:28
# 370177  2016-03-16 17:51:20
# 370195  2016-03-18 12:47:25
# 370209  2016-03-18 15:25:22
# 370212  2016-03-08 16:48:42
# 370218  2016-03-30 20:52:49
# 370221  2016-03-17 09:52:53
# 370328  2016-03-17 13:53:43
# 370346  2016-03-28 19:56:52
# 370397  2016-03-30 14:53:58
# 370404  2016-04-03 09:37:54
# 370409  2016-03-16 23:51:41
# 370413  2016-03-16 12:36:20
# 370433  2016-03-14 15:38:13
# 370764  2016-03-26 16:36:17
# 370798  2016-03-28 10:55:28
# 370836  2016-03-24 16:54:28
# 370952  2016-03-09 13:37:36
# 371001  2016-03-25 16:42:56
# 371060  2016-03-10 15:36:45
# 371110  2016-04-07 08:36:16
# 371121  2016-03-15 13:57:24
# 371146  2016-04-04 21:40:20
# 371150  2016-04-01 02:36:41
# 371309  2016-03-07 19:51:14
# 371509  2016-03-11 23:40:32
#
#                                                      name  seller  price  \
# 83                         BASTLER FAHRZEUG MIT REST TUEV  privat    350
# 165                                            IS ALES OK  privat    500
# 191                               BMW 530XD E60 EZ10/2008  privat  14000
# 320                     BIETE BMW 318 I KOMBI AUCH TAUSCH  privat   1600
# 365                                     PEUGEOT 107 KLIMA  privat   5500
# 373                      PEUGEOT  F  206 MIT MOTORSCHADEN  privat    300
# 427            ALFA GIULIETTA 2.0 JTDM MIT QV AUSSTATTUNG  privat  13950
# 563                                           TOP ZUSTAND  privat   2600
# 612            PEUGEOT 206CC QUIKSILVER BJ 2005 95.000 KM  privat   3800
# 658      BMW E 46 CABRIO  BLACK SAPHIR METALLIC  FACELIFT  privat   7400
# 698              C 220CDI KOMBI TÜV NEU DPF MOPF FACELIFT  privat   5900
# 735                                  SMART COUPE TUEV NEU  privat   1690
# 797                                          ZU VERKAUFEN  privat   1200
# 806                         MERCEDES C280 / W202 GEPFLEGT  privat    999
# 900     TOP  ZUSTAND  NOCH TUEV UND WENIGE KILOMETER  ...  privat    380
# 907                                    BMW 318TI IN WEISS  privat    300
# 957                          TOP TRANSPORTER MIT WENIG KM  privat   3100
# 974                          SUZUKI VITARA TÜV 4X4 ALLRAD  privat   1599
# 1060                                 VERKAUFE FORD ESCORD  privat    750
# 1244                             VW DERBY  PROJEKTAUFGABE  privat    350
# 1255                                HYUNDAI ATOS PRIME MX  privat    888
# 1261                                   MERCEDES C 220 CDI  privat   1650
# 1433                     MERCEDES  A KLASSE   UNFALL !!!   privat    500
# 1504                                     BMW 323I TÜV NEU  privat   1850
# 1542                                 RENAULT BASTLER AUTO  privat    280
# 1630       MERCEDES 190D 2 5 DIESEL MIT ANHAENGERKUPPLUNG  privat   2800
# 1684                      PEUGEOT 206 TÜV NEU KLIMAANLAGE  privat   2199
# 1734                           BMW E36 CABRIO MIT M PAKET  privat   1550
# 1835                                 SOMMERRAEDER BMW E90  privat    350
# 1880               SUCHE EIN GUTES AUTO MKT RATENZAHLUNG.  privat  14500
# ...                                                   ...     ...    ...
# 369819      GOLF4 GTI 1.8T MOTOR UEBERHOLT *EVTL. TAUSCH*  privat   4500
# 369827                                         PEUGOT 206  privat   2500
# 369950                            SUCHE DRINGEND EIN AUTO  privat    650
# 369976                            FORD FIESTA....TUEV NEU  privat   1299
# 370085                            TOP BMW TÜV 12 2017 TOP  privat   1200
# 370177  BMW E36 325I AC SCHNITZER PAKET LIMO  OHNE VANOS   privat   2300
# 370195          MERCEDES BENZ E 500 VOLLAUSTATTUNG V8 TOP  privat   8000
# 370209                              BMW 520I ZU VERKAUFEN  privat   2899
# 370212                                       BMW E61 525I  privat   5800
# 370218                               T4 MIT LKW ZULASSUNG  privat    750
# 370221        SUCHE BMW E36 ALLES ANBIETEN AUSSER COMPACT  privat    300
# 370328                 ZAHLE 1000 € VERMITTLUNGSPROVISION  privat    265
# 370346                                      ZUM VERKAUFEN  privat    300
# 370397                                 RENAULT TWINGT 1.2  privat    350
# 370404                    SMART PASSION CABRIO CDI BRABUS  privat   4250
# 370409         MERCEDES   BENZ CLS 250 CDI SHOOTING BRAKE  privat  43500
# 370413                                       HYUNDAI ATOS  privat    150
# 370433  PEUGEOT 106  SEHR SPARSAM UND GUENSTIG IM UNTE...  privat    850
# 370764                     FORD FIESTA MIT TÜV BIS 1.2018  privat   1150
# 370798                                MERCEDES BENZ E 200  privat   2999
# 370836      OPEL ZAVIRA 2.0DTI FRONTSCHADEN MOTOR LAEUFT.  privat    900
# 370952                                       RENAULT CLIP  privat   9800
# 371001                    CITROEN XSARA VTS 2.0 16V 163PS  privat   2800
# 371060             FORD MAVERICK GELAENDEWAGEN JAEGERAUTO  privat   2200
# 371110  SEHR GEPFLEGTER RENULT KOMBI AUS 1HAND UND NEU...  privat   1670
# 371121                                  MERCEDES BENZ 407  privat   1500
# 371146  VOLKSWAGEN UP! HIGH UP! NAVI  GLAS SD  SITZHZG...  privat  10980
# 371150                             HYUNDAI ATOS PRIME 1.0  privat   1000
# 371309     TAUSCHE GOLF2 GEGEN VW AUDI ODER RATTE RATLOOK  privat   1500
# 371509  LT 35 DIESEL GRUENE PLAKETTE....LETZTE GELEGEN...  privat   1900
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 83      control  kleinwagen                1997    manuell       54
# 165     control  kleinwagen                1999    manuell        0
# 191        test   limousine                2008        NaN      235
# 320        test       kombi                1999    manuell        0
# 365        test  kleinwagen                2012    manuell       68
# 373     control  kleinwagen                2001    manuell        0
# 427     control      andere                2011    manuell      140
# 563     control         NaN                2005        NaN        0
# 612        test      cabrio                2005    manuell      109
# 658        test      cabrio                2003  automatik      192
# 698     control       kombi                2004    manuell      150
# 735     control  kleinwagen                2000  automatik        0
# 797        test         NaN                2016    manuell      115
# 806        test   limousine                1995    manuell      192
# 900        test         NaN                2016    manuell       54
# 907        test         NaN                2016    manuell      140
# 957        test      andere                2001    manuell       90
# 974     control         NaN                2017    manuell        0
# 1060    control  kleinwagen                1990    manuell       90
# 1244    control         NaN                1985        NaN        0
# 1255    control  kleinwagen                2005    manuell       60
# 1261       test   limousine                1998    manuell      125
# 1433    control         NaN                2000        NaN        0
# 1504       test   limousine                1999    manuell      170
# 1542       test         NaN                2000    manuell        0
# 1630    control   limousine                1990    manuell       94
# 1684       test         NaN                2018    manuell       75
# 1734       test         NaN                1995    manuell      150
# 1835    control         NaN                2005        NaN        0
# 1880       test         NaN                2000        NaN        0
# ...         ...         ...                 ...        ...      ...
# 369819     test   limousine                1998    manuell      224
# 369827  control  kleinwagen                2007    manuell       75
# 369950     test  kleinwagen                1997        NaN        0
# 369976  control  kleinwagen                2002        NaN        0
# 370085  control         NaN                2000        NaN        0
# 370177  control         NaN                2017  automatik      192
# 370195  control   limousine                2002  automatik      306
# 370209     test   limousine                2001    manuell      177
# 370212     test       kombi                2005  automatik      192
# 370218  control         bus                1994    manuell       75
# 370221     test         NaN                2000    manuell        0
# 370328  control   limousine                2015    manuell      105
# 370346  control   limousine                2001  automatik        0
# 370397  control       coupe                1996    manuell       55
# 370404  control      cabrio                2005  automatik       41
# 370409     test       kombi                2013  automatik      204
# 370413     test         NaN                2000        NaN        0
# 370433  control         NaN                2005    manuell       75
# 370764  control  kleinwagen                1998    manuell       60
# 370798  control       kombi                1998    manuell        0
# 370836  control         NaN                2017    manuell      101
# 370952  control  kleinwagen                2013    manuell       90
# 371001  control       coupe                2003    manuell      163
# 371060     test         suv                1994    manuell      124
# 371110  control         NaN                2018    manuell        0
# 371121  control         bus                1984    manuell        0
# 371146     test         NaN                2018    manuell       75
# 371150  control         NaN                2017    manuell       54
# 371309  control         NaN                1995        NaN        0
# 371509     test         NaN                2000    manuell      110
#
#         kilometer  monthOfRegistration fuelType          brand  \
# 83         150000                    3      NaN           FIAT
# 165        150000                    0   benzin        RENAULT
# 191        150000                    0      NaN            BMW
# 320        150000                    6   benzin            BMW
# 365         40000                   12      NaN        PEUGEOT
# 373        150000                    5   benzin        PEUGEOT
# 427         60000                   11   diesel     ALFA_ROMEO
# 563        125000                    0      NaN      CHEVROLET
# 612        100000                   12   benzin        PEUGEOT
# 658        150000                    8      NaN            BMW
# 698        150000                    2   diesel  MERCEDES_BENZ
# 735        125000                   12   benzin          SMART
# 797         20000                    0   benzin         NISSAN
# 806        150000                    5   benzin  MERCEDES_BENZ
# 900        100000                    0   benzin          SKODA
# 907        150000                    0   benzin            BMW
# 957         70000                    7   diesel            KIA
# 974        150000                    0   benzin         SUZUKI
# 1060       150000                    4   benzin           FORD
# 1244       100000                    0   benzin     VOLKSWAGEN
# 1255       150000                    0   benzin        HYUNDAI
# 1261       150000                   11      NaN  MERCEDES_BENZ
# 1433         5000                    0      NaN  MERCEDES_BENZ
# 1504       150000                   12      lpg            BMW
# 1542       100000                    0   diesel        RENAULT
# 1630       150000                   11   diesel  MERCEDES_BENZ
# 1684       150000                    8   benzin        PEUGEOT
# 1734       150000                    5      NaN            BMW
# 1835         5000                    0      NaN            BMW
# 1880       125000                    0      NaN  MERCEDES_BENZ
# ...           ...                  ...      ...            ...
# 369819     150000                    6   benzin     VOLKSWAGEN
# 369827     150000                    7   benzin        PEUGEOT
# 369950       5000                    0   benzin        RENAULT
# 369976     150000                    0      NaN           FORD
# 370085     150000                    0      NaN            BMW
# 370177     150000                    0      NaN            BMW
# 370195     150000                   12   benzin  MERCEDES_BENZ
# 370209     150000                    6   benzin            BMW
# 370212     150000                    0      NaN            BMW
# 370218     150000                    0   diesel     VOLKSWAGEN
# 370221     150000                    0   benzin            BMW
# 370328      10000                    4      NaN           OPEL
# 370346     150000                    4      NaN       CHRYSLER
# 370397     150000                    0   benzin        RENAULT
# 370404     125000                    9   diesel          SMART
# 370409      90000                    3   diesel  MERCEDES_BENZ
# 370413     150000                    0      NaN        HYUNDAI
# 370433     150000                    0   benzin        PEUGEOT
# 370764     150000                    0      NaN           FIAT
# 370798     150000                    0   benzin  MERCEDES_BENZ
# 370836     150000                    6      NaN           OPEL
# 370952      50000                    4      NaN        RENAULT
# 371001     150000                    7   benzin        CITROEN
# 371060     150000                    0   benzin           FORD
# 371110      90000                    0   benzin        RENAULT
# 371121     150000                    5   diesel  MERCEDES_BENZ
# 371146      20000                    1      NaN     VOLKSWAGEN
# 371150     125000                    2      NaN        HYUNDAI
# 371309     150000                    0      NaN     VOLKSWAGEN
# 371509     150000                    7      NaN     VOLKSWAGEN
#
#        notRepairedDamage          model
# 83                    ja  MISSING VALUE
# 165                 nein  MISSING VALUE
# 191                 nein  MISSING VALUE
# 320                 nein  MISSING VALUE
# 365                 nein  MISSING VALUE
# 373                   ja  MISSING VALUE
# 427                 nein  MISSING VALUE
# 563                  NaN  MISSING VALUE
# 612                  NaN  MISSING VALUE
# 658                 nein  MISSING VALUE
# 698                 nein  MISSING VALUE
# 735                 nein  MISSING VALUE
# 797                 nein  MISSING VALUE
# 806                  NaN  MISSING VALUE
# 900                   ja  MISSING VALUE
# 907                  NaN  MISSING VALUE
# 957                 nein  MISSING VALUE
# 974                 nein  MISSING VALUE
# 1060                  ja  MISSING VALUE
# 1244                 NaN  MISSING VALUE
# 1255                  ja  MISSING VALUE
# 1261                nein  MISSING VALUE
# 1433                 NaN  MISSING VALUE
# 1504                 NaN  MISSING VALUE
# 1542                  ja  MISSING VALUE
# 1630                nein  MISSING VALUE
# 1684                 NaN  MISSING VALUE
# 1734                 NaN  MISSING VALUE
# 1835                 NaN  MISSING VALUE
# 1880                 NaN  MISSING VALUE
# ...                  ...            ...
# 369819              nein  MISSING VALUE
# 369827              nein  MISSING VALUE
# 369950              nein  MISSING VALUE
# 369976               NaN  MISSING VALUE
# 370085               NaN  MISSING VALUE
# 370177              nein  MISSING VALUE
# 370195              nein  MISSING VALUE
# 370209              nein  MISSING VALUE
# 370212              nein  MISSING VALUE
# 370218               NaN  MISSING VALUE
# 370221               NaN  MISSING VALUE
# 370328              nein  MISSING VALUE
# 370346                ja  MISSING VALUE
# 370397              nein  MISSING VALUE
# 370404              nein  MISSING VALUE
# 370409              nein  MISSING VALUE
# 370413                ja  MISSING VALUE
# 370433               NaN  MISSING VALUE
# 370764              nein  MISSING VALUE
# 370798               NaN  MISSING VALUE
# 370836               NaN  MISSING VALUE
# 370952               NaN  MISSING VALUE
# 371001               NaN  MISSING VALUE
# 371060              nein  MISSING VALUE
# 371110              nein  MISSING VALUE
# 371121               NaN  MISSING VALUE
# 371146              nein  MISSING VALUE
# 371150              nein  MISSING VALUE
# 371309               NaN  MISSING VALUE
# 371509              nein  MISSING VALUE
#
# [6966 rows x 15 columns]

# %%
brandsmodels
# Out:
# {'VOLKSWAGEN': ['GOLF',
#   'PASSAT',
#   'POLO',
#   'SCIROCCO',
#   'TRANSPORTER',
#   'JETTA',
#   'EOS',
#   'TOURAN',
#   'LUPO',
#   'CADDY',
#   'TIGUAN',
#   'SHARAN',
#   'UP',
#   'FOX',
#   'BEETLE',
#   'TOUAREG',
#   'KAEFER',
#   'PHAETON',
#   'CC',
#   'BORA',
#   'AMAROK'],
#  'SKODA': ['FABIA', 'YETI', 'OCTAVIA', 'ROOMSTER', 'SUPERB', 'CITIGO'],
#  'BMW': ['3ER',
#   '5ER',
#   '1ER',
#   '7ER',
#   'Z_REIHE',
#   '6ER',
#   'X_REIHE',
#   'M_REIHE',
#   'I3'],
#  'PEUGEOT': ['2_REIHE', '3_REIHE', '5_REIHE', '1_REIHE', '4_REIHE'],
#  'FORD': ['C_MAX',
#   'KA',
#   'FIESTA',
#   'ESCORT',
#   'FOCUS',
#   'MUSTANG',
#   'MONDEO',
#   'S_MAX',
#   'GALAXY',
#   'TRANSIT',
#   'KUGA',
#   'FUSION',
#   'B_MAX'],
#  'MAZDA': ['3_REIHE',
#   '6_REIHE',
#   '5_REIHE',
#   'RX_REIHE',
#   '1_REIHE',
#   'MX_REIHE',
#   'CX_REIHE'],
#  'NISSAN': ['NAVARA',
#   'MICRA',
#   'ALMERA',
#   'PRIMERA',
#   'JUKE',
#   'QASHQAI',
#   'X_TRAIL',
#   'NOTE'],
#  'RENAULT': ['TWINGO',
#   'CLIO',
#   'KANGOO',
#   'SCENIC',
#   'MEGANE',
#   'R19',
#   'ESPACE',
#   'MODUS',
#   'LAGUNA'],
#  'MERCEDES_BENZ': ['A_KLASSE',
#   'E_KLASSE',
#   'B_KLASSE',
#   'C_KLASSE',
#   'VITO',
#   'SPRINTER',
#   'SLK',
#   'GLK',
#   'M_KLASSE',
#   'VIANO',
#   'S_KLASSE',
#   'SL',
#   'CLK',
#   'V_KLASSE',
#   'CL',
#   'G_KLASSE',
#   'GL'],
#  'OPEL': ['MERIVA',
#   'KADETT',
#   'SIGNUM',
#   'ASTRA',
#   'INSIGNIA',
#   'COMBO',
#   'CORSA',
#   'OMEGA',
#   'ZAFIRA',
#   'VECTRA',
#   'AGILA',
#   'TIGRA',
#   'CALIBRA',
#   'ANTARA',
#   'VIVARO'],
#  'SEAT': ['AROSA',
#   'IBIZA',
#   'CORDOBA',
#   'MII',
#   'LEON',
#   'EXEO',
#   'ALHAMBRA',
#   'TOLEDO',
#   'ALTEA'],
#  'CITROEN': ['C4', 'BERLINGO', 'C1', 'C3', 'C5', 'C2'],
#  'HONDA': ['CIVIC', 'JAZZ', 'ACCORD', 'CR_REIHE'],
#  'FIAT': ['PUNTO',
#   'PANDA',
#   'SEICENTO',
#   '500',
#   'STILO',
#   'DUCATO',
#   'BRAVO',
#   'CROMA',
#   'DOBLO'],
#  'MINI': ['ONE', 'COOPER', 'CLUBMAN'],
#  'SMART': ['FORTWO', 'ROADSTER', 'FORFOUR'],
#  'AUDI': ['A8',
#   'A4',
#   'A1',
#   'TT',
#   'A6',
#   '80',
#   '100',
#   'A3',
#   'A2',
#   'A5',
#   'Q5',
#   '90',
#   'Q3',
#   'Q7',
#   '200'],
#  'ALFA_ROMEO': ['156', '147', 'SPIDER', '159', '145'],
#  'SUBARU': ['FORESTER', 'IMPREZA', 'JUSTY', 'LEGACY'],
#  'VOLVO': ['XC_REIHE', 'V40', 'V50', 'C_REIHE', 'V70', 'S60', '850', 'V60'],
#  'KIA': ['SPORTAGE', 'SORENTO', 'CEED', 'RIO', 'PICANTO', 'CARNIVAL'],
#  'HYUNDAI': ['GETZ', 'I_REIHE', 'SANTA', 'TUCSON'],
#  'MITSUBISHI': ['COLT', 'CARISMA', 'GALANT', 'LANCER', 'PAJERO', 'OUTLANDER'],
#  'CHEVROLET': ['MATIZ', 'SPARK', 'CAPTIVA', 'AVEO'],
#  'DAEWOO': ['MATIZ', 'LANOS', 'KALOS', 'NUBIRA'],
#  'DACIA': ['LOGAN', 'DUSTER', 'SANDERO', 'LODGY'],
#  'DAIHATSU': ['CUORE', 'SIRION', 'CHARADE', 'MOVE', 'TERIOS', 'MATERIA'],
#  'TOYOTA': ['AVENSIS', 'COROLLA', 'VERSO', 'RAV', 'YARIS', 'AYGO', 'AURIS'],
#  'CHRYSLER': ['PTCRUISER', 'CROSSFIRE', '300C', 'VOYAGER'],
#  'PORSCHE': ['BOXSTER', '911', 'CAYENNE'],
#  'SUZUKI': ['SWIFT', 'JIMNY'],
#  'LANCIA': ['YPSILON', 'LYBRA', 'MUSA', 'DELTA', 'ELEFANTINO', 'KAPPA'],
#  'LAND_ROVER': ['DISCOVERY',
#   'RANGE_ROVER',
#   'RANGE_ROVER_SPORT',
#   'FREELANDER',
#   'RANGE_ROVER_EVOQUE',
#   'DEFENDER',
#   'SERIE_2',
#   'SERIE_3',
#   'SERIE_1',
#   'DISCOVERY_SPORT'],
#  'ROVER': ['DISCOVERY', 'FREELANDER', 'DEFENDER', 'RANGEROVER'],
#  'JAGUAR': ['X_TYPE', 'S_TYPE'],
#  'JEEP': ['WRANGLER', 'CHEROKEE'],
#  'SAAB': ['900', '9000'],
#  'LADA': ['SAMARA', 'NIVA', 'KALINA'],
#  'TRABANT': ['601']}

# %%
####Suggest deletion of these values

df[(df.price>=100)&(df.price<1000)].count()
# Out:
# dateCrawled            68584
# name                   68584
# seller                 68584
# price                  68584
# abtest                 68584
# vehicleType            56851
# yearOfRegistration     68584
# gearbox                62913
# powerPS                68584
# kilometer              68584
# monthOfRegistration    68584
# fuelType               58147
# brand                  68584
# notRepairedDamage      46774
# model                  68584
# dtype: int64

# %%
df.groupby(["brand","model"]).price.mean()
df[df.model=='ANDERE']
# Out:
#                 dateCrawled  \
# 24      2016-03-13 20:40:49
# 38      2016-04-01 17:45:07
# 39      2016-03-25 15:50:30
# 52      2016-04-04 10:57:36
# 56      2016-03-21 01:59:07
# 58      2016-03-10 20:53:19
# 68      2016-03-21 12:47:55
# 69      2016-03-15 09:51:05
# 88      2016-03-13 19:52:34
# 93      2016-04-02 23:25:25
# 104     2016-03-16 16:44:10
# 118     2016-04-04 09:50:15
# 167     2016-03-30 10:50:00
# 182     2016-03-22 10:55:42
# 211     2016-03-25 01:36:44
# 238     2016-03-12 08:51:00
# 241     2016-03-22 11:59:28
# 249     2016-03-10 10:46:01
# 250     2016-03-06 18:49:03
# 260     2016-03-21 10:44:34
# 277     2016-03-11 13:52:52
# 290     2016-03-17 22:52:09
# 309     2016-03-09 19:58:09
# 336     2016-03-26 13:53:42
# 337     2016-03-16 17:38:52
# 351     2016-03-09 20:45:43
# 392     2016-03-12 12:40:29
# 421     2016-03-22 12:55:10
# 426     2016-03-18 12:48:27
# 435     2016-04-01 13:50:10
# ...                     ...
# 371050  2016-03-05 20:43:30
# 371066  2016-03-22 16:58:12
# 371068  2016-03-27 15:54:00
# 371069  2016-04-03 16:46:11
# 371070  2016-03-11 19:49:36
# 371126  2016-04-04 20:57:20
# 371132  2016-03-31 00:50:02
# 371141  2016-03-20 17:55:10
# 371153  2016-04-03 20:50:55
# 371167  2016-03-21 20:57:41
# 371177  2016-03-23 16:57:30
# 371185  2016-03-22 20:48:48
# 371192  2016-03-25 21:51:57
# 371247  2016-03-19 20:53:14
# 371256  2016-03-05 22:52:41
# 371278  2016-03-07 19:46:36
# 371306  2016-03-08 00:49:14
# 371312  2016-03-15 12:55:31
# 371343  2016-03-12 00:58:17
# 371346  2016-03-23 07:55:05
# 371370  2016-03-19 14:59:31
# 371393  2016-03-13 20:38:41
# 371394  2016-03-23 23:37:40
# 371441  2016-03-21 20:44:38
# 371444  2016-03-05 14:55:29
# 371445  2016-03-11 14:45:44
# 371457  2016-03-12 08:37:15
# 371471  2016-03-07 19:58:44
# 371481  2016-03-12 16:48:14
# 371488  2016-03-15 01:51:20
#
#                                                      name  seller  price  \
# 24                             MERCEDES 200E  TÜV 04/2016  privat    500
# 38      ABSCHLEPPWAGEN VW LT 195.000 GRUENE PLAKETTE T...  privat  11900
# 39                                   MERCEDES CAMPER D407  privat   1500
# 52          VERKAUFE MEINEN KLEINEN WEGEN NEU ANSCHAFFUNG  privat   1400
# 56                                   BMW 435I SPORT COUPE  privat  39600
# 58             SEAT INCA 1.9SDI   LKW ZULASSUNG   TÜV NEU  privat   2399
# 68                                HONDA HRV RESERVIERT!!!  privat   2100
# 69                                      MERCEDES BENZ 190  privat   1280
# 88                                       MITSUBISHI L 400  privat   1800
# 93               SENATOR A2  3 0E  180PS  CD AUSSTATTUNG.  privat   1222
# 104             HYUNDAI GENESIS COUPE GT 3.8 V6 AUTOMATIK  privat  22999
# 118                            VOLKSWAGEN CORRADO 1.8 G60  privat   3500
# 167                             MITSUBISHI SPACE OHNE TÜV  privat    300
# 182                             OPEL SINTRA 2.2  7 SITZER  privat    300
# 211                              VOLKSWAGEN VENTO 1.8 CLX  privat    999
# 238                             SUZUKI LJ 80 FUER BASTLER  privat   1000
# 241                     LANCIA PHEDRA 2.0 16V JTD EMBLEMA  privat   1440
# 249                                     MAZDA PREMACY 1.9  privat    800
# 250                                          NISSAN 350 Z  privat  10200
# 260     PORSCHE CAYMAN 2.9   PCM/NAVI   SPORT CHRONO  ...  privat  25900
# 277            MERCEDES BENZ CLS 350 CDI 4MATIC 7G TRONIC  privat  48000
# 290                                    MITSUBISHI 3000 GT  privat   6000
# 309                                      MITSUBISHI L 300  privat   2899
# 336                                      TOYOTA CELICA GT  privat   2600
# 337                  MERCEDES BENZ C 220 T CDI AVANTGARDE  privat  11700
# 351                                       CAMARO 3.4 ..V6  privat   3550
# 392                RENAULT GRAND SCENIC  7 SITZER  EURO 4  privat   2950
# 421              PEUGEOT 806 HDI JE PARLE FRANCAIS LA 110  privat   2200
# 426                          CORVETTE C1 1959 TOP ZUSTAND  privat  90500
# 435                          SUZUKI VITARA 1 6 L BENZINER  privat   1199
# ...                                                   ...     ...    ...
# 371050      TRABANT 600 P60 LIMO SCHEUNENFUND  / KEIN 601  privat    800
# 371066                                TOYOTA SUPRA 3.0 NT  privat   8500
# 371068                                   HYUNDAI ATOS 1.0  privat    750
# 371069                     RENAULT TRAFIC 2.0 DCI 90 L2H2  privat   3000
# 371070                            CHRYSLER STRATUS 2.5 LX  privat    999
# 371126                                        NISSAN PIXO  privat   3250
# 371132                                         FORD CAPRI  privat   7000
# 371141                                  ICH VERKAUFE HIER  privat   1650
# 371153                                      TOYOTA IQ 1.0  privat   4900
# 371167                                            AUDI S5  privat  28000
# 371177  RENAULT CARAVELLE CABRIOLET   CHIC IN DIE SAISON!  privat  10500
# 371185                 MERCEDES BENZ CLS 55 AMG AUTOMATIK  privat  20000
# 371192                   SKODA PRAKTIK 2008R KLIMATYZACJA  privat   2300
# 371247                     ALFA ROMEO GT 2.0 JTS SPORTIVA  privat   3950
# 371256                 AUDI CABRIOLET 2.0 / ALLES GEMACHT  privat   6499
# 371278                                     CITROËN JUMPER  privat   2300
# 371306                    MERCEDES BENZ CLS 350 7G TRONIC  privat  16999
# 371312                               MERCEDES BENZ CE 230  privat   8500
# 371343                       HYUNDAI H 1  6 SITZER  WEISS  privat   9300
# 371346  OPEL GT GESUCHT GUTER ZUTSAND UNFALLFREI ! BIS...  privat  14000
# 371370                          RENAULT R 5 GTR   3   TÜR  privat    790
# 371393                                       DAEWOO REZZO  privat   1000
# 371394  FIAT FIORINO MIT LKW ZULASSUNG  TRANSPORTER  K...  privat    890
# 371441                   BMW E9 COUPE RESTAURATIONSOBJEKT  privat  16500
# 371444                                     CITROEN JUMPER  privat   5000
# 371445                            HYUNDAI ATOS TÜV 3/2018  privat   2500
# 371457                      CHEVY VAN 4X4 ALLRAD H NUMMER  privat   5990
# 371471                 TRABANT P70 COUPE OLDTIMER IFA DDR  privat   3300
# 371481  PORSCHE 944 S2 CABRIO 1991 3 0 211PS ANTHAZIT/...  privat  12800
# 371488          MERCEDES BENZ MERCEDES SPORTCOUPE CLC 180  privat   2999
#
#          abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 24         test   limousine                1990    manuell      118
# 38         test      andere                2002    manuell      129
# 39         test         bus                1984    manuell       70
# 52      control         NaN                2016    manuell       55
# 56         test       coupe                2014  automatik      306
# 58         test         NaN                2018    manuell       64
# 68      control         suv                2000    manuell      105
# 69      control   limousine                1992  automatik      109
# 88      control         bus                2001    manuell       87
# 93      control   limousine                1984  automatik      180
# 104     control       coupe                2012  automatik      303
# 118     control       coupe                1991    manuell      160
# 167        test  kleinwagen                1994    manuell        0
# 182     control         bus                1997    manuell        0
# 211        test   limousine                1995    manuell       75
# 238     control         suv                1982    manuell       41
# 241     control         bus                2003    manuell      109
# 249        test         bus                2001  automatik      114
# 250     control       coupe                2008    manuell        0
# 260        test       coupe                2009    manuell      265
# 277        test       coupe                2014  automatik      265
# 290        test       coupe                1995    manuell      286
# 309        test         bus                1996    manuell       69
# 336     control       coupe                1998    manuell      170
# 337     control       kombi                2008    manuell      170
# 351        test   limousine                1993    manuell        0
# 392        test         bus                2005    manuell      131
# 421     control         bus                2000    manuell        0
# 426     control      cabrio                1959  automatik      295
# 435     control         suv                1992    manuell       80
# ...         ...         ...                 ...        ...      ...
# 371050  control         NaN                1970        NaN        0
# 371066     test       coupe                1995    manuell      224
# 371068  control  kleinwagen                2001        NaN        0
# 371069  control         bus                2008    manuell       90
# 371070     test   limousine                1997  automatik      163
# 371126  control  kleinwagen                2010    manuell       68
# 371132  control       coupe                1980  automatik      114
# 371141     test       coupe                1999    manuell      177
# 371153     test  kleinwagen                2011    manuell       68
# 371167  control       coupe                2009    manuell      354
# 371177     test      cabrio                1968    manuell       54
# 371185  control       coupe                2006  automatik      476
# 371192     test       kombi                2008    manuell       80
# 371247  control       coupe                2006    manuell      166
# 371256  control      cabrio                1996    manuell      116
# 371278  control         bus                2000    manuell        0
# 371306  control       coupe                2006  automatik      272
# 371312  control       coupe                1981  automatik      136
# 371343     test         bus                2011    manuell      116
# 371346  control       coupe                2007    manuell      264
# 371370     test         NaN                1990    manuell        0
# 371393  control         bus                2001    manuell      121
# 371394  control         bus                1999    manuell       67
# 371441  control       coupe                1973    manuell      200
# 371444  control         NaN                2017    manuell      120
# 371445  control  kleinwagen                2007    manuell       60
# 371457  control         bus                1984  automatik        0
# 371471  control       coupe                1957    manuell       40
# 371481  control      cabrio                1991    manuell      211
# 371488     test       coupe                2003    manuell      143
#
#         kilometer  monthOfRegistration fuelType          brand  \
# 24         150000                   10   benzin  MERCEDES_BENZ
# 38         150000                   11   diesel     VOLKSWAGEN
# 39         150000                    8   diesel  MERCEDES_BENZ
# 52           5000                    1      NaN        HYUNDAI
# 56          30000                    7   benzin            BMW
# 58         125000                    3      NaN           SEAT
# 68         150000                    8   benzin          HONDA
# 69         150000                    9   benzin  MERCEDES_BENZ
# 88         150000                    7   diesel     MITSUBISHI
# 93         150000                    3   benzin           OPEL
# 104         50000                    4   benzin        HYUNDAI
# 118        150000                    5   benzin     VOLKSWAGEN
# 167        150000                    7   benzin     MITSUBISHI
# 182        150000                    7   benzin           OPEL
# 211        150000                   10   benzin     VOLKSWAGEN
# 238        150000                   11   benzin         SUZUKI
# 241        150000                   11   diesel         LANCIA
# 249        150000                    4   benzin          MAZDA
# 250         90000                    6   benzin         NISSAN
# 260        125000                    5   benzin        PORSCHE
# 277         80000                   10   diesel  MERCEDES_BENZ
# 290        150000                    4   benzin     MITSUBISHI
# 309        150000                    9   diesel     MITSUBISHI
# 336        150000                   10   benzin         TOYOTA
# 337        150000                    7   diesel  MERCEDES_BENZ
# 351        125000                   11   benzin      CHEVROLET
# 392        150000                    6   diesel        RENAULT
# 421        150000                    3   diesel        PEUGEOT
# 426         90000                    7   benzin      CHEVROLET
# 435        150000                    5   benzin         SUZUKI
# ...           ...                  ...      ...            ...
# 371050     150000                    0      NaN        TRABANT
# 371066     150000                    3   benzin         TOYOTA
# 371068     150000                    0   benzin        HYUNDAI
# 371069     150000                    6   diesel        RENAULT
# 371070     150000                    8   benzin       CHRYSLER
# 371126      80000                    6   benzin         NISSAN
# 371132      80000                    8   benzin           FORD
# 371141     150000                    8   benzin           FORD
# 371153      60000                    3   benzin         TOYOTA
# 371167      60000                    7   benzin           AUDI
# 371177      20000                    4      NaN        RENAULT
# 371185     125000                    7   benzin  MERCEDES_BENZ
# 371192     150000                    3   diesel          SKODA
# 371247     150000                    5   benzin     ALFA_ROMEO
# 371256     150000                   12   benzin           AUDI
# 371278      80000                    0   diesel        CITROEN
# 371306     125000                   10   benzin  MERCEDES_BENZ
# 371312     150000                    4   benzin  MERCEDES_BENZ
# 371343     150000                   12   diesel        HYUNDAI
# 371346      80000                    6   benzin           OPEL
# 371370     150000                    1   benzin        RENAULT
# 371393     150000                    1   benzin         DAEWOO
# 371394     125000                    7   diesel           FIAT
# 371441     150000                    6   benzin            BMW
# 371444     150000                    7      NaN        CITROEN
# 371445     125000                    3   benzin        HYUNDAI
# 371457      70000                    4   benzin      CHEVROLET
# 371471     100000                   11   benzin        TRABANT
# 371481     150000                    7   benzin        PORSCHE
# 371488     150000                    3   benzin  MERCEDES_BENZ
#
#        notRepairedDamage   model
# 24                    ja  ANDERE
# 38                  nein  ANDERE
# 39                  nein  ANDERE
# 52                   NaN  ANDERE
# 56                  nein  ANDERE
# 58                  nein  ANDERE
# 68                  nein  ANDERE
# 69                   NaN  ANDERE
# 88                  nein  ANDERE
# 93                   NaN  ANDERE
# 104                 nein  ANDERE
# 118                 nein  ANDERE
# 167                  NaN  ANDERE
# 182                  NaN  ANDERE
# 211                 nein  ANDERE
# 238                  NaN  ANDERE
# 241                 nein  ANDERE
# 249                   ja  ANDERE
# 250                  NaN  ANDERE
# 260                 nein  ANDERE
# 277                 nein  ANDERE
# 290                 nein  ANDERE
# 309                 nein  ANDERE
# 336                 nein  ANDERE
# 337                 nein  ANDERE
# 351                  NaN  ANDERE
# 392                 nein  ANDERE
# 421                 nein  ANDERE
# 426                 nein  ANDERE
# 435                 nein  ANDERE
# ...                  ...     ...
# 371050               NaN  ANDERE
# 371066                ja  ANDERE
# 371068               NaN  ANDERE
# 371069                ja  ANDERE
# 371070              nein  ANDERE
# 371126                ja  ANDERE
# 371132              nein  ANDERE
# 371141               NaN  ANDERE
# 371153              nein  ANDERE
# 371167              nein  ANDERE
# 371177              nein  ANDERE
# 371185              nein  ANDERE
# 371192               NaN  ANDERE
# 371247              nein  ANDERE
# 371256              nein  ANDERE
# 371278              nein  ANDERE
# 371306              nein  ANDERE
# 371312              nein  ANDERE
# 371343              nein  ANDERE
# 371346              nein  ANDERE
# 371370               NaN  ANDERE
# 371393              nein  ANDERE
# 371394              nein  ANDERE
# 371441                ja  ANDERE
# 371444                ja  ANDERE
# 371445               NaN  ANDERE
# 371457               NaN  ANDERE
# 371471              nein  ANDERE
# 371481              nein  ANDERE
# 371488                ja  ANDERE
#
# [25398 rows x 15 columns]
